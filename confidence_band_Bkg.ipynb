# %% [markdown]
# # 信頼バンドの根探索 (`find_confidence_band`)
#
# 等間隔グリッドの代わりに、ブラケット＋幾何二分法でバンドの上下端を直接探す例。
# 最も広い 2σ で外側をブラケットし、各レベル (1σ/90%/2σ) の端を入れ子で詰める。
#
# - `num_pseudo_data`: ブラケット段階の擬似データ数（粗くてよい）
# - `n_pseudo_edge`: 端の二分法で使う擬似データ数（cutoff のノイズを抑えるため大きめ）
# - `seed`: 固定すると各点が再現可能になり、二分法のジッターが減る

# %%
from neutrino_analysis_band import NeutrinoAnalysis

a = NeutrinoAnalysis(background_scenario='b', intervals='180',
                     GeV=0.6e16, solver='osqp')
a.optimize(a.data_vector)   # ベストフィットを先に求める (self.result を埋める)
result_b = a.optimize(a.data_vector)
print("\nOptimization Complete.")
print(f"Minimum chi-squared: {result_b.fun / a.c}")
# 3. Plot the primary result: the optimized flux vs. theory.
a.plot_flux_comparison(save = True)
# Out:
# Optimization Complete.
# Minimum chi-squared: 6.779129900985238e-05
# Plot saved as scenario_bkg_b/flux_comparison_bkg_b.pdf

# %% [markdown]
# ## 複数インデックスのバンドを保存して重ねる
#
# 1. インデックスごとに `find_and_save_band` を実行し、`bands/` 配下に 1 ファイルずつ JSON で保存する。
# 2. `plot_flux_with_bands` で保存済みファイルを読み込み、`optimize` の最適フラックス（散布図）の上に各インデックスのバンドを誤差棒として重ねる。
#
# `save_band` / `load_band` は JSON 形式（人が読める）。バンドの中心は保存時の `self.result.x[index]` なので、同じ `optimize` 結果の散布図とちょうど重なる。

# %%
# 複数インデックスでバンドを作り、インデックスごとに 1 ファイルへ保存
# 保存先は ./bands/band_bkg<scenario>_idx<NNN>.json
indices = [0, 1, 2, 3, 4, 5, 8, 13, 16, 20, 25, 30, 40, 50, 60, 70, 80, 90, 100, 110, 120, 130, 140, 150, 160, 167]     # 走らせたいインデックス

for idx in indices:
    print(f'=== index {idx} ===')
    a.find_and_save_band(
        idx,
        outdir='scenario_bkg_b/bands',
        levels=(0.678, 0.954),
        num_pseudo_data=20,
        n_pseudo_edge=100,
        step=1.5,
        rel_tol=0.03,
        seed=42,
        n_jobs=-1,
        verbose=True,
    )
# Out:
# === index 0 ===
# [band idx=0] v0=1.0466e+12 (phys), bracketing with step=1.5
#   upper bracket: 2.6824e+13
#   lower bracket: 6.9775e+11
#   level 0.678: [8.6553e+11, 1.3706e+13] (phys)
#   level 0.954: [7.8210e+11, 2.4549e+13] (phys)
# Band saved as scenario_bkg_b/bands/band_bkgb_idx000.json
# === index 1 ===
# [band idx=1] v0=2.3090e+12 (phys), bracketing with step=1.5
#   upper bracket: 1.1689e+13
#   lower bracket: 6.8414e+11
#   level 0.678: [8.0413e+11, 6.2832e+12] (phys)
#   level 0.954: [7.3123e+11, 1.0973e+13] (phys)
# Band saved as scenario_bkg_b/bands/band_bkgb_idx001.json
# === index 2 ===
# [band idx=2] v0=4.5775e+12 (phys), bracketing with step=1.5
#   upper bracket: 6.8662e+12
#   lower bracket: 6.0280e+11
#   level 0.678: [7.9535e+11, 4.6362e+12] (phys)
#   level 0.954: [7.3479e+11, 6.6106e+12] (phys)
# Band saved as scenario_bkg_b/bands/band_bkgb_idx002.json
# === index 3 ===
# [band idx=3] v0=3.8398e+12 (phys), bracketing with step=1.5
#   upper bracket: 5.7597e+12
#   lower bracket: 5.0566e+11
#   level 0.678: [7.9416e+11, 3.8891e+12] (phys)
#   level 0.954: [7.3369e+11, 4.6440e+12] (phys)
# Band saved as scenario_bkg_b/bands/band_bkgb_idx003.json
# === index 4 ===
# [band idx=4] v0=2.1410e+12 (phys), bracketing with step=1.5
#   upper bracket: 4.8172e+12
#   lower bracket: 6.3436e+11
#   level 0.678: [8.0452e+11, 2.3397e+12] (phys)
#   level 0.954: [7.3159e+11, 3.5096e+12] (phys)
# Band saved as scenario_bkg_b/bands/band_bkgb_idx004.json
# === index 5 ===
# [warn] best-fit value v0=3.819e+07 is already outside the 0.954 band — check the construction.
# [band idx=5] v0=6.8543e+11 (phys), bracketing with step=1.5
#   upper bracket: 3.4700e+12
#   lower bracket: 4.5695e+11
#   level 0.678: [6.7685e+11, 2.0125e+12] (phys)
#   level 0.954: [6.7685e+11, 2.7978e+12] (phys)
# Band saved as scenario_bkg_b/bands/band_bkgb_idx005.json
# === index 8 ===
# [warn] best-fit value v0=4.072e+07 is already outside the 0.954 band — check the construction.
# [band idx=8] v0=7.3081e+11 (phys), bracketing with step=1.5
#   upper bracket: 2.4665e+12
#   lower bracket: 4.8721e+11
#   level 0.678: [7.2167e+11, 1.4906e+12] (phys)
#   level 0.954: [7.2167e+11, 1.9450e+12] (phys)
# Band saved as scenario_bkg_b/bands/band_bkgb_idx008.json
# === index 13 ===
# [band idx=13] v0=7.3189e+11 (phys), bracketing with step=1.5
#   upper bracket: 1.6468e+12
#   lower bracket: 4.8793e+11
#   level 0.678: [7.2273e+11, 1.2945e+12] (phys)
#   level 0.954: [6.8702e+11, 1.5071e+12] (phys)
# Band saved as scenario_bkg_b/bands/band_bkgb_idx013.json
# === index 16 ===
# [warn] best-fit value v0=3.699e+07 is already outside the 0.954 band — check the construction.
# [band idx=16] v0=6.6389e+11 (phys), bracketing with step=1.5
#   upper bracket: 1.4937e+12
#   lower bracket: 4.4259e+11
#   level 0.678: [6.5558e+11, 1.2044e+12] (phys)
#   level 0.954: [6.5558e+11, 1.4022e+12] (phys)
# Band saved as scenario_bkg_b/bands/band_bkgb_idx016.json
# === index 20 ===
# [band idx=20] v0=7.4600e+11 (phys), bracketing with step=1.5
#   upper bracket: 1.6785e+12
#   lower bracket: 4.9733e+11
#   level 0.678: [7.0026e+11, 1.1334e+12] (phys)
#   level 0.954: [6.4900e+11, 1.3195e+12] (phys)
# Band saved as scenario_bkg_b/bands/band_bkgb_idx020.json
# === index 25 ===
# [band idx=25] v0=6.8547e+11 (phys), bracketing with step=1.5
#   upper bracket: 1.5423e+12
#   lower bracket: 4.5698e+11
#   level 0.678: [6.5996e+11, 1.0955e+12] (phys)
#   level 0.954: [6.1164e+11, 1.2124e+12] (phys)
# Band saved as scenario_bkg_b/bands/band_bkgb_idx025.json
# === index 30 ===
# [band idx=30] v0=6.3187e+11 (phys), bracketing with step=1.5
#   upper bracket: 1.4217e+12
#   lower bracket: 4.2125e+11
#   level 0.678: [6.2397e+11, 1.0624e+12] (phys)
#   level 0.954: [5.7829e+11, 1.1463e+12] (phys)
# Band saved as scenario_bkg_b/bands/band_bkgb_idx030.json
# === index 40 ===
# [band idx=40] v0=6.3234e+11 (phys), bracketing with step=1.5
#   upper bracket: 1.4228e+12
#   lower bracket: 4.2156e+11
#   level 0.678: [5.6424e+11, 9.6068e+11] (phys)
#   level 0.954: [4.8465e+11, 1.0366e+12] (phys)
# Band saved as scenario_bkg_b/bands/band_bkgb_idx040.json
# === index 50 ===
# [band idx=50] v0=6.3643e+11 (phys), bracketing with step=1.5
#   upper bracket: 1.4320e+12
#   lower bracket: 2.8286e+11
#   level 0.678: [4.8778e+11, 8.9611e+11] (phys)
#   level 0.954: [4.1898e+11, 9.6690e+11] (phys)
# Band saved as scenario_bkg_b/bands/band_bkgb_idx050.json
# === index 60 ===
# [warn] best-fit value v0=1.675e+07 is already outside the 0.954 band — check the construction.
# [band idx=60] v0=3.0056e+11 (phys), bracketing with step=1.5
#   upper bracket: 1.0144e+12
#   lower bracket: 2.0037e+11
#   level 0.678: [2.9680e+11, 7.8485e+11] (phys)
#   level 0.954: [2.9680e+11, 8.9653e+11] (phys)
# Band saved as scenario_bkg_b/bands/band_bkgb_idx060.json
# === index 70 ===
# [band idx=70] v0=2.8291e+11 (phys), bracketing with step=1.5
#   upper bracket: 9.5482e+11
#   lower bracket: 1.8861e+11
#   level 0.678: [2.7937e+11, 7.1122e+11] (phys)
#   level 0.954: [2.7238e+11, 7.8212e+11] (phys)
# Band saved as scenario_bkg_b/bands/band_bkgb_idx070.json
# === index 80 ===
# [band idx=80] v0=2.6817e+11 (phys), bracketing with step=1.5
#   upper bracket: 9.0506e+11
#   lower bracket: 1.7878e+11
#   level 0.678: [2.6481e+11, 6.3679e+11] (phys)
#   level 0.954: [2.2177e+11, 6.8709e+11] (phys)
# Band saved as scenario_bkg_b/bands/band_bkgb_idx080.json
# === index 90 ===
# [band idx=90] v0=2.3801e+11 (phys), bracketing with step=1.5
#   upper bracket: 8.0327e+11
#   lower bracket: 1.5867e+11
#   level 0.678: [2.2341e+11, 5.5453e+11] (phys)
#   level 0.954: [1.6071e+11, 5.9833e+11] (phys)
# Band saved as scenario_bkg_b/bands/band_bkgb_idx090.json
# === index 100 ===
# [band idx=100] v0=1.7974e+11 (phys), bracketing with step=1.5
#   upper bracket: 6.0664e+11
#   lower bracket: 1.1983e+11
#   level 0.678: [1.7750e+11, 4.7838e+11] (phys)
#   level 0.954: [1.3095e+11, 5.3616e+11] (phys)
# Band saved as scenario_bkg_b/bands/band_bkgb_idx100.json
# === index 110 ===
# [band idx=110] v0=2.0774e+11 (phys), bracketing with step=1.5
#   upper bracket: 4.6741e+11
#   lower bracket: 9.2327e+10
#   level 0.678: [1.4027e+11, 4.3875e+11] (phys)
#   level 0.954: [9.3512e+10, 4.6156e+11] (phys)
# Band saved as scenario_bkg_b/bands/band_bkgb_idx110.json
# === index 120 ===
# [band idx=120] v0=1.2517e+11 (phys), bracketing with step=1.5
#   upper bracket: 4.2243e+11
#   lower bracket: 5.5629e+10
#   level 0.678: [9.1190e+10, 3.8052e+11] (phys)
#   level 0.954: [5.6343e+10, 4.1846e+11] (phys)
# Band saved as scenario_bkg_b/bands/band_bkgb_idx120.json
# === index 130 ===
# [band idx=130] v0=1.7643e+11 (phys), bracketing with step=1.5
#   upper bracket: 3.9698e+11
#   lower bracket: 2.3234e+10
#   level 0.678: [5.0090e+10, 3.3672e+11] (phys)
#   level 0.954: [2.3420e+10, 3.9201e+11] (phys)
# Band saved as scenario_bkg_b/bands/band_bkgb_idx130.json
# === index 140 ===
# [band idx=140] v0=2.1870e+10 (phys), bracketing with step=1.5
#   upper bracket: 3.7366e+11
#   lower edge reaches 0 / unbounded below
#   level 0.678: [0.0000e+00, 2.8958e+11] (phys)
#   level 0.954: [0.0000e+00, 3.3820e+11] (phys)
# Band saved as scenario_bkg_b/bands/band_bkgb_idx140.json
# === index 150 ===
# [band idx=150] v0=9.5643e+09 (phys), bracketing with step=1.5
#   upper bracket: 3.6768e+11
#   lower edge reaches 0 / unbounded below
#   level 0.678: [0.0000e+00, 2.3638e+11] (phys)
#   level 0.954: [0.0000e+00, 2.6493e+11] (phys)
# Band saved as scenario_bkg_b/bands/band_bkgb_idx150.json
# === index 160 ===
# [band idx=160] v0=2.5727e+10 (phys), bracketing with step=1.5
#   upper bracket: 2.9305e+11
#   lower edge reaches 0 / unbounded below
#   level 0.678: [0.0000e+00, 1.8396e+11] (phys)
#   level 0.954: [0.0000e+00, 2.1417e+11] (phys)
# Band saved as scenario_bkg_b/bands/band_bkgb_idx160.json
# === index 167 ===
# [band idx=167] v0=5.2269e+10 (phys), bracketing with step=1.5
#   upper bracket: 1.7641e+11
#   lower edge reaches 0 / unbounded below
#   level 0.678: [0.0000e+00, 1.4450e+11] (phys)
#   level 0.954: [0.0000e+00, 1.7475e+11] (phys)
# Band saved as scenario_bkg_b/bands/band_bkgb_idx167.json

# %%
# 保存したバンドを読み込んで optimize 結果の上に重ねる
# band_files はグロブパターンでも、明示的なリストでもよい
a.plot_flux_with_bands(
    f'scenario_bkg_b/bands/band_bkg{a.background_scenario}_idx*.json',
    levels=(0.678, 0.954),   # 表示するレベル (省略すると保存済み全レベル)
    save=True,
    ylim=(0, 3e13),                # 高フラックス側の裾まで見えるように
)
import matplotlib.pyplot as plt
#plt.yscale('log')
plt.ylim(0, 2e12)
plt.show()
# Out:
# Plot saved as scenario_bkg_b/flux_with_bands_bkg_b.pdf

# %%
# 保存したバンドを読み込んで optimize 結果の上に重ねる
# band_files はグロブパターンでも、明示的なリストでもよい
a.plot_flux_with_bands(
    f'scenario_bkg_b/bands/band_bkg{a.background_scenario}_idx*.json',
    levels=(0.678, 0.954),   # 表示するレベル (省略すると保存済み全レベル)
    save=True,
    ylim=(0, 3e13),                # 高フラックス側の裾まで見えるように
)
import matplotlib.pyplot as plt
plt.yscale('log')
plt.ylim(1e11, 1e14)
plt.show()
# Out:
# Plot saved as scenario_bkg_b/flux_with_bands_bkg_b.pdf
