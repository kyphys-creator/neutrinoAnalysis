# %% [markdown]
# # Confidence-band root finder (`find_confidence_band`)
#
# Example: instead of a uniform grid, locate the band edges directly by bracketing + geometric bisection.
# Bracket the outer reach with the widest level (2σ); the narrower 1σ / 90% / 2σ edges nest inside that interval.
#
# - `num_pseudo_data`: pseudo-data sample size during bracketing (can be coarse)
# - `n_pseudo_edge`: pseudo-data sample size for the edge bisection (larger suppresses cutoff noise)
# - `seed`: fixed value makes every evaluation reproducible and stops the bisection from jittering

# %%
from neutrino_analysis_band import NeutrinoAnalysis

# %%
a = NeutrinoAnalysis(background_scenario='flat', intervals='180',
                     GeV=0.003e16, solver='osqp', T=300)
a.optimize(a.data_vector)   # Compute the best fit first (populates self.result)
result_b = a.optimize(a.data_vector)
print("\nOptimization Complete.")
print(f"Minimum chi-squared: {result_b.fun / a.c}")
# 3. Plot the primary result: the optimized flux vs. theory.
a.plot_flux_comparison(save = True)
# Out:
# Optimization Complete.
# Minimum chi-squared: 9.16380365213297e-23
# Plot saved as T300/scenario_bkg_flat/flux_comparison_bkg_flat.pdf

# %% [markdown]
# ## Save bands for several indices and overlay them
#
# 1. Run `find_and_save_band` per index and save one JSON file per index under `bands/`.
# 2. Load the saved files with `plot_flux_with_bands` and overlay each index's band as an error bar on top of the `optimize` flux scatter.
#
# `save_band` / `load_band` use a human-readable JSON format. The band centre is the saved `self.result.x[index]`, so it lines up exactly with the scatter from the same `optimize` result.

# %%
# Saved automatically under the T-prefixed folder (outdir can be omitted)
# → T3/scenario_bkg_flat/bands/band_bkgflat_idx000.json

# Build bands for several indices and save one file per index
# Destination: ./bands/band_bkg<scenario>_idx<NNN>.json
indices = [0, 1, 2, 3, 4, 5, 8, 13, 16, 20, 25, 30, 40, 50, 60, 70, 80, 90, 100, 110, 120, 130, 140, 150, 160, 167]     # Indices to run

for idx in indices:
    print(f'=== index {idx} ===')
    a.find_and_save_band(
        idx,
        outdir='T300/scenario_bkg_flat/bands',
        levels=(0.678, 0.954),
        num_pseudo_data=50,
        n_pseudo_edge=500,
        step=1.5,
        rel_tol=0.03,
        seed=42,
        n_jobs=1,
        verbose=True,
    )
# Out:
# === index 0 ===
# [band idx=0] v0=1.2284e+12 (phys), bracketing with step=1.5
#   upper bracket: 4.7223e+13
#   lower bracket: 8.1892e+11
#   level 0.678: [1.2130e+12, 3.3070e+13] (phys)
#   level 0.954: [1.2130e+12, 3.9239e+13] (phys)
# Band saved as T300/scenario_bkg_flat/bands/band_bkgflat_idx000.json
# === index 1 ===
# [band idx=1] v0=1.2284e+12 (phys), bracketing with step=1.5
#   upper bracket: 2.0988e+13
#   lower bracket: 8.1892e+11
#   level 0.678: [1.0687e+12, 1.5218e+13] (phys)
#   level 0.954: [1.0419e+12, 1.7774e+13] (phys)
# Band saved as T300/scenario_bkg_flat/bands/band_bkgflat_idx001.json
# === index 2 ===
# [band idx=2] v0=1.2284e+12 (phys), bracketing with step=1.5
#   upper bracket: 1.3992e+13
#   lower bracket: 8.1892e+11
#   level 0.678: [1.0687e+12, 9.2989e+12] (phys)
#   level 0.954: [1.0419e+12, 1.0826e+13] (phys)
# Band saved as T300/scenario_bkg_flat/bands/band_bkgflat_idx002.json
# === index 3 ===
# [band idx=3] v0=1.2284e+12 (phys), bracketing with step=1.5
#   upper bracket: 9.3280e+12
#   lower bracket: 8.1892e+11
#   level 0.678: [1.0687e+12, 6.4292e+12] (phys)
#   level 0.954: [1.0419e+12, 7.4142e+12] (phys)
# Band saved as T300/scenario_bkg_flat/bands/band_bkgflat_idx003.json
# === index 4 ===
# [band idx=4] v0=1.2284e+12 (phys), bracketing with step=1.5
#   upper bracket: 6.2187e+12
#   lower bracket: 8.1892e+11
#   level 0.678: [1.0687e+12, 4.8885e+12] (phys)
#   level 0.954: [1.0419e+12, 5.5489e+12] (phys)
# Band saved as T300/scenario_bkg_flat/bands/band_bkgflat_idx004.json
# === index 5 ===
# [band idx=5] v0=1.2284e+12 (phys), bracketing with step=1.5
#   upper bracket: 6.2187e+12
#   lower bracket: 8.1892e+11
#   level 0.678: [1.0687e+12, 3.8916e+12] (phys)
#   level 0.954: [1.0419e+12, 4.3068e+12] (phys)
# Band saved as T300/scenario_bkg_flat/bands/band_bkgflat_idx005.json
# === index 8 ===
# [band idx=8] v0=1.2284e+12 (phys), bracketing with step=1.5
#   upper bracket: 2.7639e+12
#   lower bracket: 8.1892e+11
#   level 0.678: [1.0687e+12, 2.3443e+12] (phys)
#   level 0.954: [1.0419e+12, 2.5944e+12] (phys)
# Band saved as T300/scenario_bkg_flat/bands/band_bkgflat_idx008.json
# === index 13 ===
# [band idx=13] v0=1.2284e+12 (phys), bracketing with step=1.5
#   upper bracket: 1.8426e+12
#   lower bracket: 8.1892e+11
#   level 0.678: [1.0687e+12, 1.5629e+12] (phys)
#   level 0.954: [1.0419e+12, 1.6441e+12] (phys)
# Band saved as T300/scenario_bkg_flat/bands/band_bkgflat_idx013.json
# === index 16 ===
# [band idx=16] v0=1.2284e+12 (phys), bracketing with step=1.5
#   upper bracket: 1.8426e+12
#   lower bracket: 8.1892e+11
#   level 0.678: [1.0687e+12, 1.3769e+12] (phys)
#   level 0.954: [1.0419e+12, 1.4122e+12] (phys)
# Band saved as T300/scenario_bkg_flat/bands/band_bkgflat_idx016.json
# === index 20 ===
# [band idx=20] v0=1.2284e+12 (phys), bracketing with step=1.5
#   upper bracket: 1.8426e+12
#   lower bracket: 8.1892e+11
#   level 0.678: [1.0419e+12, 1.2761e+12] (phys)
#   level 0.954: [1.0158e+12, 1.3088e+12] (phys)
# Band saved as T300/scenario_bkg_flat/bands/band_bkgflat_idx020.json
# === index 25 ===
# [band idx=25] v0=1.1294e+12 (phys), bracketing with step=1.5
#   upper bracket: 1.6941e+12
#   lower bracket: 7.5292e+11
#   level 0.678: [9.8253e+11, 1.2342e+12] (phys)
#   level 0.954: [9.5795e+11, 1.2342e+12] (phys)
# Band saved as T300/scenario_bkg_flat/bands/band_bkgflat_idx025.json
# === index 30 ===
# [band idx=30] v0=9.8565e+11 (phys), bracketing with step=1.5
#   upper bracket: 1.4785e+12
#   lower bracket: 6.5710e+11
#   level 0.678: [9.4896e+11, 1.1048e+12] (phys)
#   level 0.954: [9.2521e+11, 1.1332e+12] (phys)
# Band saved as T300/scenario_bkg_flat/bands/band_bkgflat_idx030.json
# === index 40 ===
# [band idx=40] v0=9.6237e+11 (phys), bracketing with step=1.5
#   upper bracket: 1.4436e+12
#   lower bracket: 6.4158e+11
#   level 0.678: [8.3723e+11, 9.9974e+11] (phys)
#   level 0.954: [8.1628e+11, 1.0254e+12] (phys)
# Band saved as T300/scenario_bkg_flat/bands/band_bkgflat_idx040.json
# === index 50 ===
# [band idx=50] v0=8.6298e+11 (phys), bracketing with step=1.5
#   upper bracket: 1.2945e+12
#   lower bracket: 5.7532e+11
#   level 0.678: [7.5077e+11, 8.9649e+11] (phys)
#   level 0.954: [7.3198e+11, 9.1950e+11] (phys)
# Band saved as T300/scenario_bkg_flat/bands/band_bkgflat_idx050.json
# === index 60 ===
# [band idx=60] v0=7.6268e+11 (phys), bracketing with step=1.5
#   upper bracket: 1.1440e+12
#   lower bracket: 5.0845e+11
#   level 0.678: [6.6350e+11, 8.1262e+11] (phys)
#   level 0.954: [6.4690e+11, 8.3348e+11] (phys)
# Band saved as T300/scenario_bkg_flat/bands/band_bkgflat_idx060.json
# === index 70 ===
# [band idx=70] v0=6.4580e+11 (phys), bracketing with step=1.5
#   upper bracket: 9.6870e+11
#   lower bracket: 4.3054e+11
#   level 0.678: [5.7625e+11, 7.0576e+11] (phys)
#   level 0.954: [5.4777e+11, 7.4245e+11] (phys)
# Band saved as T300/scenario_bkg_flat/bands/band_bkgflat_idx070.json
# === index 80 ===
# [band idx=80] v0=5.5834e+11 (phys), bracketing with step=1.5
#   upper bracket: 8.3752e+11
#   lower bracket: 3.7223e+11
#   level 0.678: [4.8574e+11, 6.2584e+11] (phys)
#   level 0.954: [4.6174e+11, 6.4190e+11] (phys)
# Band saved as T300/scenario_bkg_flat/bands/band_bkgflat_idx080.json
# === index 90 ===
# [band idx=90] v0=4.7435e+11 (phys), bracketing with step=1.5
#   upper bracket: 7.1152e+11
#   lower bracket: 3.1623e+11
#   level 0.678: [4.0234e+11, 5.3169e+11] (phys)
#   level 0.954: [3.8246e+11, 5.5933e+11] (phys)
# Band saved as T300/scenario_bkg_flat/bands/band_bkgflat_idx090.json
# === index 100 ===
# [band idx=100] v0=3.8514e+11 (phys), bracketing with step=1.5
#   upper bracket: 5.7771e+11
#   lower bracket: 2.5676e+11
#   level 0.678: [3.2668e+11, 4.5414e+11] (phys)
#   level 0.954: [3.1053e+11, 4.6580e+11] (phys)
# Band saved as T300/scenario_bkg_flat/bands/band_bkgflat_idx100.json
# === index 110 ===
# [band idx=110] v0=3.3050e+11 (phys), bracketing with step=1.5
#   upper bracket: 4.9576e+11
#   lower bracket: 2.2034e+11
#   level 0.678: [2.7332e+11, 3.7046e+11] (phys)
#   level 0.954: [2.5331e+11, 3.8972e+11] (phys)
# Band saved as T300/scenario_bkg_flat/bands/band_bkgflat_idx110.json
# === index 120 ===
# [band idx=120] v0=2.5935e+11 (phys), bracketing with step=1.5
#   upper bracket: 3.8903e+11
#   lower bracket: 1.7290e+11
#   level 0.678: [2.1448e+11, 3.2171e+11] (phys)
#   level 0.954: [1.9878e+11, 3.2997e+11] (phys)
# Band saved as T300/scenario_bkg_flat/bands/band_bkgflat_idx120.json
# === index 130 ===
# [band idx=130] v0=2.0936e+11 (phys), bracketing with step=1.5
#   upper bracket: 3.1404e+11
#   lower bracket: 1.3957e+11
#   level 0.678: [1.6458e+11, 2.5970e+11] (phys)
#   level 0.954: [1.5253e+11, 2.7321e+11] (phys)
# Band saved as T300/scenario_bkg_flat/bands/band_bkgflat_idx130.json
# === index 140 ===
# [band idx=140] v0=1.1751e+11 (phys), bracketing with step=1.5
#   upper bracket: 2.6440e+11
#   lower bracket: 7.8342e+10
#   level 0.678: [1.0755e+11, 2.0785e+11] (phys)
#   level 0.954: [1.0223e+11, 2.2427e+11] (phys)
# Band saved as T300/scenario_bkg_flat/bands/band_bkgflat_idx140.json
# === index 150 ===
# [band idx=150] v0=1.1751e+11 (phys), bracketing with step=1.5
#   upper bracket: 2.6440e+11
#   lower bracket: 3.4819e+10
#   level 0.678: [4.0155e+10, 1.8781e+11] (phys)
#   level 0.954: [3.6515e+10, 1.9758e+11] (phys)
# Band saved as T300/scenario_bkg_flat/bands/band_bkgflat_idx150.json
# === index 160 ===
# [band idx=160] v0=1.1751e+11 (phys), bracketing with step=1.5
#   upper bracket: 1.7627e+11
#   lower bracket: 1.5475e+10
#   level 0.678: [2.1412e+10, 1.3172e+11] (phys)
#   level 0.954: [1.6619e+10, 1.4212e+11] (phys)
# Band saved as T300/scenario_bkg_flat/bands/band_bkgflat_idx160.json
# === index 167 ===
# [band idx=167] v0=0.0000e+00 (phys), bracketing with step=1.5
#   upper edge unbounded (still inside at max_bracket)
#   lower edge reaches 0 / unbounded below
#   level 0.678: [0.0000e+00, inf] (phys)
#   level 0.954: [0.0000e+00, inf] (phys)
# Band saved as T300/scenario_bkg_flat/bands/band_bkgflat_idx167.json

# %%
# Load the saved bands and overlay them on the optimize result
# band_files can be a glob pattern or an explicit list
a.plot_flux_with_bands(
    f'T300/scenario_bkg_flat/bands/band_bkg{a.background_scenario}_idx*.json',
    levels=(0.678, 0.954),   # Levels to plot (omit to show all saved levels)
    save=True,
    ylim=(0, 3e13),                # So the high-flux tail is visible
)
import matplotlib.pyplot as plt
#plt.yscale('log')
plt.ylim(0, 2e12)
plt.show()
# Out:
# Plot saved as T300/scenario_bkg_flat/flux_with_bands_bkg_flat.pdf

# %%
# Load the saved bands and overlay them on the optimize result
# band_files can be a glob pattern or an explicit list
a.plot_flux_with_bands(
    f'T300/scenario_bkg_flat/bands/band_bkg{a.background_scenario}_idx*.json',
    levels=(0.678, 0.954),   # Levels to plot (omit to show all saved levels)
    save=True,
    ylim=(0, 3e13),                # So the high-flux tail is visible
)
import matplotlib.pyplot as plt
plt.yscale('log')
plt.ylim(1e11, 1e14)
plt.show()
# Out:
# Plot saved as T300/scenario_bkg_flat/flux_with_bands_bkg_flat.pdf
