# %% [markdown]
# # Confidence-band root finder (`find_confidence_band`)
#
# Example: instead of a uniform grid, locate the band edges directly by bracketing + geometric bisection.
# Bracket the outer reach with the widest level (2σ); the narrower 1σ / 90% / 2σ edges nest inside that interval.
#
# - `num_pseudo_data`: pseudo-data sample size during bracketing (can be coarse)
# - `n_pseudo_edge`: pseudo-data sample size for the edge bisection (larger suppresses cutoff noise)
# - `seed`: fixed value makes every evaluation reproducible and stops the bisection from jittering

# %%
from neutrino_analysis_band import NeutrinoAnalysis

# %%
a = NeutrinoAnalysis(background_scenario='flat', intervals='180',
                     GeV=0.01e16, solver='osqp', T=300)
a.optimize(a.data_vector)   # Compute the best fit first (populates self.result)
result_b = a.optimize(a.data_vector)
print("\nOptimization Complete.")
print(f"Minimum chi-squared: {result_b.fun / a.c}")
# 3. Plot the primary result: the optimized flux vs. theory.
a.plot_flux_comparison(save = True)
# Out:
# Optimization Complete.
# Minimum chi-squared: 2.604866125200661e-17
# Plot saved as T300/scenario_bkg_flat/flux_comparison_bkg_flat.pdf

# %% [markdown]
# ## Save bands for several indices and overlay them
#
# 1. Run `find_and_save_band` per index and save one JSON file per index under `bands/`.
# 2. Load the saved files with `plot_flux_with_bands` and overlay each index's band as an error bar on top of the `optimize` flux scatter.
#
# `save_band` / `load_band` use a human-readable JSON format. The band centre is the saved `self.result.x[index]`, so it lines up exactly with the scatter from the same `optimize` result.

# %%
# Saved automatically under the T-prefixed folder (outdir can be omitted)
# → T3/scenario_bkg_flat/bands/band_bkgflat_idx000.json

# Build bands for several indices and save one file per index
# Destination: ./bands/band_bkg<scenario>_idx<NNN>.json
indices = [0, 1, 2, 3, 4, 5, 8, 13, 16, 20, 25, 30, 40, 50, 60, 70, 80, 90, 100, 110, 120, 130, 140, 150, 160, 167]     # Indices to run

for idx in indices:
    print(f'=== index {idx} ===')
    a.find_and_save_band(
        idx,
        outdir='T300/scenario_bkg_flat/bands',
        levels=(0.678, 0.954),
        num_pseudo_data=50,
        n_pseudo_edge=500,
        step=1.5,
        rel_tol=0.03,
        seed=42,
        n_jobs=1,
        verbose=True,
    )
# Out:
# === index 0 ===
# [band idx=0] v0=1.2284e+12 (phys), bracketing with step=1.5
#   upper bracket: 4.7223e+13
#   lower bracket: 8.1892e+11
#   level 0.678: [1.2130e+12, 3.3070e+13] (phys)
#   level 0.954: [1.2130e+12, 3.9239e+13] (phys)
# Band saved as T300/scenario_bkg_flat/bands/band_bkgflat_idx000.json
# === index 1 ===
# [band idx=1] v0=1.3694e+12 (phys), bracketing with step=1.5
#   upper bracket: 2.3398e+13
#   lower bracket: 9.1294e+11
#   level 0.678: [1.0765e+12, 1.5185e+13] (phys)
#   level 0.954: [1.0496e+12, 1.7735e+13] (phys)
# Band saved as T300/scenario_bkg_flat/bands/band_bkgflat_idx001.json
# === index 2 ===
# [band idx=2] v0=1.3512e+12 (phys), bracketing with step=1.5
#   upper bracket: 1.5391e+13
#   lower bracket: 9.0081e+11
#   level 0.678: [1.0622e+12, 9.3015e+12] (phys)
#   level 0.954: [1.0356e+12, 1.0829e+13] (phys)
# Band saved as T300/scenario_bkg_flat/bands/band_bkgflat_idx002.json
# === index 3 ===
# [band idx=3] v0=1.3291e+12 (phys), bracketing with step=1.5
#   upper bracket: 1.0093e+13
#   lower bracket: 8.8605e+11
#   level 0.678: [1.0716e+12, 6.4266e+12] (phys)
#   level 0.954: [1.0448e+12, 7.4112e+12] (phys)
# Band saved as T300/scenario_bkg_flat/bands/band_bkgflat_idx003.json
# === index 4 ===
# [band idx=4] v0=1.3068e+12 (phys), bracketing with step=1.5
#   upper bracket: 6.6155e+12
#   lower bracket: 8.7117e+11
#   level 0.678: [1.0536e+12, 4.8197e+12] (phys)
#   level 0.954: [1.0273e+12, 5.4708e+12] (phys)
# Band saved as T300/scenario_bkg_flat/bands/band_bkgflat_idx004.json
# === index 5 ===
# [band idx=5] v0=1.2884e+12 (phys), bracketing with step=1.5
#   upper bracket: 4.3482e+12
#   lower bracket: 8.5890e+11
#   level 0.678: [1.0654e+12, 3.8431e+12] (phys)
#   level 0.954: [1.0388e+12, 4.3073e+12] (phys)
# Band saved as T300/scenario_bkg_flat/bands/band_bkgflat_idx005.json
# === index 8 ===
# [band idx=8] v0=1.2578e+12 (phys), bracketing with step=1.5
#   upper bracket: 2.8300e+12
#   lower bracket: 8.3853e+11
#   level 0.678: [1.0669e+12, 2.4004e+12] (phys)
#   level 0.954: [1.0402e+12, 2.5900e+12] (phys)
# Band saved as T300/scenario_bkg_flat/bands/band_bkgflat_idx008.json
# === index 13 ===
# [band idx=13] v0=1.2367e+12 (phys), bracketing with step=1.5
#   upper bracket: 1.8551e+12
#   lower bracket: 8.2449e+11
#   level 0.678: [1.0759e+12, 1.5735e+12] (phys)
#   level 0.954: [1.0490e+12, 1.6139e+12] (phys)
# Band saved as T300/scenario_bkg_flat/bands/band_bkgflat_idx013.json
# === index 16 ===
# [band idx=16] v0=1.2287e+12 (phys), bracketing with step=1.5
#   upper bracket: 1.8431e+12
#   lower bracket: 8.1914e+11
#   level 0.678: [1.0689e+12, 1.3772e+12] (phys)
#   level 0.954: [1.0422e+12, 1.4126e+12] (phys)
# Band saved as T300/scenario_bkg_flat/bands/band_bkgflat_idx016.json
# === index 20 ===
# [band idx=20] v0=1.2052e+12 (phys), bracketing with step=1.5
#   upper bracket: 1.8077e+12
#   lower bracket: 8.0344e+11
#   level 0.678: [1.0484e+12, 1.2841e+12] (phys)
#   level 0.954: [1.0222e+12, 1.2841e+12] (phys)
# Band saved as T300/scenario_bkg_flat/bands/band_bkgflat_idx020.json
# === index 25 ===
# [band idx=25] v0=1.0896e+12 (phys), bracketing with step=1.5
#   upper bracket: 1.6343e+12
#   lower bracket: 7.2638e+11
#   level 0.678: [9.7221e+11, 1.2526e+12] (phys)
#   level 0.954: [9.7221e+11, 1.2526e+12] (phys)
# Band saved as T300/scenario_bkg_flat/bands/band_bkgflat_idx025.json
# === index 30 ===
# [band idx=30] v0=1.0071e+12 (phys), bracketing with step=1.5
#   upper bracket: 1.5107e+12
#   lower bracket: 6.7142e+11
#   level 0.678: [9.4538e+11, 1.1006e+12] (phys)
#   level 0.954: [9.2172e+11, 1.1289e+12] (phys)
# Band saved as T300/scenario_bkg_flat/bands/band_bkgflat_idx030.json
# === index 40 ===
# [band idx=40] v0=9.1974e+11 (phys), bracketing with step=1.5
#   upper bracket: 1.3796e+12
#   lower bracket: 6.1316e+11
#   level 0.678: [8.4174e+11, 1.0051e+12] (phys)
#   level 0.954: [8.2068e+11, 1.0309e+12] (phys)
# Band saved as T300/scenario_bkg_flat/bands/band_bkgflat_idx040.json
# === index 50 ===
# [band idx=50] v0=8.2845e+11 (phys), bracketing with step=1.5
#   upper bracket: 1.2427e+12
#   lower bracket: 5.5230e+11
#   level 0.678: [7.5819e+11, 9.0536e+11] (phys)
#   level 0.954: [7.3922e+11, 9.2859e+11] (phys)
# Band saved as T300/scenario_bkg_flat/bands/band_bkgflat_idx050.json
# === index 60 ===
# [band idx=60] v0=7.3287e+11 (phys), bracketing with step=1.5
#   upper bracket: 1.0993e+12
#   lower bracket: 4.8858e+11
#   level 0.678: [6.7072e+11, 8.0091e+11] (phys)
#   level 0.954: [6.3757e+11, 8.2146e+11] (phys)
# Band saved as T300/scenario_bkg_flat/bands/band_bkgflat_idx060.json
# === index 70 ===
# [band idx=70] v0=6.4236e+11 (phys), bracketing with step=1.5
#   upper bracket: 9.6354e+11
#   lower bracket: 4.2824e+11
#   level 0.678: [5.7318e+11, 7.2001e+11] (phys)
#   level 0.954: [5.5883e+11, 7.3849e+11] (phys)
# Band saved as T300/scenario_bkg_flat/bands/band_bkgflat_idx070.json
# === index 80 ===
# [band idx=80] v0=5.5353e+11 (phys), bracketing with step=1.5
#   upper bracket: 8.3030e+11
#   lower bracket: 3.6902e+11
#   level 0.678: [4.8155e+11, 6.2044e+11] (phys)
#   level 0.954: [4.6950e+11, 6.3637e+11] (phys)
# Band saved as T300/scenario_bkg_flat/bands/band_bkgflat_idx080.json
# === index 90 ===
# [band idx=90] v0=4.6575e+11 (phys), bracketing with step=1.5
#   upper bracket: 6.9863e+11
#   lower bracket: 3.1050e+11
#   level 0.678: [4.0519e+11, 5.3546e+11] (phys)
#   level 0.954: [3.8517e+11, 5.4920e+11] (phys)
# Band saved as T300/scenario_bkg_flat/bands/band_bkgflat_idx090.json
# === index 100 ===
# [band idx=100] v0=3.8730e+11 (phys), bracketing with step=1.5
#   upper bracket: 5.8095e+11
#   lower bracket: 2.5820e+11
#   level 0.678: [3.2851e+11, 4.4526e+11] (phys)
#   level 0.954: [3.1227e+11, 4.6841e+11] (phys)
# Band saved as T300/scenario_bkg_flat/bands/band_bkgflat_idx100.json
# === index 110 ===
# [band idx=110] v0=3.2208e+11 (phys), bracketing with step=1.5
#   upper bracket: 4.8312e+11
#   lower bracket: 2.1472e+11
#   level 0.678: [2.7319e+11, 3.7028e+11] (phys)
#   level 0.954: [2.5319e+11, 3.8953e+11] (phys)
# Band saved as T300/scenario_bkg_flat/bands/band_bkgflat_idx110.json
# === index 120 ===
# [band idx=120] v0=2.6324e+11 (phys), bracketing with step=1.5
#   upper bracket: 3.9487e+11
#   lower bracket: 1.7550e+11
#   level 0.678: [2.1225e+11, 3.1837e+11] (phys)
#   level 0.954: [2.0176e+11, 3.3493e+11] (phys)
# Band saved as T300/scenario_bkg_flat/bands/band_bkgflat_idx120.json
# === index 130 ===
# [band idx=130] v0=2.1298e+11 (phys), bracketing with step=1.5
#   upper bracket: 3.1948e+11
#   lower bracket: 1.4199e+11
#   level 0.678: [1.6743e+11, 2.6420e+11] (phys)
#   level 0.954: [1.5129e+11, 2.7098e+11] (phys)
# Band saved as T300/scenario_bkg_flat/bands/band_bkgflat_idx130.json
# === index 140 ===
# [band idx=140] v0=1.6902e+11 (phys), bracketing with step=1.5
#   upper bracket: 2.5353e+11
#   lower bracket: 7.5121e+10
#   level 0.678: [1.0849e+11, 2.0967e+11] (phys)
#   level 0.954: [1.0055e+11, 2.2057e+11] (phys)
# Band saved as T300/scenario_bkg_flat/bands/band_bkgflat_idx140.json
# === index 150 ===
# [band idx=150] v0=1.2249e+11 (phys), bracketing with step=1.5
#   upper bracket: 2.7561e+11
#   lower bracket: 3.6294e+10
#   level 0.678: [3.9537e+10, 1.9087e+11] (phys)
#   level 0.954: [3.6643e+10, 1.9577e+11] (phys)
# Band saved as T300/scenario_bkg_flat/bands/band_bkgflat_idx150.json
# === index 160 ===
# [band idx=160] v0=6.6027e+10 (phys), bracketing with step=1.5
#   upper bracket: 1.4856e+11
#   lower bracket: 1.3042e+10
#   level 0.678: [2.1380e+10, 1.3256e+11] (phys)
#   level 0.954: [1.6594e+10, 1.4303e+11] (phys)
# Band saved as T300/scenario_bkg_flat/bands/band_bkgflat_idx160.json
# === index 167 ===
# [band idx=167] v0=3.9484e+10 (phys), bracketing with step=1.5
#   upper bracket: 1.3326e+11
#   lower edge reaches 0 / unbounded below
#   level 0.678: [0.0000e+00, 1.0310e+11] (phys)
#   level 0.954: [0.0000e+00, 1.1338e+11] (phys)
# Band saved as T300/scenario_bkg_flat/bands/band_bkgflat_idx167.json

# %%
# Load the saved bands and overlay them on the optimize result
# band_files can be a glob pattern or an explicit list
a.plot_flux_with_bands(
    f'T300/scenario_bkg_flat/bands/band_bkg{a.background_scenario}_idx*.json',
    levels=(0.678, 0.954),   # Levels to plot (omit to show all saved levels)
    save=True,
    ylim=(0, 3e13),                # So the high-flux tail is visible
)
import matplotlib.pyplot as plt
#plt.yscale('log')
plt.ylim(0, 2e12)
plt.show()
# Out:
# Plot saved as T300/scenario_bkg_flat/flux_with_bands_bkg_flat.pdf

# %%
# Load the saved bands and overlay them on the optimize result
# band_files can be a glob pattern or an explicit list
a.plot_flux_with_bands(
    f'T300/scenario_bkg_flat/bands/band_bkg{a.background_scenario}_idx*.json',
    levels=(0.678, 0.954),   # Levels to plot (omit to show all saved levels)
    save=True,
    ylim=(0, 3e13),                # So the high-flux tail is visible
)
import matplotlib.pyplot as plt
plt.yscale('log')
plt.ylim(1e11, 1e14)
plt.show()
# Out:
# Plot saved as T300/scenario_bkg_flat/flux_with_bands_bkg_flat.pdf
