# %%
from neutrino_analysis_band import NeutrinoAnalysis

# %%
# Run optimize() on each scenario first
a_flat = NeutrinoAnalysis(background_scenario='flat', intervals='180', GeV=0.32e16, solver='scipy', T=300)
a_flat.optimize(a_flat.data_vector)
# Out:
#            message: `xtol` termination condition is satisfied.
#            success: True
#             status: 2
#                fun: 7.187017236184457e+67
#                  x: [ 1.092e+07  1.092e+07 ...  2.664e+05  2.664e+05]
#                nit: 16787
#               nfev: 16887
#               njev: 16517
#               nhev: 16517
#           cg_niter: 2946605
#       cg_stop_cond: 2
#               grad: [ 1.354e+56  1.757e+56 ... -1.651e+55 -1.687e+55]
#    lagrangian_grad: [-1.156e+54 -1.156e+54 ... -1.302e+55 -1.302e+55]
#             constr: [array([ 1.267e-07,  3.353e-08, ...,  0.000e+00,
#                             0.000e+00], shape=(179,)), array([ 1.092e+07,  1.092e+07, ...,  2.664e+05,
#                             2.664e+05], shape=(180,))]
#                jac: [<Compressed Sparse Row sparse array of dtype 'float64'
#                     	with 358 stored elements and shape (179, 180)>, <Compressed Sparse Row sparse array of dtype 'float64'
#                     	with 180 stored elements and shape (180, 180)>]
#        constr_nfev: [0, 0]
#        constr_njev: [0, 0]
#        constr_nhev: [0, 0]
#                  v: [array([-1.366e+56, -3.134e+56, ..., -7.342e+54,
#                            -3.854e+54], shape=(179,)), array([ 9.692e+39,  9.692e+39, ...,  1.835e+44,
#                             1.835e+44], shape=(180,))]
#             method: tr_interior_point
#         optimality: 4.017384644757663e+55
#   constr_violation: 0.0
#     execution_time: 177.83298897743225
#          tr_radius: 5.000000000000002e-10
#     constr_penalty: 1.0
#  barrier_parameter: 2.048000000000001e-09
#  barrier_tolerance: 2.048000000000001e-09
#              niter: 16787

# %%
a_flat.plot_band_comparison(
    {r'Flat Bkg 1$\sigma$ CL':    'T300/scenario_bkg_flat/bands/band_*.json',},
    level=0.678,
    optimized={'Flat Bkg': a_flat},   # Overlay each scenario's optimize result
    ylim=(0, 2e12), save=True,
    fname='band_comparison_T300_1sigma_edge.pdf',
    logy = False
)
# Out:
# Plot saved as band_comparison_T300_1sigma_edge.pdf

# %%
a_flat.plot_band_comparison(
    {r'Flat Bkg 1$\sigma$ CL':    'T300/scenario_bkg_flat/bands/band_*.json',},
    level=0.678,
    optimized={'Flat Bkg': a_flat},   # Overlay each scenario's optimize result
    ylim=(1e11, 3e13), save=True,
    fname='band_comparison_T300_1sigma_edge.pdf',
    logy = True
)
# Out:
# Plot saved as band_comparison_T300_1sigma_edge.pdf

# %%
a_flat.plot_band_comparison(
    {r'Flat Bkg 2$\sigma$ CL':    'T300/scenario_bkg_flat/bands/band_*.json',},
    level=0.954,
    optimized={'Flat Bkg': a_flat},   # Overlay each scenario's optimize result
    ylim=(0, 2e12), save=True,
    fname='band_comparison_T300_2sigma_edge.pdf',
    logy = False
)
# Out:
# Plot saved as band_comparison_T300_2sigma_edge.pdf

# %%
a_flat.plot_band_comparison(
    {r'Flat Bkg 2$\sigma$ CL':    'T300/scenario_bkg_flat/bands/band_*.json',},
    level=0.954,
    optimized={'Flat Bkg': a_flat},   # Overlay each scenario's optimize result
    ylim=(1e11, 3e13), save=True,
    fname='band_comparison_T300_2sigma_edge.pdf',
    logy = True
)
# Out:
# Plot saved as band_comparison_T300_2sigma_edge.pdf

# %%
# Load the saved bands and overlay them on the optimize result
# band_files can be a glob pattern or an explicit list
a_flat.plot_flux_with_bands(
    f'T300/scenario_bkg_flat/bands/band_bkg{a_flat.background_scenario}_idx*.json',
    levels=(0.678, 0.954),   # Levels to plot (omit to show all saved levels)
    save=True,
    ylim=(0, 3e13),                # So the high-flux tail is visible
)
import matplotlib.pyplot as plt
plt.yscale('log')
plt.ylim(1e11, 1e14)
plt.show()
# Out:
# Plot saved as T300/scenario_bkg_flat/flux_with_bands_bkg_flat.pdf
