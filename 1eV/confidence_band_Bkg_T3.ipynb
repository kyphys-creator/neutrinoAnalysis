# %% [markdown]
# # Confidence-band root finder (`find_confidence_band`)
#
# Example: instead of a uniform grid, locate the band edges directly by bracketing + geometric bisection.
# Bracket the outer reach with the widest level (2σ); the narrower 1σ / 90% / 2σ edges nest inside that interval.
#
# - `num_pseudo_data`: pseudo-data sample size during bracketing (can be coarse)
# - `n_pseudo_edge`: pseudo-data sample size for the edge bisection (larger suppresses cutoff noise)
# - `seed`: fixed value makes every evaluation reproducible and stops the bisection from jittering

# %%
from neutrino_analysis_band import NeutrinoAnalysis

# %%
a = NeutrinoAnalysis(background_scenario='b', intervals='180',
                     GeV=0.1e16, solver='osqp', T=3)
a.optimize(a.data_vector)   # Compute the best fit first (populates self.result)
result_b = a.optimize(a.data_vector)
print("\nOptimization Complete.")
print(f"Minimum chi-squared: {result_b.fun / a.c}")
# 3. Plot the primary result: the optimized flux vs. theory.
a.plot_flux_comparison(save = True)
# Out:
# Optimization Complete.
# Minimum chi-squared: 3.4391269970638554e-12
# Plot saved as T3/scenario_bkg_b/flux_comparison_bkg_b.pdf

# %% [markdown]
# ## Save bands for several indices and overlay them
#
# 1. Run `find_and_save_band` per index and save one JSON file per index under `bands/`.
# 2. Load the saved files with `plot_flux_with_bands` and overlay each index's band as an error bar on top of the `optimize` flux scatter.
#
# `save_band` / `load_band` use a human-readable JSON format. The band centre is the saved `self.result.x[index]`, so it lines up exactly with the scatter from the same `optimize` result.

# %%
# Saved automatically under the T-prefixed folder (outdir can be omitted)
# → T3/scenario_bkg_flat/bands/band_bkgflat_idx000.json

# Build bands for several indices and save one file per index
# Destination: ./bands/band_bkg<scenario>_idx<NNN>.json
indices = [0, 1, 2, 3, 4, 5, 8, 13, 16, 20, 25, 30, 40, 50, 60, 70, 80, 90, 100, 110, 120, 130, 140, 150, 160, 167]     # Indices to run

for idx in indices:
    print(f'=== index {idx} ===')
    a.find_and_save_band(
        idx,
        outdir='T3/scenario_bkg_b/bands',
        levels=(0.678, 0.954),
        num_pseudo_data=50,
        n_pseudo_edge=500,
        step=1.5,
        rel_tol=0.03,
        seed=42,
        n_jobs=1,
        verbose=True,
        bkg_penalty=True,
    )
# Out:
# === index 0 ===
# [band idx=0] v0=1.2284e+12 (phys), bracketing with step=1.5
#   upper bracket: 1.5938e+14
#   lower bracket: 8.1892e+11
#   level 0.678: [1.0687e+12, 9.2726e+13] (phys)
#   level 0.954: [9.1792e+11, 1.4357e+14] (phys)
# Band saved as T3/scenario_bkg_b/bands/band_bkgb_idx000_bkgpen.json
# === index 1 ===
# [band idx=1] v0=1.2284e+12 (phys), bracketing with step=1.5
#   upper bracket: 7.0835e+13
#   lower bracket: 5.4595e+11
#   level 0.678: [8.9495e+11, 4.0371e+13] (phys)
#   level 0.954: [7.8844e+11, 6.2903e+13] (phys)
# Band saved as T3/scenario_bkg_b/bands/band_bkgb_idx001_bkgpen.json
# === index 2 ===
# [band idx=2] v0=1.2284e+12 (phys), bracketing with step=1.5
#   upper bracket: 4.7223e+13
#   lower bracket: 5.4595e+11
#   level 0.678: [8.9495e+11, 2.4168e+13] (phys)
#   level 0.954: [7.8844e+11, 3.7064e+13] (phys)
# Band saved as T3/scenario_bkg_b/bands/band_bkgb_idx002_bkgpen.json
# === index 3 ===
# [band idx=3] v0=1.2284e+12 (phys), bracketing with step=1.5
#   upper bracket: 3.1482e+13
#   lower bracket: 5.4595e+11
#   level 0.678: [8.9495e+11, 1.6086e+13] (phys)
#   level 0.954: [7.8844e+11, 2.4748e+13] (phys)
# Band saved as T3/scenario_bkg_b/bands/band_bkgb_idx003_bkgpen.json
# === index 4 ===
# [band idx=4] v0=1.2284e+12 (phys), bracketing with step=1.5
#   upper bracket: 2.0988e+13
#   lower bracket: 5.4595e+11
#   level 0.678: [8.9495e+11, 1.1663e+13] (phys)
#   level 0.954: [7.8844e+11, 1.7384e+13] (phys)
# Band saved as T3/scenario_bkg_b/bands/band_bkgb_idx004_bkgpen.json
# === index 5 ===
# [band idx=5] v0=1.2284e+12 (phys), bracketing with step=1.5
#   upper bracket: 1.3992e+13
#   lower bracket: 5.4595e+11
#   level 0.678: [8.9495e+11, 8.7836e+12] (phys)
#   level 0.954: [7.8844e+11, 1.3092e+13] (phys)
# Band saved as T3/scenario_bkg_b/bands/band_bkgb_idx005_bkgpen.json
# === index 8 ===
# [band idx=8] v0=1.2284e+12 (phys), bracketing with step=1.5
#   upper bracket: 6.2187e+12
#   lower bracket: 5.4595e+11
#   level 0.678: [8.9495e+11, 4.5307e+12] (phys)
#   level 0.954: [7.8844e+11, 6.1409e+12] (phys)
# Band saved as T3/scenario_bkg_b/bands/band_bkgb_idx008_bkgpen.json
# === index 13 ===
# [band idx=13] v0=1.2284e+12 (phys), bracketing with step=1.5
#   upper bracket: 4.1458e+12
#   lower bracket: 5.4595e+11
#   level 0.678: [8.9495e+11, 2.2354e+12] (phys)
#   level 0.954: [7.8844e+11, 3.0299e+12] (phys)
# Band saved as T3/scenario_bkg_b/bands/band_bkgb_idx013_bkgpen.json
# === index 16 ===
# [band idx=16] v0=1.2284e+12 (phys), bracketing with step=1.5
#   upper bracket: 2.7639e+12
#   lower bracket: 5.4595e+11
#   level 0.678: [8.9495e+11, 1.7740e+12] (phys)
#   level 0.954: [7.8844e+11, 2.2856e+12] (phys)
# Band saved as T3/scenario_bkg_b/bands/band_bkgb_idx016_bkgpen.json
# === index 20 ===
# [band idx=20] v0=1.2284e+12 (phys), bracketing with step=1.5
#   upper bracket: 1.8426e+12
#   lower bracket: 5.4595e+11
#   level 0.678: [8.7255e+11, 1.4856e+12] (phys)
#   level 0.954: [7.6871e+11, 1.7740e+12] (phys)
# Band saved as T3/scenario_bkg_b/bands/band_bkgb_idx020_bkgpen.json
# === index 25 ===
# [band idx=25] v0=1.1294e+12 (phys), bracketing with step=1.5
#   upper bracket: 1.6941e+12
#   lower bracket: 5.0195e+11
#   level 0.678: [8.2282e+11, 1.4010e+12] (phys)
#   level 0.954: [7.2490e+11, 1.5902e+12] (phys)
# Band saved as T3/scenario_bkg_b/bands/band_bkgb_idx025_bkgpen.json
# === index 30 ===
# [band idx=30] v0=9.8565e+11 (phys), bracketing with step=1.5
#   upper bracket: 1.4785e+12
#   lower bracket: 6.5710e+11
#   level 0.678: [7.7482e+11, 1.3192e+12] (phys)
#   level 0.954: [7.0013e+11, 1.4600e+12] (phys)
# Band saved as T3/scenario_bkg_b/bands/band_bkgb_idx030_bkgpen.json
# === index 40 ===
# [band idx=40] v0=9.6237e+11 (phys), bracketing with step=1.5
#   upper bracket: 1.4436e+12
#   lower bracket: 4.2772e+11
#   level 0.678: [6.8360e+11, 1.1938e+12] (phys)
#   level 0.954: [6.0224e+11, 1.3211e+12] (phys)
# Band saved as T3/scenario_bkg_b/bands/band_bkgb_idx040_bkgpen.json
# === index 50 ===
# [band idx=50] v0=8.6298e+11 (phys), bracketing with step=1.5
#   upper bracket: 1.2945e+12
#   lower bracket: 3.8355e+11
#   level 0.678: [5.8271e+11, 1.0705e+12] (phys)
#   level 0.954: [5.1336e+11, 1.1847e+12] (phys)
# Band saved as T3/scenario_bkg_b/bands/band_bkgb_idx050_bkgpen.json
# === index 60 ===
# [band idx=60] v0=7.6268e+11 (phys), bracketing with step=1.5
#   upper bracket: 1.1440e+12
#   lower bracket: 3.3897e+11
#   level 0.678: [5.1498e+11, 9.7035e+11] (phys)
#   level 0.954: [4.3127e+11, 1.0739e+12] (phys)
# Band saved as T3/scenario_bkg_b/bands/band_bkgb_idx060_bkgpen.json
# === index 70 ===
# [band idx=70] v0=6.4580e+11 (phys), bracketing with step=1.5
#   upper bracket: 9.6870e+11
#   lower bracket: 2.8702e+11
#   level 0.678: [4.2515e+11, 8.6437e+11] (phys)
#   level 0.954: [3.5604e+11, 9.5658e+11] (phys)
# Band saved as T3/scenario_bkg_b/bands/band_bkgb_idx070_bkgpen.json
# === index 80 ===
# [band idx=80] v0=5.5834e+11 (phys), bracketing with step=1.5
#   upper bracket: 1.2563e+12
#   lower bracket: 2.4815e+11
#   level 0.678: [3.4066e+11, 7.8617e+11] (phys)
#   level 0.954: [2.8529e+11, 8.4826e+11] (phys)
# Band saved as T3/scenario_bkg_b/bands/band_bkgb_idx080_bkgpen.json
# === index 90 ===
# [band idx=90] v0=4.7435e+11 (phys), bracketing with step=1.5
#   upper bracket: 1.0673e+12
#   lower bracket: 2.1082e+11
#   level 0.678: [2.7511e+11, 6.8504e+11] (phys)
#   level 0.954: [2.1901e+11, 7.5812e+11] (phys)
# Band saved as T3/scenario_bkg_b/bands/band_bkgb_idx090_bkgpen.json
# === index 100 ===
# [band idx=100] v0=3.8514e+11 (phys), bracketing with step=1.5
#   upper bracket: 8.6657e+11
#   lower bracket: 1.1412e+11
#   level 0.678: [2.1572e+11, 6.0014e+11] (phys)
#   level 0.954: [1.5616e+11, 6.6417e+11] (phys)
# Band saved as T3/scenario_bkg_b/bands/band_bkgb_idx100_bkgpen.json
# === index 110 ===
# [band idx=110] v0=3.3050e+11 (phys), bracketing with step=1.5
#   upper bracket: 7.4364e+11
#   lower bracket: 9.7927e+10
#   level 0.678: [1.5307e+11, 5.1501e+11] (phys)
#   level 0.954: [1.0467e+11, 5.8458e+11] (phys)
# Band saved as T3/scenario_bkg_b/bands/band_bkgb_idx110_bkgpen.json
# === index 120 ===
# [band idx=120] v0=2.5935e+11 (phys), bracketing with step=1.5
#   upper bracket: 5.8354e+11
#   lower bracket: 5.1230e+10
#   level 0.678: [1.0549e+11, 4.3605e+11] (phys)
#   level 0.954: [6.1958e+10, 5.0766e+11] (phys)
# Band saved as T3/scenario_bkg_b/bands/band_bkgb_idx120_bkgpen.json
# === index 130 ===
# [band idx=130] v0=2.0936e+11 (phys), bracketing with step=1.5
#   upper bracket: 4.7106e+11
#   lower bracket: 2.7570e+10
#   level 0.678: [5.9438e+10, 3.7981e+11] (phys)
#   level 0.954: [2.7790e+10, 4.4218e+11] (phys)
# Band saved as T3/scenario_bkg_b/bands/band_bkgb_idx130_bkgpen.json
# === index 140 ===
# [band idx=140] v0=1.1751e+11 (phys), bracketing with step=1.5
#   upper bracket: 3.9661e+11
#   lower bracket: 1.3586e+09
#   level 0.678: [2.8408e+10, 3.2487e+11] (phys)
#   level 0.954: [1.3705e+09, 3.8548e+11] (phys)
# Band saved as T3/scenario_bkg_b/bands/band_bkgb_idx140_bkgpen.json
# === index 150 ===
# [band idx=150] v0=1.1751e+11 (phys), bracketing with step=1.5
#   upper bracket: 3.9661e+11
#   lower edge reaches 0 / unbounded below
#   level 0.678: [0.0000e+00, 2.7905e+11] (phys)
#   level 0.954: [0.0000e+00, 3.1875e+11] (phys)
# Band saved as T3/scenario_bkg_b/bands/band_bkgb_idx150_bkgpen.json
# === index 160 ===
# [band idx=160] v0=1.1751e+11 (phys), bracketing with step=1.5
#   upper bracket: 2.6440e+11
#   lower edge reaches 0 / unbounded below
#   level 0.678: [0.0000e+00, 2.1318e+11] (phys)
#   level 0.954: [0.0000e+00, 2.5456e+11] (phys)
# Band saved as T3/scenario_bkg_b/bands/band_bkgb_idx160_bkgpen.json
# === index 167 ===
# [band idx=167] v0=0.0000e+00 (phys), bracketing with step=1.5
#   upper edge unbounded (still inside at max_bracket)
#   lower edge reaches 0 / unbounded below
#   level 0.678: [0.0000e+00, inf] (phys)
#   level 0.954: [0.0000e+00, inf] (phys)
# Band saved as T3/scenario_bkg_b/bands/band_bkgb_idx167_bkgpen.json

# %%
# Load the saved bands and overlay them on the optimize result
# band_files can be a glob pattern or an explicit list
a.plot_flux_with_bands(
    f'scenario_bkg_b/bands/band_bkg{a.background_scenario}_idx*.json',
    levels=(0.678, 0.954),   # Levels to plot (omit to show all saved levels)
    save=True,
    ylim=(0, 3e13),                # So the high-flux tail is visible
)
import matplotlib.pyplot as plt
#plt.yscale('log')
plt.ylim(0, 2e12)
plt.show()

# %%
# Load the saved bands and overlay them on the optimize result
# band_files can be a glob pattern or an explicit list
a.plot_flux_with_bands(
    f'scenario_bkg_b/bands/band_bkg{a.background_scenario}_idx*.json',
    levels=(0.678, 0.954),   # Levels to plot (omit to show all saved levels)
    save=True,
    ylim=(0, 3e13),                # So the high-flux tail is visible
)
import matplotlib.pyplot as plt
plt.yscale('log')
plt.ylim(1e11, 1e14)
plt.show()
