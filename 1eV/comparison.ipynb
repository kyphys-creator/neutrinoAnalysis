# %%
from neutrino_analysis_band import NeutrinoAnalysis

# %%
# 各シナリオを optimize 済みにしておく
a_flat = NeutrinoAnalysis(background_scenario='flat', intervals='180', GeV=0.32e16, solver='osqp')
a_flat.optimize(a_flat.data_vector)
a_a = NeutrinoAnalysis(background_scenario='a', intervals='180', GeV=0.36e16, solver='osqp')
a_a.optimize(a_a.data_vector)
a_b = NeutrinoAnalysis(background_scenario='b', intervals='180', GeV=0.6e16, solver='osqp')
a_b.optimize(a_b.data_vector)

a_flat.plot_band_comparison(
    {'b':    'T3/scenario_bkg_b/bands/band_*.json',
     'a': 'T3/scenario_bkg_a/bands/band_*.json',},
    level=0.678,
    optimized={'b': a_b},   # ← 各シナリオの optimize 結果を重ねる
    ylim=(0, 2e12), save=True,
    fname='band_comparison_1sigma_edge.pdf',
    logy = False
)
# Out:
# Plot saved as band_comparison_1sigma_edge.pdf

# %%
# 各シナリオを optimize 済みにしておく
a_flat = NeutrinoAnalysis(background_scenario='flat', intervals='180', GeV=0.32e16, solver='osqp')
a_flat.optimize(a_flat.data_vector)
a_a = NeutrinoAnalysis(background_scenario='a', intervals='180', GeV=0.36e16, solver='osqp')
a_a.optimize(a_a.data_vector)
a_b = NeutrinoAnalysis(background_scenario='b', intervals='180', GeV=0.6e16, solver='osqp')
a_b.optimize(a_b.data_vector)

a_flat.plot_band_comparison(
    {'b':    'T3/scenario_bkg_b/bands/band_*.json',
     'a': 'T3/scenario_bkg_a/bands/band_*.json',},
    level=0.678,
    optimized={'b': a_b},   # ← 各シナリオの optimize 結果を重ねる
    ylim=(1e11, 3e13), save=True,
    fname='band_comparison_1sigma_edge.pdf',
    logy = True
)
# Out:
# Plot saved as band_comparison_1sigma_edge.pdf

# %%
# 各シナリオを optimize 済みにしておく
a_flat = NeutrinoAnalysis(background_scenario='flat', intervals='180', GeV=0.32e16, solver='osqp')
a_flat.optimize(a_flat.data_vector)
a_a = NeutrinoAnalysis(background_scenario='a', intervals='180', GeV=0.36e16, solver='osqp')
a_a.optimize(a_a.data_vector)
a_b = NeutrinoAnalysis(background_scenario='b', intervals='180', GeV=0.6e16, solver='osqp')
a_b.optimize(a_b.data_vector)

a_flat.plot_band_comparison(
    {'b':    'T3/scenario_bkg_b/bands/band_*.json',
     'a': 'T3/scenario_bkg_a/bands/band_*.json',},
    level=0.954,
    optimized={'b': a_b},   # ← 各シナリオの optimize 結果を重ねる
    ylim=(0, 5e12), save=True,
    fname='band_comparison_2sigma.pdf',
)
# Out:
# Plot saved as band_comparison_2sigma.pdf

# %%
# 各シナリオを optimize 済みにしておく
a_flat = NeutrinoAnalysis(background_scenario='flat', intervals='180', GeV=0.32e16, solver='osqp')
a_flat.optimize(a_flat.data_vector)
a_a = NeutrinoAnalysis(background_scenario='a', intervals='180', GeV=0.36e16, solver='osqp')
a_a.optimize(a_a.data_vector)
a_b = NeutrinoAnalysis(background_scenario='b', intervals='180', GeV=0.6e16, solver='osqp')
a_b.optimize(a_b.data_vector)

a_flat.plot_band_comparison(
    {'b':    'T3/scenario_bkg_b/bands/band_*.json',
     'a': 'T3/scenario_bkg_a/bands/band_*.json',},
    level=0.954,
    optimized={'b': a_b},   # ← 各シナリオの optimize 結果を重ねる
    ylim=(1e11, 3e13), save=True,
    fname='band_comparison_2sigma_edge.pdf',
    logy = True
)
# Out:
# Plot saved as band_comparison_2sigma_edge.pdf

# %% [markdown]
# ### Individual bands

# %%
# 各シナリオを optimize 済みにしておく
a_flat = NeutrinoAnalysis(background_scenario='flat', intervals='180', GeV=0.32e16, solver='osqp')
a_flat.optimize(a_flat.data_vector)
a_a = NeutrinoAnalysis(background_scenario='a', intervals='180', GeV=0.36e16, solver='osqp')
a_a.optimize(a_a.data_vector)
a_b = NeutrinoAnalysis(background_scenario='b', intervals='180', GeV=0.6e16, solver='osqp')
a_b.optimize(a_b.data_vector)

# 保存したバンドを読み込んで optimize 結果の上に重ねる
# band_files はグロブパターンでも、明示的なリストでもよい
a_a.plot_flux_with_bands(
    f'T3/scenario_bkg_a/bands/band_bkg{a_a.background_scenario}_idx*.json',
    levels=(0.678, 0.954),   # 表示するレベル (省略すると保存済み全レベル)
    save=True,
    ylim=(0, 3e13),                # 高フラックス側の裾まで見えるように
)
import matplotlib.pyplot as plt
plt.yscale('log')
plt.ylim(1e10, 3e13)
plt.show()
# Out:
# Plot saved as T3/scenario_bkg_a/flux_with_bands_bkg_a.pdf

# %%
# 各シナリオを optimize 済みにしておく
a_flat = NeutrinoAnalysis(background_scenario='flat', intervals='180', GeV=0.32e16, solver='osqp')
a_flat.optimize(a_flat.data_vector)
a_a = NeutrinoAnalysis(background_scenario='a', intervals='180', GeV=0.36e16, solver='osqp')
a_a.optimize(a_a.data_vector)
a_b = NeutrinoAnalysis(background_scenario='b', intervals='180', GeV=0.6e16, solver='osqp')
a_b.optimize(a_b.data_vector)

# 保存したバンドを読み込んで optimize 結果の上に重ねる
# band_files はグロブパターンでも、明示的なリストでもよい
a_b.plot_flux_with_bands(
    f'T3/scenario_bkg_b/bands/band_bkg{a_b.background_scenario}_idx*.json',
    levels=(0.678, 0.954),   # 表示するレベル (省略すると保存済み全レベル)
    save=True,
    ylim=(0, 3e13),                # 高フラックス側の裾まで見えるように
)
import matplotlib.pyplot as plt
plt.yscale('log')
plt.ylim(1e10, 3e13)
plt.show()
# Out:
# Plot saved as T3/scenario_bkg_b/flux_with_bands_bkg_b.pdf
