# %% [markdown]
# # 信頼バンドの根探索 (`find_confidence_band`)
#
# 等間隔グリッドの代わりに、ブラケット＋幾何二分法でバンドの上下端を直接探す例。
# 最も広い 2σ で外側をブラケットし、各レベル (1σ/90%/2σ) の端を入れ子で詰める。
#
# - `num_pseudo_data`: ブラケット段階の擬似データ数（粗くてよい）
# - `n_pseudo_edge`: 端の二分法で使う擬似データ数（cutoff のノイズを抑えるため大きめ）
# - `seed`: 固定すると各点が再現可能になり、二分法のジッターが減る

# %%
from neutrino_analysis_band import NeutrinoAnalysis

# %%
a = NeutrinoAnalysis(background_scenario='a', intervals='180',
                     GeV=1e16, solver='osqp', T=20)
a.optimize(a.data_vector)   # ベストフィットを先に求める (self.result を埋める)
result_a = a.optimize(a.data_vector)
print("\nOptimization Complete.")
print(f"Minimum chi-squared: {result_a.fun / a.c}")
# 3. Plot the primary result: the optimized flux vs. theory.
a.plot_flux_comparison(save = True)
# Out:
# Optimization Complete.
# Minimum chi-squared: 2.468163639986362e-05
# Plot saved as T20/scenario_bkg_a/flux_comparison_bkg_a.pdf

# %% [markdown]
# ## 複数インデックスのバンドを保存して重ねる
#
# 1. インデックスごとに `find_and_save_band` を実行し、`bands/` 配下に 1 ファイルずつ JSON で保存する。
# 2. `plot_flux_with_bands` で保存済みファイルを読み込み、`optimize` の最適フラックス（散布図）の上に各インデックスのバンドを誤差棒として重ねる。
#
# `save_band` / `load_band` は JSON 形式（人が読める）。バンドの中心は保存時の `self.result.x[index]` なので、同じ `optimize` 結果の散布図とちょうど重なる。

# %%
# 自動で T 別フォルダに保存（outdir 省略可）
# → T3/scenario_bkg_flat/bands/band_bkgflat_idx000.json

# 複数インデックスでバンドを作り、インデックスごとに 1 ファイルへ保存
# 保存先は ./bands/band_bkg<scenario>_idx<NNN>.json
indices = [1, 2, 3, 4, 5, 8, 13, 16, 20, 25, 30, 40, 50, 60, 70, 80, 90, 100, 110, 120, 130, 140, 150, 160, 167]     # 走らせたいインデックス

for idx in indices:
    print(f'=== index {idx} ===')
    a.find_and_save_band(
        idx,
        outdir='T20/scenario_bkg_a/bands',
        levels=(0.678, 0.954),
        num_pseudo_data=50,
        n_pseudo_edge=500,
        step=1.5,
        rel_tol=0.03,
        seed=42,
        n_jobs=1,
        verbose=True,
    )
# Out:
# === index 1 ===
# [band idx=1] v0=1.2442e+12 (phys), bracketing with step=1.5
#   upper bracket: 3.1887e+13
#   lower bracket: 8.2947e+11
#   level 0.678: [1.0289e+12, 1.9456e+13] (phys)
#   level 0.954: [9.5360e+11, 2.8453e+13] (phys)
# Band saved as T20/scenario_bkg_a/bands/band_bkga_idx001.json
# === index 2 ===
# [band idx=2] v0=1.2442e+12 (phys), bracketing with step=1.5
#   upper bracket: 2.1258e+13
#   lower bracket: 8.2947e+11
#   level 0.678: [1.0289e+12, 1.1813e+13] (phys)
#   level 0.954: [9.5360e+11, 1.6844e+13] (phys)
# Band saved as T20/scenario_bkg_a/bands/band_bkga_idx002.json
# === index 3 ===
# [band idx=3] v0=1.2442e+12 (phys), bracketing with step=1.5
#   upper bracket: 1.4172e+13
#   lower bracket: 8.2947e+11
#   level 0.678: [1.0289e+12, 8.0901e+12] (phys)
#   level 0.954: [9.5360e+11, 1.1390e+13] (phys)
# Band saved as T20/scenario_bkg_a/bands/band_bkga_idx003.json
# === index 4 ===
# [band idx=4] v0=1.2442e+12 (phys), bracketing with step=1.5
#   upper bracket: 9.4481e+12
#   lower bracket: 8.2947e+11
#   level 0.678: [1.0289e+12, 6.0162e+12] (phys)
#   level 0.954: [9.5360e+11, 8.2583e+12] (phys)
# Band saved as T20/scenario_bkg_a/bands/band_bkga_idx004.json
# === index 5 ===
# [band idx=5] v0=1.2442e+12 (phys), bracketing with step=1.5
#   upper bracket: 6.2988e+12
#   lower bracket: 8.2947e+11
#   level 0.678: [1.0289e+12, 4.7068e+12] (phys)
#   level 0.954: [9.5360e+11, 6.2200e+12] (phys)
# Band saved as T20/scenario_bkg_a/bands/band_bkga_idx005.json
# === index 8 ===
# [band idx=8] v0=1.2442e+12 (phys), bracketing with step=1.5
#   upper bracket: 4.1992e+12
#   lower bracket: 8.2947e+11
#   level 0.678: [1.0289e+12, 2.7382e+12] (phys)
#   level 0.954: [9.5360e+11, 3.5056e+12] (phys)
# Band saved as T20/scenario_bkg_a/bands/band_bkga_idx008.json
# === index 13 ===
# [band idx=13] v0=1.2442e+12 (phys), bracketing with step=1.5
#   upper bracket: 2.7994e+12
#   lower bracket: 8.2947e+11
#   level 0.678: [1.0289e+12, 1.6653e+12] (phys)
#   level 0.954: [9.5360e+11, 1.9388e+12] (phys)
# Band saved as T20/scenario_bkg_a/bands/band_bkga_idx013.json
# === index 16 ===
# [band idx=16] v0=1.2442e+12 (phys), bracketing with step=1.5
#   upper bracket: 1.8663e+12
#   lower bracket: 8.2947e+11
#   level 0.678: [1.0289e+12, 1.4671e+12] (phys)
#   level 0.954: [9.5360e+11, 1.5830e+12] (phys)
# Band saved as T20/scenario_bkg_a/bands/band_bkga_idx016.json
# === index 20 ===
# [band idx=20] v0=1.2442e+12 (phys), bracketing with step=1.5
#   upper bracket: 1.8663e+12
#   lower bracket: 8.2947e+11
#   level 0.678: [1.0032e+12, 1.3257e+12] (phys)
#   level 0.954: [9.2974e+11, 1.3946e+12] (phys)
# Band saved as T20/scenario_bkg_a/bands/band_bkga_idx020.json
# === index 25 ===
# [band idx=25] v0=1.1688e+12 (phys), bracketing with step=1.5
#   upper bracket: 1.7533e+12
#   lower bracket: 7.7923e+11
#   level 0.678: [9.4242e+11, 1.2774e+12] (phys)
#   level 0.954: [8.9584e+11, 1.3101e+12] (phys)
# Band saved as T20/scenario_bkg_a/bands/band_bkga_idx025.json
# === index 30 ===
# [band idx=30] v0=9.9320e+11 (phys), bracketing with step=1.5
#   upper bracket: 1.4898e+12
#   lower bracket: 6.6213e+11
#   level 0.678: [8.8623e+11, 1.1711e+12] (phys)
#   level 0.954: [8.4243e+11, 1.2320e+12] (phys)
# Band saved as T20/scenario_bkg_a/bands/band_bkga_idx030.json
# === index 40 ===
# [band idx=40] v0=9.9320e+11 (phys), bracketing with step=1.5
#   upper bracket: 1.4898e+12
#   lower bracket: 6.6213e+11
#   level 0.678: [8.0080e+11, 1.0582e+12] (phys)
#   level 0.954: [7.6122e+11, 1.1133e+12] (phys)
# Band saved as T20/scenario_bkg_a/bands/band_bkga_idx040.json
# === index 50 ===
# [band idx=50] v0=8.0553e+11 (phys), bracketing with step=1.5
#   upper bracket: 1.2083e+12
#   lower bracket: 5.3702e+11
#   level 0.678: [7.0079e+11, 9.4985e+11] (phys)
#   level 0.954: [6.6615e+11, 9.9923e+11] (phys)
# Band saved as T20/scenario_bkg_a/bands/band_bkga_idx050.json
# === index 60 ===
# [band idx=60] v0=7.3091e+11 (phys), bracketing with step=1.5
#   upper bracket: 1.0964e+12
#   lower bracket: 4.8727e+11
#   level 0.678: [6.0444e+11, 8.6186e+11] (phys)
#   level 0.954: [5.7457e+11, 9.0667e+11] (phys)
# Band saved as T20/scenario_bkg_a/bands/band_bkga_idx060.json
# === index 70 ===
# [band idx=70] v0=6.5426e+11 (phys), bracketing with step=1.5
#   upper bracket: 9.8139e+11
#   lower bracket: 4.3617e+11
#   level 0.678: [5.2752e+11, 7.7147e+11] (phys)
#   level 0.954: [4.8890e+11, 8.1158e+11] (phys)
# Band saved as T20/scenario_bkg_a/bands/band_bkga_idx070.json
# === index 80 ===
# [band idx=80] v0=5.6654e+11 (phys), bracketing with step=1.5
#   upper bracket: 8.4981e+11
#   lower bracket: 3.7769e+11
#   level 0.678: [4.3421e+11, 6.6804e+11] (phys)
#   level 0.954: [4.0243e+11, 7.0277e+11] (phys)
# Band saved as T20/scenario_bkg_a/bands/band_bkga_idx080.json
# === index 90 ===
# [band idx=90] v0=4.7452e+11 (phys), bracketing with step=1.5
#   upper bracket: 7.1178e+11
#   lower bracket: 3.1635e+11
#   level 0.678: [3.5459e+11, 5.8863e+11] (phys)
#   level 0.954: [3.2041e+11, 6.1923e+11] (phys)
# Band saved as T20/scenario_bkg_a/bands/band_bkga_idx090.json
# === index 100 ===
# [band idx=100] v0=3.7523e+11 (phys), bracketing with step=1.5
#   upper bracket: 5.6284e+11
#   lower bracket: 2.5015e+11
#   level 0.678: [2.8759e+11, 4.8965e+11] (phys)
#   level 0.954: [2.5986e+11, 5.2833e+11] (phys)
# Band saved as T20/scenario_bkg_a/bands/band_bkga_idx100.json
# === index 110 ===
# [band idx=110] v0=3.2583e+11 (phys), bracketing with step=1.5
#   upper bracket: 4.8874e+11
#   lower bracket: 1.4481e+11
#   level 0.678: [2.3738e+11, 4.1455e+11] (phys)
#   level 0.954: [2.0390e+11, 4.4729e+11] (phys)
# Band saved as T20/scenario_bkg_a/bands/band_bkga_idx110.json
# === index 120 ===
# [band idx=120] v0=2.6199e+11 (phys), bracketing with step=1.5
#   upper bracket: 3.9298e+11
#   lower bracket: 1.1644e+11
#   level 0.678: [1.7690e+11, 3.5965e+11] (phys)
#   level 0.954: [1.5985e+11, 3.7835e+11] (phys)
# Band saved as T20/scenario_bkg_a/bands/band_bkga_idx120.json
# === index 130 ===
# [band idx=130] v0=2.0871e+11 (phys), bracketing with step=1.5
#   upper bracket: 4.6961e+11
#   lower bracket: 9.2762e+10
#   level 0.678: [1.4093e+11, 2.9388e+11] (phys)
#   level 0.954: [1.0664e+11, 3.2523e+11] (phys)
# Band saved as T20/scenario_bkg_a/bands/band_bkga_idx130.json
# === index 140 ===
# [band idx=140] v0=1.1746e+11 (phys), bracketing with step=1.5
#   upper bracket: 2.6428e+11
#   lower bracket: 5.2204e+10
#   level 0.678: [9.0025e+10, 2.3582e+11] (phys)
#   level 0.954: [6.8124e+10, 2.6098e+11] (phys)
# Band saved as T20/scenario_bkg_a/bands/band_bkga_idx140.json
# === index 150 ===
# [band idx=150] v0=1.1746e+11 (phys), bracketing with step=1.5
#   upper bracket: 2.6428e+11
#   lower bracket: 1.5468e+10
#   level 0.678: [2.9847e+10, 2.0775e+11] (phys)
#   level 0.954: [2.0735e+10, 2.2992e+11] (phys)
# Band saved as T20/scenario_bkg_a/bands/band_bkga_idx150.json
# === index 160 ===
# [band idx=160] v0=1.1746e+11 (phys), bracketing with step=1.5
#   upper bracket: 2.6428e+11
#   lower bracket: 1.7882e+08
# Failure:interrupted

# %%
# 保存したバンドを読み込んで optimize 結果の上に重ねる
# band_files はグロブパターンでも、明示的なリストでもよい
a.plot_flux_with_bands(
    f'scenario_bkg_b/bands/band_bkg{a.background_scenario}_idx*.json',
    levels=(0.678, 0.954),   # 表示するレベル (省略すると保存済み全レベル)
    save=True,
    ylim=(0, 3e13),                # 高フラックス側の裾まで見えるように
)
import matplotlib.pyplot as plt
#plt.yscale('log')
plt.ylim(0, 2e12)
plt.show()

# %%
# 保存したバンドを読み込んで optimize 結果の上に重ねる
# band_files はグロブパターンでも、明示的なリストでもよい
a.plot_flux_with_bands(
    f'scenario_bkg_b/bands/band_bkg{a.background_scenario}_idx*.json',
    levels=(0.678, 0.954),   # 表示するレベル (省略すると保存済み全レベル)
    save=True,
    ylim=(0, 3e13),                # 高フラックス側の裾まで見えるように
)
import matplotlib.pyplot as plt
plt.yscale('log')
plt.ylim(1e11, 1e14)
plt.show()
