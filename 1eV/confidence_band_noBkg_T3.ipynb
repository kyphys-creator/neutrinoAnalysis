# %% [markdown]
# # 信頼バンドの根探索 (`find_confidence_band`)
#
# 等間隔グリッドの代わりに、ブラケット＋幾何二分法でバンドの上下端を直接探す例。
# 最も広い 2σ で外側をブラケットし、各レベル (1σ/90%/2σ) の端を入れ子で詰める。
#
# - `num_pseudo_data`: ブラケット段階の擬似データ数（粗くてよい）
# - `n_pseudo_edge`: 端の二分法で使う擬似データ数（cutoff のノイズを抑えるため大きめ）
# - `seed`: 固定すると各点が再現可能になり、二分法のジッターが減る

# %%
from neutrino_analysis_band import NeutrinoAnalysis

# %%
a = NeutrinoAnalysis(background_scenario='a', intervals='180',
                     GeV=1e16, solver='osqp', T=3)
a.optimize(a.data_vector)   # ベストフィットを先に求める (self.result を埋める)
result_a = a.optimize(a.data_vector)
print("\nOptimization Complete.")
print(f"Minimum chi-squared: {result_a.fun / a.c}")
# 3. Plot the primary result: the optimized flux vs. theory.
a.plot_flux_comparison(save = True)
# Out:
# Optimization Complete.
# Minimum chi-squared: 1.3821109232811892e-07
# Plot saved as T3/scenario_bkg_a/flux_comparison_bkg_a.pdf

# %% [markdown]
# ## 複数インデックスのバンドを保存して重ねる
#
# 1. インデックスごとに `find_and_save_band` を実行し、`bands/` 配下に 1 ファイルずつ JSON で保存する。
# 2. `plot_flux_with_bands` で保存済みファイルを読み込み、`optimize` の最適フラックス（散布図）の上に各インデックスのバンドを誤差棒として重ねる。
#
# `save_band` / `load_band` は JSON 形式（人が読める）。バンドの中心は保存時の `self.result.x[index]` なので、同じ `optimize` 結果の散布図とちょうど重なる。

# %%
# 自動で T 別フォルダに保存（outdir 省略可）
# → T3/scenario_bkg_flat/bands/band_bkgflat_idx000.json

# 複数インデックスでバンドを作り、インデックスごとに 1 ファイルへ保存
# 保存先は ./bands/band_bkg<scenario>_idx<NNN>.json
indices = [1, 2, 3, 4, 5, 8, 13, 16, 20, 25, 30, 40, 50, 60, 70, 80, 90, 100, 110, 120, 130, 140, 150, 160, 167]     # 走らせたいインデックス

for idx in indices:
    print(f'=== index {idx} ===')
    a.find_and_save_band(
        idx,
        outdir='T3/scenario_bkg_a/bands',
        levels=(0.678, 0.954),
        num_pseudo_data=50,
        n_pseudo_edge=500,
        step=1.5,
        rel_tol=0.03,
        seed=42,
        n_jobs=1,
        verbose=True,
    )
# Out:
# === index 1 ===
# [band idx=1] v0=1.2441e+12 (phys), bracketing with step=1.5
#   upper bracket: 4.7827e+13
#   lower bracket: 8.2939e+11
#   level 0.678: [9.2965e+11, 4.6841e+12] (phys)
#   level 0.954: [8.4003e+11, 4.6841e+12] (phys)
# Band saved as T3/scenario_bkg_a/bands/band_bkga_idx001.json
# === index 2 ===
# [band idx=2] v0=1.2581e+12 (phys), bracketing with step=1.5
#   upper bracket: 6.3691e+12
#   lower bracket: 8.3873e+11
#   level 0.678: [9.6425e+11, 5.4023e+12] (phys)
#   level 0.954: [8.4949e+11, 5.4023e+12] (phys)
# Band saved as T3/scenario_bkg_a/bands/band_bkga_idx002.json
# === index 3 ===
# [band idx=3] v0=1.2577e+12 (phys), bracketing with step=1.5
#   upper bracket: 1.8866e+12
#   lower bracket: 8.3847e+11
#   level 0.678: [9.6395e+11, 1.8163e+12] (phys)
#   level 0.954: [8.4923e+11, 1.8163e+12] (phys)
# Band saved as T3/scenario_bkg_a/bands/band_bkga_idx003.json
# === index 4 ===
# [band idx=4] v0=1.2575e+12 (phys), bracketing with step=1.5
#   upper bracket: 1.4324e+13
#   lower bracket: 8.3836e+11
#   level 0.678: [9.6383e+11, 8.4937e+12] (phys)
#   level 0.954: [8.4912e+11, 1.3151e+13] (phys)
# Band saved as T3/scenario_bkg_a/bands/band_bkga_idx004.json
# === index 5 ===
# [band idx=5] v0=1.2574e+12 (phys), bracketing with step=1.5
#   upper bracket: 9.5485e+12
#   lower bracket: 8.3828e+11
#   level 0.678: [9.6372e+11, 6.4777e+12] (phys)
#   level 0.954: [8.4903e+11, 9.4735e+12] (phys)
# Band saved as T3/scenario_bkg_a/bands/band_bkga_idx005.json
# === index 8 ===
# [band idx=8] v0=1.2571e+12 (phys), bracketing with step=1.5
#   upper bracket: 6.3640e+12
#   lower bracket: 8.3806e+11
#   level 0.678: [9.6348e+11, 3.5086e+12] (phys)
#   level 0.954: [8.4882e+11, 5.1312e+12] (phys)
# Band saved as T3/scenario_bkg_a/bands/band_bkga_idx008.json
# === index 13 ===
# [band idx=13] v0=1.2566e+12 (phys), bracketing with step=1.5
#   upper bracket: 2.8274e+12
#   lower bracket: 8.3774e+11
#   level 0.678: [9.6311e+11, 1.8613e+12] (phys)
#   level 0.954: [8.4849e+11, 2.5228e+12] (phys)
# Band saved as T3/scenario_bkg_a/bands/band_bkga_idx013.json
# === index 16 ===
# [band idx=16] v0=1.2473e+12 (phys), bracketing with step=1.5
#   upper bracket: 2.8064e+12
#   lower bracket: 8.3152e+11
#   level 0.678: [9.5596e+11, 1.5869e+12] (phys)
#   level 0.954: [8.6381e+11, 1.8949e+12] (phys)
# Band saved as T3/scenario_bkg_a/bands/band_bkga_idx016.json
# === index 20 ===
# [band idx=20] v0=1.2020e+12 (phys), bracketing with step=1.5
#   upper bracket: 1.8029e+12
#   lower bracket: 8.0130e+11
#   level 0.678: [9.4487e+11, 1.4173e+12] (phys)
#   level 0.954: [8.5378e+11, 1.5685e+12] (phys)
# Band saved as T3/scenario_bkg_a/bands/band_bkga_idx020.json
# === index 25 ===
# [band idx=25] v0=1.0847e+12 (phys), bracketing with step=1.5
#   upper bracket: 1.6270e+12
#   lower bracket: 7.2310e+11
#   level 0.678: [8.7454e+11, 1.3455e+12] (phys)
#   level 0.954: [8.1051e+11, 1.4154e+12] (phys)
# Band saved as T3/scenario_bkg_a/bands/band_bkga_idx025.json
# === index 30 ===
# [band idx=30] v0=1.0112e+12 (phys), bracketing with step=1.5
#   upper bracket: 1.5168e+12
#   lower bracket: 6.7413e+11
#   level 0.678: [8.1531e+11, 1.2543e+12] (phys)
#   level 0.954: [7.5562e+11, 1.3534e+12] (phys)
# Band saved as T3/scenario_bkg_a/bands/band_bkga_idx030.json
# === index 40 ===
# [band idx=40] v0=9.2029e+11 (phys), bracketing with step=1.5
#   upper bracket: 1.3804e+12
#   lower bracket: 6.1353e+11
#   level 0.678: [7.4201e+11, 1.1130e+12] (phys)
#   level 0.954: [6.7048e+11, 1.2009e+12] (phys)
# Band saved as T3/scenario_bkg_a/bands/band_bkga_idx040.json
# === index 50 ===
# [band idx=50] v0=8.2683e+11 (phys), bracketing with step=1.5
#   upper bracket: 1.2402e+12
#   lower bracket: 5.5122e+11
#   level 0.678: [6.4998e+11, 1.0257e+12] (phys)
#   level 0.954: [5.8732e+11, 1.0790e+12] (phys)
# Band saved as T3/scenario_bkg_a/bands/band_bkga_idx050.json
# === index 60 ===
# [band idx=60] v0=7.3349e+11 (phys), bracketing with step=1.5
#   upper bracket: 1.1002e+12
#   lower bracket: 4.8899e+11
#   level 0.678: [5.6217e+11, 9.0986e+11] (phys)
#   level 0.954: [4.9527e+11, 9.8173e+11] (phys)
# Band saved as T3/scenario_bkg_a/bands/band_bkga_idx060.json
# === index 70 ===
# [band idx=70] v0=6.4245e+11 (phys), bracketing with step=1.5
#   upper bracket: 9.6367e+11
#   lower bracket: 2.8553e+11
#   level 0.678: [4.6806e+11, 8.3836e+11] (phys)
# Failure:interrupted

# %%
# 保存したバンドを読み込んで optimize 結果の上に重ねる
# band_files はグロブパターンでも、明示的なリストでもよい
a.plot_flux_with_bands(
    f'scenario_bkg_b/bands/band_bkg{a.background_scenario}_idx*.json',
    levels=(0.678, 0.954),   # 表示するレベル (省略すると保存済み全レベル)
    save=True,
    ylim=(0, 3e13),                # 高フラックス側の裾まで見えるように
)
import matplotlib.pyplot as plt
#plt.yscale('log')
plt.ylim(0, 2e12)
plt.show()

# %%
# 保存したバンドを読み込んで optimize 結果の上に重ねる
# band_files はグロブパターンでも、明示的なリストでもよい
a.plot_flux_with_bands(
    f'scenario_bkg_b/bands/band_bkg{a.background_scenario}_idx*.json',
    levels=(0.678, 0.954),   # 表示するレベル (省略すると保存済み全レベル)
    save=True,
    ylim=(0, 3e13),                # 高フラックス側の裾まで見えるように
)
import matplotlib.pyplot as plt
plt.yscale('log')
plt.ylim(1e11, 1e14)
plt.show()
