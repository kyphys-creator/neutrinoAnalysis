# %% [markdown]
# # Confidence-band root finder (`find_confidence_band`)
#
# Example: instead of a uniform grid, locate the band edges directly by bracketing + geometric bisection.
# Bracket the outer reach with the widest level (2σ); the narrower 1σ / 90% / 2σ edges nest inside that interval.
#
# - `num_pseudo_data`: pseudo-data sample size during bracketing (can be coarse)
# - `n_pseudo_edge`: pseudo-data sample size for the edge bisection (larger suppresses cutoff noise)
# - `seed`: fixed value makes every evaluation reproducible and stops the bisection from jittering

# %%
from neutrino_analysis_band import NeutrinoAnalysis

# %%
a = NeutrinoAnalysis(background_scenario='b', intervals='180',
                     GeV=0.1e16, solver='osqp', T=40)
a.optimize(a.data_vector)   # Compute the best fit first (populates self.result)
result_b = a.optimize(a.data_vector)
print("\nOptimization Complete.")
print(f"Minimum chi-squared: {result_b.fun / a.c}")
# 3. Plot the primary result: the optimized flux vs. theory.
a.plot_flux_comparison(save = True)
# Out:
# Optimization Complete.
# Minimum chi-squared: 9.4151724674321e-12
# Plot saved as T40/scenario_bkg_b/flux_comparison_bkg_b.pdf

# %% [markdown]
# ## Save bands for several indices and overlay them
#
# 1. Run `find_and_save_band` per index and save one JSON file per index under `bands/`.
# 2. Load the saved files with `plot_flux_with_bands` and overlay each index's band as an error bar on top of the `optimize` flux scatter.
#
# `save_band` / `load_band` use a human-readable JSON format. The band centre is the saved `self.result.x[index]`, so it lines up exactly with the scatter from the same `optimize` result.

# %%
# Saved automatically under the T-prefixed folder (outdir can be omitted)
# → T3/scenario_bkg_flat/bands/band_bkgflat_idx000.json

# Build bands for several indices and save one file per index
# Destination: ./bands/band_bkg<scenario>_idx<NNN>.json
indices = [0, 1, 2, 3, 4, 5, 8, 13, 16, 20, 25, 30, 40, 50, 60, 70, 80, 90, 100, 110, 120, 130, 140, 150, 160, 167]     # Indices to run

for idx in indices:
    print(f'=== index {idx} ===')
    a.find_and_save_band(
        idx,
        outdir='T40/scenario_bkg_b/bands',
        levels=(0.678, 0.954),
        num_pseudo_data=50,
        n_pseudo_edge=500,
        step=1.5,
        rel_tol=0.03,
        seed=42,
        n_jobs=1,
        verbose=True,
        bkg_penalty=True,
    )
# Out:
# === index 0 ===
# [band idx=0] v0=1.2284e+12 (phys), bracketing with step=1.5
#   upper bracket: 7.0835e+13
#   lower bracket: 8.1892e+11
#   level 0.678: [1.1827e+12, 4.8822e+13] (phys)
#   level 0.954: [1.1242e+12, 7.0278e+13] (phys)
# Band saved as T40/scenario_bkg_b/bands/band_bkgb_idx000_bkgpen.json
# === index 1 ===
# [band idx=1] v0=1.2284e+12 (phys), bracketing with step=1.5
#   upper bracket: 3.1482e+13
#   lower bracket: 8.1892e+11
#   level 0.678: [1.0158e+12, 2.1803e+13] (phys)
#   level 0.954: [9.4147e+11, 3.1088e+13] (phys)
# Band saved as T40/scenario_bkg_b/bands/band_bkgb_idx001_bkgpen.json
# === index 2 ===
# [band idx=2] v0=1.2284e+12 (phys), bracketing with step=1.5
#   upper bracket: 2.0988e+13
#   lower bracket: 8.1892e+11
#   level 0.678: [1.0158e+12, 1.3030e+13] (phys)
#   level 0.954: [9.4147e+11, 1.8579e+13] (phys)
# Band saved as T40/scenario_bkg_b/bands/band_bkgb_idx002_bkgpen.json
# === index 3 ===
# [band idx=3] v0=1.2284e+12 (phys), bracketing with step=1.5
#   upper bracket: 1.3992e+13
#   lower bracket: 8.1892e+11
#   level 0.678: [1.0158e+12, 8.9521e+12] (phys)
#   level 0.954: [9.4147e+11, 1.2367e+13] (phys)
# Band saved as T40/scenario_bkg_b/bands/band_bkgb_idx003_bkgpen.json
# === index 4 ===
# [band idx=4] v0=1.2284e+12 (phys), bracketing with step=1.5
#   upper bracket: 9.3280e+12
#   lower bracket: 8.1892e+11
#   level 0.678: [1.0158e+12, 6.6361e+12] (phys)
#   level 0.954: [9.4147e+11, 9.1093e+12] (phys)
# Band saved as T40/scenario_bkg_b/bands/band_bkgb_idx004_bkgpen.json
# === index 5 ===
# [band idx=5] v0=1.2284e+12 (phys), bracketing with step=1.5
#   upper bracket: 9.3280e+12
#   lower bracket: 8.1892e+11
#   level 0.678: [1.0158e+12, 5.1506e+12] (phys)
#   level 0.954: [9.4147e+11, 6.9590e+12] (phys)
# Band saved as T40/scenario_bkg_b/bands/band_bkgb_idx005_bkgpen.json
# === index 8 ===
# [band idx=8] v0=1.2284e+12 (phys), bracketing with step=1.5
#   upper bracket: 4.1458e+12
#   lower bracket: 8.1892e+11
#   level 0.678: [1.0158e+12, 2.9169e+12] (phys)
#   level 0.954: [9.4147e+11, 3.7345e+12] (phys)
# Band saved as T40/scenario_bkg_b/bands/band_bkgb_idx008_bkgpen.json
# === index 13 ===
# [band idx=13] v0=1.2284e+12 (phys), bracketing with step=1.5
#   upper bracket: 2.7639e+12
#   lower bracket: 8.1892e+11
#   level 0.678: [1.0158e+12, 1.7296e+12] (phys)
#   level 0.954: [9.4147e+11, 2.0136e+12] (phys)
# Band saved as T40/scenario_bkg_b/bands/band_bkgb_idx013_bkgpen.json
# === index 16 ===
# [band idx=16] v0=1.2284e+12 (phys), bracketing with step=1.5
#   upper bracket: 1.8426e+12
#   lower bracket: 8.1892e+11
#   level 0.678: [1.0158e+12, 1.4856e+12] (phys)
#   level 0.954: [9.4147e+11, 1.6441e+12] (phys)
# Band saved as T40/scenario_bkg_b/bands/band_bkgb_idx016_bkgpen.json
# === index 20 ===
# [band idx=20] v0=1.2284e+12 (phys), bracketing with step=1.5
#   upper bracket: 1.8426e+12
#   lower bracket: 8.1892e+11
#   level 0.678: [9.9042e+11, 1.3424e+12] (phys)
#   level 0.954: [9.1792e+11, 1.4122e+12] (phys)
# Band saved as T40/scenario_bkg_b/bands/band_bkgb_idx020_bkgpen.json
# === index 25 ===
# [band idx=25] v0=1.1294e+12 (phys), bracketing with step=1.5
#   upper bracket: 1.6941e+12
#   lower bracket: 7.5293e+11
#   level 0.678: [9.3398e+11, 1.2984e+12] (phys)
#   level 0.954: [8.8782e+11, 1.3317e+12] (phys)
# Band saved as T40/scenario_bkg_b/bands/band_bkgb_idx025_bkgpen.json
# === index 30 ===
# [band idx=30] v0=9.8565e+11 (phys), bracketing with step=1.5
#   upper bracket: 1.4785e+12
#   lower bracket: 6.5710e+11
#   level 0.678: [8.7949e+11, 1.2227e+12] (phys)
#   level 0.954: [8.3602e+11, 1.2540e+12] (phys)
# Band saved as T40/scenario_bkg_b/bands/band_bkgb_idx030_bkgpen.json
# === index 40 ===
# [band idx=40] v0=9.6237e+11 (phys), bracketing with step=1.5
#   upper bracket: 1.4436e+12
#   lower bracket: 6.4158e+11
#   level 0.678: [7.7594e+11, 1.0787e+12] (phys)
#   level 0.954: [7.3760e+11, 1.1348e+12] (phys)
# Band saved as T40/scenario_bkg_b/bands/band_bkgb_idx040_bkgpen.json
# === index 50 ===
# [band idx=50] v0=8.6298e+11 (phys), bracketing with step=1.5
#   upper bracket: 1.2945e+12
#   lower bracket: 5.7532e+11
#   level 0.678: [6.9581e+11, 9.6730e+11] (phys)
#   level 0.954: [6.4487e+11, 1.0176e+12] (phys)
# Band saved as T40/scenario_bkg_b/bands/band_bkgb_idx050_bkgpen.json
# === index 60 ===
# [band idx=60] v0=7.6268e+11 (phys), bracketing with step=1.5
#   upper bracket: 1.1440e+12
#   lower bracket: 5.0845e+11
#   level 0.678: [5.9955e+11, 8.7681e+11] (phys)
#   level 0.954: [5.6992e+11, 9.2240e+11] (phys)
# Band saved as T40/scenario_bkg_b/bands/band_bkgb_idx060_bkgpen.json
# === index 70 ===
# [band idx=70] v0=6.4580e+11 (phys), bracketing with step=1.5
#   upper bracket: 9.6870e+11
#   lower bracket: 4.3054e+11
#   level 0.678: [5.2070e+11, 7.8105e+11] (phys)
#   level 0.954: [4.8258e+11, 8.2165e+11] (phys)
# Band saved as T40/scenario_bkg_b/bands/band_bkgb_idx070_bkgpen.json
# === index 80 ===
# [band idx=80] v0=5.5834e+11 (phys), bracketing with step=1.5
#   upper bracket: 8.3752e+11
#   lower bracket: 3.7223e+11
#   level 0.678: [4.2793e+11, 6.7527e+11] (phys)
#   level 0.954: [3.8668e+11, 7.2861e+11] (phys)
# Band saved as T40/scenario_bkg_b/bands/band_bkgb_idx080_bkgpen.json
# === index 90 ===
# [band idx=90] v0=4.7435e+11 (phys), bracketing with step=1.5
#   upper bracket: 7.1152e+11
#   lower bracket: 3.1623e+11
#   level 0.678: [3.4559e+11, 5.8841e+11] (phys)
#   level 0.954: [3.2029e+11, 6.3489e+11] (phys)
# Band saved as T40/scenario_bkg_b/bands/band_bkgb_idx090_bkgpen.json
# === index 100 ===
# [band idx=100] v0=3.8514e+11 (phys), bracketing with step=1.5
#   upper bracket: 5.7771e+11
#   lower bracket: 1.7117e+11
#   level 0.678: [2.8060e+11, 5.0259e+11] (phys)
#   level 0.954: [2.4720e+11, 5.4229e+11] (phys)
# Band saved as T40/scenario_bkg_b/bands/band_bkgb_idx100_bkgpen.json
# === index 110 ===
# [band idx=110] v0=3.3050e+11 (phys), bracketing with step=1.5
#   upper bracket: 4.9576e+11
#   lower bracket: 1.4689e+11
#   level 0.678: [2.1758e+11, 4.3129e+11] (phys)
#   level 0.954: [1.9169e+11, 4.6536e+11] (phys)
# Band saved as T40/scenario_bkg_b/bands/band_bkgb_idx110_bkgpen.json
# === index 120 ===
# [band idx=120] v0=2.5935e+11 (phys), bracketing with step=1.5
#   upper bracket: 5.8354e+11
#   lower bracket: 1.1527e+11
#   level 0.678: [1.7074e+11, 3.6517e+11] (phys)
#   level 0.954: [1.3592e+11, 3.9402e+11] (phys)
# Band saved as T40/scenario_bkg_b/bands/band_bkgb_idx120_bkgpen.json
# === index 130 ===
# [band idx=130] v0=2.0936e+11 (phys), bracketing with step=1.5
#   upper bracket: 4.7106e+11
#   lower bracket: 9.3049e+10
#   level 0.678: [1.1542e+11, 3.1011e+11] (phys)
#   level 0.954: [9.4243e+10, 3.4320e+11] (phys)
# Band saved as T40/scenario_bkg_b/bands/band_bkgb_idx130_bkgpen.json
# === index 140 ===
# [band idx=140] v0=1.1751e+11 (phys), bracketing with step=1.5
#   upper bracket: 3.9661e+11
#   lower bracket: 5.2228e+10
#   level 0.678: [8.3473e+10, 2.4897e+11] (phys)
#   level 0.954: [5.2898e+10, 2.7905e+11] (phys)
# Band saved as T40/scenario_bkg_b/bands/band_bkgb_idx140_bkgpen.json
# === index 150 ===
# [band idx=150] v0=1.1751e+11 (phys), bracketing with step=1.5
#   upper bracket: 2.6440e+11
#   lower bracket: 1.0317e+10
#   level 0.678: [2.4968e+10, 2.1866e+11] (phys)
#   level 0.954: [1.0416e+10, 2.4198e+11] (phys)
# Band saved as T40/scenario_bkg_b/bands/band_bkgb_idx150_bkgpen.json
# === index 160 ===
# [band idx=160] v0=1.1751e+11 (phys), bracketing with step=1.5
#   upper bracket: 2.6440e+11
#   lower edge reaches 0 / unbounded below
#   level 0.678: [0.0000e+00, 1.6971e+11] (phys)
#   level 0.954: [0.0000e+00, 1.8781e+11] (phys)
# Band saved as T40/scenario_bkg_b/bands/band_bkgb_idx160_bkgpen.json
# === index 167 ===
# [band idx=167] v0=0.0000e+00 (phys), bracketing with step=1.5
#   upper edge unbounded (still inside at max_bracket)
#   lower edge reaches 0 / unbounded below
#   level 0.678: [0.0000e+00, inf] (phys)
#   level 0.954: [0.0000e+00, inf] (phys)
# Band saved as T40/scenario_bkg_b/bands/band_bkgb_idx167_bkgpen.json

# %%
# Load the saved bands and overlay them on the optimize result
# band_files can be a glob pattern or an explicit list
a.plot_flux_with_bands(
    f'scenario_bkg_b/bands/band_bkg{a.background_scenario}_idx*.json',
    levels=(0.678, 0.954),   # Levels to plot (omit to show all saved levels)
    save=True,
    ylim=(0, 3e13),                # So the high-flux tail is visible
)
import matplotlib.pyplot as plt
#plt.yscale('log')
plt.ylim(0, 2e12)
plt.show()

# %%
# Load the saved bands and overlay them on the optimize result
# band_files can be a glob pattern or an explicit list
a.plot_flux_with_bands(
    f'scenario_bkg_b/bands/band_bkg{a.background_scenario}_idx*.json',
    levels=(0.678, 0.954),   # Levels to plot (omit to show all saved levels)
    save=True,
    ylim=(0, 3e13),                # So the high-flux tail is visible
)
import matplotlib.pyplot as plt
plt.yscale('log')
plt.ylim(1e11, 1e14)
plt.show()
