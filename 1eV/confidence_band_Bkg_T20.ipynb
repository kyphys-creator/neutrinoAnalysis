# %% [markdown]
# # 信頼バンドの根探索 (`find_confidence_band`)
#
# 等間隔グリッドの代わりに、ブラケット＋幾何二分法でバンドの上下端を直接探す例。
# 最も広い 2σ で外側をブラケットし、各レベル (1σ/90%/2σ) の端を入れ子で詰める。
#
# - `num_pseudo_data`: ブラケット段階の擬似データ数（粗くてよい）
# - `n_pseudo_edge`: 端の二分法で使う擬似データ数（cutoff のノイズを抑えるため大きめ）
# - `seed`: 固定すると各点が再現可能になり、二分法のジッターが減る

# %%
from neutrino_analysis_band import NeutrinoAnalysis

# %%
a = NeutrinoAnalysis(background_scenario='b', intervals='180',
                     GeV=1e16, solver='osqp', T=20)
a.optimize(a.data_vector)   # ベストフィットを先に求める (self.result を埋める)
result_b = a.optimize(a.data_vector)
print("\nOptimization Complete.")
print(f"Minimum chi-squared: {result_b.fun / a.c}")
# 3. Plot the primary result: the optimized flux vs. theory.
a.plot_flux_comparison(save = True)
# Out:
# Optimization Complete.
# Minimum chi-squared: 0.00016664752574637858
# Plot saved as T20/scenario_bkg_b/flux_comparison_bkg_b.pdf

# %% [markdown]
# ## 複数インデックスのバンドを保存して重ねる
#
# 1. インデックスごとに `find_and_save_band` を実行し、`bands/` 配下に 1 ファイルずつ JSON で保存する。
# 2. `plot_flux_with_bands` で保存済みファイルを読み込み、`optimize` の最適フラックス（散布図）の上に各インデックスのバンドを誤差棒として重ねる。
#
# `save_band` / `load_band` は JSON 形式（人が読める）。バンドの中心は保存時の `self.result.x[index]` なので、同じ `optimize` 結果の散布図とちょうど重なる。

# %%
# 自動で T 別フォルダに保存（outdir 省略可）
# → T3/scenario_bkg_flat/bands/band_bkgflat_idx000.json

# 複数インデックスでバンドを作り、インデックスごとに 1 ファイルへ保存
# 保存先は ./bands/band_bkg<scenario>_idx<NNN>.json
indices = [1, 2, 3, 4, 5, 8, 13, 16, 20, 25, 30, 40, 50, 60, 70, 80, 90, 100, 110, 120, 130, 140, 150, 160, 167]     # 走らせたいインデックス

for idx in indices:
    print(f'=== index {idx} ===')
    a.find_and_save_band(
        idx,
        outdir='T20/scenario_bkg_b/bands',
        levels=(0.678, 0.954),
        num_pseudo_data=50,
        n_pseudo_edge=500,
        step=1.5,
        rel_tol=0.03,
        seed=42,
        n_jobs=1,
        verbose=True,
    )
# Out:
# === index 1 ===
# [band idx=1] v0=1.2447e+12 (phys), bracketing with step=1.5
#   upper bracket: 4.7852e+13
#   lower bracket: 8.2982e+11
#   level 0.678: [1.0036e+12, 2.2482e+13] (phys)
#   level 0.954: [9.3013e+11, 3.3510e+13] (phys)
# Band saved as T20/scenario_bkg_b/bands/band_bkgb_idx001.json
# === index 2 ===
# [band idx=2] v0=2.4346e+12 (phys), bracketing with step=1.5
#   upper bracket: 2.7731e+13
#   lower bracket: 7.2136e+11
#   level 0.678: [1.0061e+12, 1.3341e+13] (phys)
#   level 0.954: [9.3240e+11, 1.9886e+13] (phys)
# Band saved as T20/scenario_bkg_b/bands/band_bkgb_idx002.json
# === index 3 ===
# [band idx=3] v0=2.1800e+12 (phys), bracketing with step=1.5
#   upper bracket: 1.6555e+13
#   lower bracket: 6.4593e+11
#   level 0.678: [1.0097e+12, 9.1408e+12] (phys)
#   level 0.954: [9.1814e+11, 1.3368e+13] (phys)
# Band saved as T20/scenario_bkg_b/bands/band_bkgb_idx003.json
# === index 4 ===
# [band idx=4] v0=1.9663e+12 (phys), bracketing with step=1.5
#   upper bracket: 9.9546e+12
#   lower bracket: 8.7392e+11
#   level 0.678: [1.0047e+12, 6.5533e+12] (phys)
#   level 0.954: [9.3116e+11, 9.8300e+12] (phys)
# Band saved as T20/scenario_bkg_b/bands/band_bkgb_idx004.json
# === index 5 ===
# [band idx=5] v0=1.7841e+12 (phys), bracketing with step=1.5
#   upper bracket: 9.0321e+12
#   lower bracket: 7.9294e+11
#   level 0.678: [1.0089e+12, 5.2384e+12] (phys)
#   level 0.954: [9.3500e+11, 7.4693e+12] (phys)
# Band saved as T20/scenario_bkg_b/bands/band_bkgb_idx005.json
# === index 8 ===
# [band idx=8] v0=1.4007e+12 (phys), bracketing with step=1.5
#   upper bracket: 4.7274e+12
#   lower bracket: 6.2254e+11
#   level 0.678: [9.9497e+11, 2.9677e+12] (phys)
#   level 0.954: [9.2213e+11, 3.9467e+12] (phys)
# Band saved as T20/scenario_bkg_b/bands/band_bkgb_idx008.json
# === index 13 ===
# [band idx=13] v0=1.1618e+12 (phys), bracketing with step=1.5
#   upper bracket: 2.6140e+12
#   lower bracket: 7.7451e+11
#   level 0.678: [1.0107e+12, 1.7209e+12] (phys)
#   level 0.954: [9.1327e+11, 2.1076e+12] (phys)
# Band saved as T20/scenario_bkg_b/bands/band_bkgb_idx013.json
# === index 16 ===
# [band idx=16] v0=1.1169e+12 (phys), bracketing with step=1.5
#   upper bracket: 1.6754e+12
#   lower bracket: 7.4461e+11
#   level 0.678: [9.9662e+11, 1.4949e+12] (phys)
#   level 0.954: [9.2366e+11, 1.6544e+12] (phys)
# Band saved as T20/scenario_bkg_b/bands/band_bkgb_idx016.json
# === index 20 ===
# [band idx=20] v0=1.0982e+12 (phys), bracketing with step=1.5
#   upper bracket: 1.6473e+12
#   lower bracket: 7.3212e+11
#   level 0.678: [9.7991e+11, 1.3623e+12] (phys)
#   level 0.954: [9.0817e+11, 1.4331e+12] (phys)
# Band saved as T20/scenario_bkg_b/bands/band_bkgb_idx020.json
# === index 25 ===
# [band idx=25] v0=1.0911e+12 (phys), bracketing with step=1.5
#   upper bracket: 1.6367e+12
#   lower bracket: 7.2743e+11
#   level 0.678: [9.2550e+11, 1.2866e+12] (phys)
#   level 0.954: [8.5775e+11, 1.3535e+12] (phys)
# Band saved as T20/scenario_bkg_b/bands/band_bkgb_idx025.json
# === index 30 ===
# [band idx=30] v0=1.0509e+12 (phys), bracketing with step=1.5
#   upper bracket: 1.5763e+12
#   lower bracket: 7.0058e+11
#   level 0.678: [8.6904e+11, 1.2081e+12] (phys)
#   level 0.954: [8.2609e+11, 1.2709e+12] (phys)
# Band saved as T20/scenario_bkg_b/bands/band_bkgb_idx030.json
# === index 40 ===
# [band idx=40] v0=9.2344e+11 (phys), bracketing with step=1.5
#   upper bracket: 1.3852e+12
#   lower bracket: 6.1563e+11
#   level 0.678: [7.8326e+11, 1.0889e+12] (phys)
#   level 0.954: [7.2592e+11, 1.1168e+12] (phys)
# Band saved as T20/scenario_bkg_b/bands/band_bkgb_idx040.json
# === index 50 ===
# [band idx=50] v0=8.2711e+11 (phys), bracketing with step=1.5
#   upper bracket: 1.2407e+12
#   lower bracket: 5.5141e+11
#   level 0.678: [6.8400e+11, 9.7530e+11] (phys)
#   level 0.954: [6.5020e+11, 1.0260e+12] (phys)
# Band saved as T20/scenario_bkg_b/bands/band_bkgb_idx050.json
# === index 60 ===
# [band idx=60] v0=7.3333e+11 (phys), bracketing with step=1.5
#   upper bracket: 1.1000e+12
#   lower bracket: 4.8889e+11
#   level 0.678: [5.9127e+11, 8.6471e+11] (phys)
#   level 0.954: [5.4798e+11, 9.3301e+11] (phys)
# Band saved as T20/scenario_bkg_b/bands/band_bkgb_idx060.json
# === index 70 ===
# [band idx=70] v0=6.4237e+11 (phys), bracketing with step=1.5
#   upper bracket: 9.6355e+11
#   lower bracket: 4.2825e+11
#   level 0.678: [5.0497e+11, 7.7689e+11] (phys)
#   level 0.954: [4.6800e+11, 8.3826e+11] (phys)
# Band saved as T20/scenario_bkg_b/bands/band_bkgb_idx070.json
# === index 80 ===
# [band idx=80] v0=5.5358e+11 (phys), bracketing with step=1.5
#   upper bracket: 8.3037e+11
#   lower bracket: 3.6905e+11
#   level 0.678: [4.2428e+11, 6.8670e+11] (phys)
#   level 0.954: [3.9322e+11, 7.4094e+11] (phys)
# Band saved as T20/scenario_bkg_b/bands/band_bkgb_idx080.json
# === index 90 ===
# [band idx=90] v0=4.6577e+11 (phys), bracketing with step=1.5
#   upper bracket: 6.9865e+11
#   lower bracket: 3.1051e+11
#   level 0.678: [3.3934e+11, 6.0781e+11] (phys)
#   level 0.954: [3.1450e+11, 6.3941e+11] (phys)
# Band saved as T20/scenario_bkg_b/bands/band_bkgb_idx090.json
# === index 100 ===
# [band idx=100] v0=3.8663e+11 (phys), bracketing with step=1.5
#   upper bracket: 5.7995e+11
#   lower bracket: 1.7184e+11
#   level 0.678: [2.8168e+11, 5.0454e+11] (phys)
# Failure:interrupted

# %%
# 保存したバンドを読み込んで optimize 結果の上に重ねる
# band_files はグロブパターンでも、明示的なリストでもよい
a.plot_flux_with_bands(
    f'scenario_bkg_b/bands/band_bkg{a.background_scenario}_idx*.json',
    levels=(0.678, 0.954),   # 表示するレベル (省略すると保存済み全レベル)
    save=True,
    ylim=(0, 3e13),                # 高フラックス側の裾まで見えるように
)
import matplotlib.pyplot as plt
#plt.yscale('log')
plt.ylim(0, 2e12)
plt.show()

# %%
# 保存したバンドを読み込んで optimize 結果の上に重ねる
# band_files はグロブパターンでも、明示的なリストでもよい
a.plot_flux_with_bands(
    f'scenario_bkg_b/bands/band_bkg{a.background_scenario}_idx*.json',
    levels=(0.678, 0.954),   # 表示するレベル (省略すると保存済み全レベル)
    save=True,
    ylim=(0, 3e13),                # 高フラックス側の裾まで見えるように
)
import matplotlib.pyplot as plt
plt.yscale('log')
plt.ylim(1e11, 1e14)
plt.show()
