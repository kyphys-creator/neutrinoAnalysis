# %%
from neutrino_analysis_band import NeutrinoAnalysis

# %%
# Run optimize() on each scenario first
a_flat = NeutrinoAnalysis(background_scenario='flat', intervals='180', GeV=0.32e16, solver='scipy', T=300)
a_flat.optimize(a_flat.data_vector)
a_a = NeutrinoAnalysis(background_scenario='a', intervals='180', GeV=0.36e16, solver='scipy', T=300)
a_a.optimize(a_a.data_vector)
a_b = NeutrinoAnalysis(background_scenario='b', intervals='180', GeV=0.6e16, solver='scipy', T=300)
a_b.optimize(a_b.data_vector)
# Out:
#            message: `xtol` termination condition is satisfied.
#            success: True
#             status: 2
#                fun: 1.5528664846366263e+65
#                  x: [ 6.892e+07  6.892e+07 ...  9.707e-17  9.706e-17]
#                nit: 20816
#               nfev: 20902
#               njev: 20558
#               nhev: 20558
#           cg_niter: 3675913
#       cg_stop_cond: 2
#               grad: [ 1.390e+52  1.804e+52 ...  1.448e+54  1.501e+54]
#    lagrangian_grad: [ 7.373e+52  7.373e+52 ... -3.403e+38  0.000e+00]
#             constr: [array([ 0.000e+00,  0.000e+00, ...,  2.951e-17,
#                             9.008e-21], shape=(179,)), array([ 6.892e+07,  6.892e+07, ...,  9.707e-17,
#                             9.706e-17], shape=(180,))]
#                jac: [<Compressed Sparse Row sparse array of dtype 'float64'
#                     	with 358 stored elements and shape (179, 180)>, <Compressed Sparse Row sparse array of dtype 'float64'
#                     	with 180 stored elements and shape (180, 180)>]
#        constr_nfev: [0, 0]
#        constr_njev: [0, 0]
#        constr_nhev: [0, 0]
#                  v: [array([ 5.984e+52,  1.155e+53, ..., -7.230e+53,
#                            -3.352e+53], shape=(179,)), array([-1.552e+37, -1.552e+37, ..., -1.835e+54,
#                            -1.836e+54], shape=(180,))]
#             method: tr_interior_point
#         optimality: 1.1145283086001651e+54
#   constr_violation: 0.0
#     execution_time: 207.83182406425476
#          tr_radius: 5.000000000000002e-10
#     constr_penalty: 1.0
#  barrier_parameter: 2.048000000000001e-09
#  barrier_tolerance: 2.048000000000001e-09
#              niter: 20816

# %%
a_b.plot_band_comparison(
    {r'Exp Bkg 1$\sigma$ CL':    'T40/scenario_bkg_b/bands/band_*.json',
     r'No Bkg 1$\sigma$ CL': 'T40/scenario_bkg_a/bands/band_*.json',},
    level=0.678,
    optimized={'Exp Bkg': a_b},   # Overlay each scenario's optimize result
    ylim=(0, 2e12), save=True,
    fname='band_comparison_T40_1sigma_edge.pdf',
    logy = False
)
# Out:
# Plot saved as band_comparison_T40_1sigma_edge.pdf

# %%
a_b.plot_band_comparison(
    {r'Exp Bkg 1$\sigma$ CL':    'T40/scenario_bkg_b/bands/band_*.json',
     r'No Bkg 1$\sigma$ CL': 'T40/scenario_bkg_a/bands/band_*.json',},
    level=0.678,
    optimized={'Exp Bkg': a_b},   # Overlay each scenario's optimize result
    ylim=(1e11, 3e13), save=True,
    fname='band_comparison_T40_1sigma_edge.pdf',
    logy = True
)
# Out:
# Plot saved as band_comparison_T40_1sigma_edge.pdf

# %%
a_b.plot_band_comparison(
    {r'Exp Bkg 2$\sigma$ CL':    'T40/scenario_bkg_b/bands/band_*.json',
     r'No Bkg 2$\sigma$ CL': 'T40/scenario_bkg_a/bands/band_*.json',},
    level=0.954,
    optimized={'Exp Bkg': a_b},   # Overlay each scenario's optimize result
    ylim=(0, 2e12), save=True,
    fname='band_comparison_T40_2sigma_edge.pdf',
    logy = False
)
# Out:
# Plot saved as band_comparison_T40_2sigma_edge.pdf

# %%
a_b.plot_band_comparison(
    {r'Exp Bkg 2$\sigma$ CL':    'T40/scenario_bkg_b/bands/band_*.json',
     r'No Bkg 2$\sigma$ CL': 'T40/scenario_bkg_a/bands/band_*.json',},
    level=0.954,
    optimized={'Exp Bkg': a_b},   # Overlay each scenario's optimize result
    ylim=(1e11, 3e13), save=True,
    fname='band_comparison_T40_2sigma_edge.pdf',
    logy = True
)
# Out:
# Plot saved as band_comparison_T40_2sigma_edge.pdf

# %% [markdown]
# ### Comparison

# %%
a_b.plot_band_comparison(
    {r'Exp Bkg 3 kg year 1$\sigma$ CL': 'T3/scenario_bkg_b/bands/band_*.json',
     r'Exp Bkg 20 kg year 1$\sigma$ CL':    'T20/scenario_bkg_b/bands/band_*.json',
     r'Exp Bkg 30 kg year 1$\sigma$ CL':    'T30/scenario_bkg_b/bands/band_*.json',
     r'Exp Bkg 40 kg year 1$\sigma$ CL':    'T40/scenario_bkg_b/bands/band_*.json',},
    level=0.678,
    optimized={'Exp Bkg': a_b},   # Overlay each scenario's optimize result
    ylim=(0, 2e12), save=True,
    fname='band_comparison_Tvaried_1sigma_edge.pdf',
    logy = False
)
# Out:
# Plot saved as band_comparison_Tvaried_1sigma_edge.pdf

# %%
a_b.plot_band_comparison(
    {r'Exp Bkg 3 kg year 2$\sigma$ CL': 'T3/scenario_bkg_b/bands/band_*.json',
     r'Exp Bkg 20 kg year 2$\sigma$ CL':    'T20/scenario_bkg_b/bands/band_*.json',
     r'Exp Bkg 30 kg year 2$\sigma$ CL':    'T30/scenario_bkg_b/bands/band_*.json',
     r'Exp Bkg 40 kg year 2$\sigma$ CL':    'T40/scenario_bkg_b/bands/band_*.json',},
    level=0.954,
    optimized={'Exp Bkg': a_b},   # Overlay each scenario's optimize result
    ylim=(0, 2e12), save=True,
    fname='band_comparison_Tvaried_2sigma_edge.pdf',
    logy = False
)
# Out:
# Plot saved as band_comparison_Tvaried_2sigma_edge.pdf

# %% [markdown]
# ### Individual bands

# %%
# Load the saved bands and overlay them on the optimize result
# band_files can be a glob pattern or an explicit list
a_a.plot_flux_with_bands(
    f'T40/scenario_bkg_a/bands/band_bkg{a_a.background_scenario}_idx*.json',
    levels=(0.678, 0.954),   # Levels to plot (omit to show all saved levels)
    save=True,
    ylim=(0, 3e13),                # So the high-flux tail is visible
)
import matplotlib.pyplot as plt
plt.ylim(0, 2e12)
plt.show()
# Out:
# Plot saved as T300/scenario_bkg_a/flux_with_bands_bkg_a.pdf

# %%
# Load the saved bands and overlay them on the optimize result
# band_files can be a glob pattern or an explicit list
a_a.plot_flux_with_bands(
    f'T40/scenario_bkg_a/bands/band_bkg{a_a.background_scenario}_idx*.json',
    levels=(0.678, 0.954),   # Levels to plot (omit to show all saved levels)
    save=True,
    ylim=(0, 3e13),                # So the high-flux tail is visible
)
import matplotlib.pyplot as plt
plt.yscale('log')
plt.ylim(1e10, 7e13)
plt.show()
# Out:
# Plot saved as T300/scenario_bkg_a/flux_with_bands_bkg_a.pdf

# %%
# Load the saved bands and overlay them on the optimize result
# band_files can be a glob pattern or an explicit list
a_b.plot_flux_with_bands(
    f'T40/scenario_bkg_b/bands/band_bkg{a_b.background_scenario}_idx*.json',
    levels=(0.678, 0.954),   # Levels to plot (omit to show all saved levels)
    save=True,
    ylim=(0, 3e13),                # So the high-flux tail is visible
)
import matplotlib.pyplot as plt
plt.ylim(0, 2e12)
plt.show()
# Out:
# Plot saved as T300/scenario_bkg_b/flux_with_bands_bkg_b.pdf

# %%
# Load the saved bands and overlay them on the optimize result
# band_files can be a glob pattern or an explicit list
a_b.plot_flux_with_bands(
    f'T40/scenario_bkg_b/bands/band_bkg{a_b.background_scenario}_idx*.json',
    levels=(0.678, 0.954),   # Levels to plot (omit to show all saved levels)
    save=True,
    ylim=(0, 3e13),                # So the high-flux tail is visible
)
import matplotlib.pyplot as plt
plt.yscale('log')
plt.ylim(1e10, 8e13)
plt.show()
# Out:
# Plot saved as T300/scenario_bkg_b/flux_with_bands_bkg_b.pdf
