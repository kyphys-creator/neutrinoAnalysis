# %%
from neutrino_analysis_band import NeutrinoAnalysis

# %%
# Run optimize() on each scenario first
a_flat = NeutrinoAnalysis(background_scenario='flat', intervals='180', GeV=0.32e16, solver='scipy', T=300)
a_flat.optimize(a_flat.data_vector)
a_a = NeutrinoAnalysis(background_scenario='a', intervals='180', GeV=0.36e16, solver='scipy', T=300)
a_a.optimize(a_a.data_vector)
a_b = NeutrinoAnalysis(background_scenario='b', intervals='180', GeV=0.6e16, solver='scipy', T=300)
a_b.optimize(a_b.data_vector)
# Out:
#            message: `xtol` termination condition is satisfied.
#            success: True
#             status: 2
#                fun: 1.5528664846188488e+65
#                  x: [ 6.892e+07  6.892e+07 ...  6.380e-17  1.056e-16]
#                nit: 20822
#               nfev: 20816
#               njev: 20562
#               nhev: 20562
#           cg_niter: 3676478
#       cg_stop_cond: 2
#               grad: [-0.000e+00 -0.000e+00 ...  2.909e+52  3.096e+52]
#    lagrangian_grad: [-1.816e+50 -1.816e+50 ... -5.317e+36  0.000e+00]
#             constr: [array([ 0.000e+00,  0.000e+00, ...,  3.796e-16,
#                            -4.176e-17], shape=(179,)), array([ 6.892e+07,  6.892e+07, ...,  6.380e-17,
#                             1.056e-16], shape=(180,))]
#                jac: [<Compressed Sparse Row sparse array of dtype 'float64'
#                     	with 358 stored elements and shape (179, 180)>, <Compressed Sparse Row sparse array of dtype 'float64'
# ...

# %%
a_b.plot_band_comparison(
    {r'1$\sigma$ CL: Exp Bkg':    'T50/scenario_bkg_b/bands/band_*_bkgpen.json',
     r'1$\sigma$ CL: No Bkg': 'T50/scenario_bkg_a/bands/band_*_bkgpen.json',},
    level=0.678,
    optimized={'Exp Bkg': a_b},   # Overlay each scenario's optimize result
    ylim=(0, 2e12), save=True,
    fname='band_comparison_T50_1sigma.pdf',
    logy = False,
    style = 'both',
    degeneracy_files='T50/scenario_bkg_b/degeneracy/degeneracy_bkgb_idx*.json',
    show_errorbars=False,
    bestfit_marker= '.'
)
# Out:
# Plot saved as band_comparison_T40_1sigma.pdf

# %%
a_b.plot_band_comparison(
    {r'1$\sigma$ CL: Exp Bkg':    'T40/scenario_bkg_b/bands/band_*_bkgpen.json',
     r'1$\sigma$ CL: No Bkg': 'T40/scenario_bkg_a/bands/band_*_bkgpen.json',},
    level=0.678,
    optimized={'Exp Bkg': a_b},   # Overlay each scenario's optimize result
    ylim=(1e11, 3e13), save=True,
    fname='band_comparison_T40_1sigma_edge.pdf',
    logy = True,
    style = 'both',
    degeneracy_files='T40/scenario_bkg_b/degeneracy/degeneracy_bkgb_idx*.json',
    show_errorbars=False,
    bestfit_marker= '.'
)
# Out:
# Plot saved as band_comparison_T40_1sigma_edge.pdf

# %%
a_b.plot_band_comparison(
    {r'2$\sigma$ CL: Exp Bkg':    'T40/scenario_bkg_b/bands/band_*_bkgpen.json',
     r'2$\sigma$ CL: No Bkg': 'T40/scenario_bkg_a/bands/band_*_bkgpen.json',},
    level=0.954,
    optimized={'Exp Bkg': a_b},   # Overlay each scenario's optimize result
    ylim=(0, 2.5e12), save=True,
    fname='1eVband_comparison_T40_2sigma_bkgpen.pdf',
    logy = False,
    style = 'both',
    degeneracy_files='T40/scenario_bkg_b/degeneracy/degeneracy_bkgb_idx*.json',
    show_errorbars=False,
    bestfit_marker= '.'
)
import matplotlib.pyplot as plt
plt.xlim(0.1, 3)
plt.ylim(1e-3, 2.5)
plt.savefig('1eVband_comparison_T40_2sigma_bkgpen.pdf')
# Out:
# Plot saved as 1eVband_comparison_T40_2sigma_bkgpen.pdf

# %%
a_b.plot_band_comparison(
    {r'2$\sigma$ CL: Exp Bkg':    'T40/scenario_bkg_b/bands/band_*_bkgpen.json',
     r'2$\sigma$ CL: No Bkg': 'T40/scenario_bkg_a/bands/band_*_bkgpen.json',},
    level=0.954,
    optimized={'Exp Bkg': a_b},   # Overlay each scenario's optimize result
    ylim=(1e11, 8e13), save=True,
    fname='1eVband_comparison_T40_2sigma_edge_bkgpen.pdf',
    logy = True,
    style = 'both',
    degeneracy_files='T40/scenario_bkg_b/degeneracy/degeneracy_bkgb_idx*.json',
    show_errorbars=False,
    bestfit_marker= '.'
)
# Out:
# Plot saved as 1eVband_comparison_T40_2sigma_edge_bkgpen.pdf

# %% [markdown]
# ### Comparison

# %%
a_b.plot_band_comparison(
    {r'1$\sigma$ CL: Exp Bkg 3 kg year': 'T3/scenario_bkg_b/bands/band_*.json',
     r'1$\sigma$ CL: Exp Bkg 40 kg year':    'T40/scenario_bkg_b/bands/band_*.json',},
    level=0.678,
    optimized={'Exp Bkg': a_b},   # Overlay each scenario's optimize result
    ylim=(0, 2e12), save=True,
    fname='band_comparison_Tvaried_1sigma.pdf',
    logy = False,
    style = 'both',
    show_errorbars=False,
    bestfit_marker= '.'
)
import matplotlib.pyplot as plt
plt.xlim(0.1, 3)
plt.ylim(1e-3, 2.5)
plt.savefig('1eVband_comparison_Tvaried_1sigma.pdf')
# Out:
# Plot saved as band_comparison_Tvaried_1sigma.pdf

# %%
a_b.plot_band_comparison(
    {r'2$\sigma$ CL: Exp Bkg 3 kg year': 'T3/scenario_bkg_b/bands/band_*_bkgpen.json',
     r'2$\sigma$ CL: Exp Bkg 40 kg year':    'T40/scenario_bkg_b/bands/band_*_bkgpen.json',},
    level=0.954,
    optimized={'Exp Bkg': a_b},   # Overlay each scenario's optimize result
    ylim=(0, 3e12), save=True,
    fname='band_comparison_Tvaried_2sigma.pdf',
    logy = False,
    style = 'both',
    show_errorbars=False,
    bestfit_marker= '.'
)
import matplotlib.pyplot as plt
plt.xlim(0.1, 3)
plt.ylim(1e-3, 2.5)
plt.savefig('1eVband_comparison_Tvaried_2sigma.pdf')
# Out:
# Plot saved as band_comparison_Tvaried_2sigma.pdf

# %% [markdown]
# ### Individual bands

# %%
# Load the saved bands and overlay them on the optimize result
# band_files can be a glob pattern or an explicit list
a_a.plot_flux_with_bands(
    f'T40/scenario_bkg_a/bands/band_bkg{a_a.background_scenario}_idx*.json',
    levels=(0.678, 0.954),   # Levels to plot (omit to show all saved levels)
    save=True,
    ylim=(0, 3e13),                # So the high-flux tail is visible
)
import matplotlib.pyplot as plt
plt.ylim(0, 2)
plt.show()
# Out:
# Plot saved as T300/scenario_bkg_a/flux_with_bands_bkg_a.pdf

# %%
# Load the saved bands and overlay them on the optimize result
# band_files can be a glob pattern or an explicit list
a_a.plot_flux_with_bands(
    f'T40/scenario_bkg_a/bands/band_bkg{a_a.background_scenario}_idx*.json',
    levels=(0.678, 0.954),   # Levels to plot (omit to show all saved levels)
    save=True,
    ylim=(0, 3e13),                # So the high-flux tail is visible
)
import matplotlib.pyplot as plt
plt.yscale('log')
plt.ylim(1e-1, 7e1)
plt.show()
# Out:
# Plot saved as T300/scenario_bkg_a/flux_with_bands_bkg_a.pdf

# %%
# Load the saved bands and overlay them on the optimize result
# band_files can be a glob pattern or an explicit list
a_b.plot_flux_with_bands(
    f'T40/scenario_bkg_b/bands/band_bkg{a_b.background_scenario}_idx*.json',
    levels=(0.678, 0.954),   # Levels to plot (omit to show all saved levels)
    save=True,
    ylim=(0, 3e13),                # So the high-flux tail is visible
)
import matplotlib.pyplot as plt
plt.ylim(0, 2)
plt.show()
# Out:
# Plot saved as T300/scenario_bkg_b/flux_with_bands_bkg_b.pdf

# %%
# Load the saved bands and overlay them on the optimize result
# band_files can be a glob pattern or an explicit list
a_b.plot_flux_with_bands(
    f'T40/scenario_bkg_b/bands/band_bkg{a_b.background_scenario}_idx*.json',
    levels=(0.678, 0.954),   # Levels to plot (omit to show all saved levels)
    save=True,
    ylim=(0, 3e13),                # So the high-flux tail is visible
)
import matplotlib.pyplot as plt
plt.yscale('log')
plt.ylim(1e-1, 8e1)
plt.show()
# Out:
# Plot saved as T300/scenario_bkg_b/flux_with_bands_bkg_b.pdf
