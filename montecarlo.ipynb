# %%
from neutrino_analysis_fast import NeutrinoAnalysis

# OSQP で爆速モード
a = NeutrinoAnalysis(background_scenario='flat', intervals='180',
                     GeV=0.32e16, solver='scipy')

# あるいは元コードに近い scipy で
#a = NeutrinoAnalysis(background_scenario='flat', solver='scipy')

# 途中でも切り替え可能
#a.set_solver('osqp')

# %%
a = NeutrinoAnalysis(background_scenario='flat', intervals='180',
                     GeV=0.32e16, solver='scipy')
result_flat = a.optimize(a.data_vector)
print("\nOptimization Complete.")
print(f"Minimum chi-squared: {result_flat.fun / a.c}")
# 3. Plot the primary result: the optimized flux vs. theory.
a.plot_flux_comparison(save = True)
# Out:
# Optimization Complete.
# Minimum chi-squared: 3.813569201894367e-30
# Plot saved as scenario_bkg_flat/flux_comparison_bkg_flat.pdf

# %%
a2 = NeutrinoAnalysis(background_scenario='flat', intervals='180',
                     GeV=1e10, solver='osqp')
result_flat2 = a2.optimize(a.data_vector)
print("\nOptimization Complete.")
print(f"Minimum chi-squared: {result_flat2.fun / a2.c}")
# 3. Plot the primary result: the optimized flux vs. theory.
a2.plot_flux_comparison(save = True)
# Out:
# Optimization Complete.
# Minimum chi-squared: 1.8032282826505587e-18
# Plot saved as scenario_bkg_flat/flux_comparison_bkg_flat.pdf

# %%
a.optimize(a.data_vector)        # ベストフィットを先に求める（self.result を埋める）

scan39 = a.scan_fixed_parameter(
    39, scan_range=0.95, num_points=21,
    num_pseudo_data=100, seed=42,
)
# Out:
# /Users/koichiromacstudio/miniforge3/lib/python3.12/site-packages/scipy/optimize/_trustregion_constr/projections.py:53: RuntimeWarning: invalid value encountered in scalar divide
#   orth = norm_A_g / (norm_A*norm_g)
# /Users/koichiromacstudio/miniforge3/lib/python3.12/site-packages/scipy/optimize/_trustregion_constr/tr_interior_point.py:250: RuntimeWarning: overflow encountered in multiply
#   return np.hstack((Hx.dot(vec_x), S_Hs_S*vec_s))
# /Users/koichiromacstudio/miniforge3/lib/python3.12/site-packages/scipy/optimize/_trustregion_constr/qp_subproblem.py:573: RuntimeWarning: invalid value encountered in scalar divide
#   alpha = rt_g / pt_H_p
# [Scan idx=39] 41 points, solver=scipy
#
# --- [1/41] flux=3.2407e+68 ---
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 3
#       1 a.optimize(a.data_vector)        # ベストフィットを先に求める（self.result を埋める）
# ----> 3 scan39 = a.scan_fixed_parameter(
#       4     39, scan_range=0.95, num_points=21,
#       5     num_pseudo_data=100, seed=42,
#       6 )
#
# File ~/Documents/Claude/neutrinoAnalysis/neutrino_analysis_fast.py:620, in NeutrinoAnalysis.scan_fixed_parameter(self, fixed_index, scan_range, num_points, num_pseudo_data, seed, n_jobs)
#     618 for i, fv in enumerate(fixed_values, 1):
#     619     print(f"\n--- [{i}/{total}] flux={self.cm**2 * self.sec * fv:.4e} ---")
# --> 620     self.run_full_monte_carlo_analysis(
#     621         num_pseudo_data=num_pseudo_data,
#     622         fixed_index=fixed_index,
#     623         fixed_value=fv,
#     624         seed=seed,
#     625         n_jobs=n_jobs,
#     626         verbose=False,
#     627     )
#     628     in68 = self.analyze_monte_carlo_results(fv, 0.678);  c68 = self.delta_chi2_cutoff
#     629     in90 = self.analyze_monte_carlo_results(fv, 0.90);   c90 = self.delta_chi2_cutoff
#
# File ~/Documents/Claude/neutrinoAnalysis/neutrino_analysis_fast.py:563, in NeutrinoAnalysis.run_full_monte_carlo_analysis(self, num_pseudo_data, fixed_index, fixed_value, seed, n_jobs, verbose)
#     561 self.fit_results = []
#     562 for i, pd_ in enumerate(self.pseudo_data_scaled, 1):
# --> 563     r = self._fit_one_pseudo(pd_, fixed_index, fixed_value, x0_seed, self)
#     564     if verbose:
#     565         print(f"  [{i}/{num_pseudo_data}] "
#     566               f"χ²_free={r.get('chi2_free')}  "
#     567               f"χ²_fix={r.get('chi2_fixed')}  Δχ²={r.get('delta_chi2')}")
#
# File ~/Documents/Claude/neutrinoAnalysis/neutrino_analysis_fast.py:498, in NeutrinoAnalysis._fit_one_pseudo(pseudo_data_scaled, fixed_index, fixed_value, x0_seed, analysis)
#     496 result_dict = {}
#     497 try:
# --> 498     res_free = analysis.optimize(pseudo_data_scaled / analysis.T,
#     499                                  x0=x0_seed.copy(), display=False)
#     500     result_dict.update(chi2_free=res_free.fun / analysis.c,
#     501                        x_free=res_free.x,
#     502                        success_free=res_free.success)
#     503 except Exception as e:
#
# File ~/Documents/Claude/neutrinoAnalysis/neutrino_analysis_fast.py:434, in NeutrinoAnalysis.optimize(self, data, x0, display)
#     432     res = self._backend.solve(data, x0=x0, display=display)
#     433 else:
# --> 434     res = self._backend.solve(data, x0, extra_constraints=None, display=display)
#     435 self.result = res
#     436 return res
#
# File ~/Documents/Claude/neutrinoAnalysis/neutrino_analysis_fast.py:108, in _ScipyBackend.solve(self, data, x0, extra_constraints, display)
#     105 if display:
#     106     options['verbose'] = 3
# --> 108 return minimize(
#     109     fun, x0, method='trust-constr',
#     110     jac=jac, hess=hess,
#     111     bounds=[(p.eps, None)] * p.n,
#     112     constraints=cons, options=options,
#     113 )
#
# File ~/miniforge3/lib/python3.12/site-packages/scipy/optimize/_minimize.py:800, in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     797     res = _minimize_slsqp(fun, x0, args, jac, bounds,
#     798                           constraints, callback=callback, **options)
#     799 elif meth == 'trust-constr':
# --> 800     res = _minimize_trustregion_constr(fun, x0, args, jac, hess, hessp,
#     801                                        bounds, constraints,
#     802                                        callback=callback, **options)
#     803 elif meth == 'dogleg':
#     804     res = _minimize_dogleg(fun, x0, args, jac, hess,
#     805                            callback=callback, **options)
#
# File ~/miniforge3/lib/python3.12/site-packages/scipy/optimize/_trustregion_constr/minimize_trustregion_constr.py:544, in _minimize_trustregion_constr(fun, x0, args, grad, hess, hessp, bounds, constraints, xtol, gtol, barrier_tol, sparse_jacobian, callback, maxiter, verbose, finite_diff_rel_step, initial_constr_penalty, initial_tr_radius, initial_barrier_parameter, initial_barrier_tolerance, factorization_method, disp, workers)
#     535     _, result = equality_constrained_sqp(
#     536         fun_and_constr, grad_and_jac, lagrangian_hess,
#     537         x0, objective.f, objective.g,
#    (...)    540         initial_constr_penalty, initial_tr_radius,
#     541         factorization_method)
#     543 elif method == 'tr_interior_point':
# --> 544     _, result = tr_interior_point(
#     545         objective.fun, objective.grad, lagrangian_hess,
#     546         n_vars, canonical.n_ineq, canonical.n_eq,
#     547         canonical.fun, canonical.jac,
#     548         x0, objective.f, objective.g,
#     549         c_ineq0, J_ineq0, c_eq0, J_eq0,
#     550         stop_criteria,
#     551         canonical.keep_feasible,
#     552         xtol, state, initial_barrier_parameter,
#     553         initial_barrier_tolerance,
#     554         initial_constr_penalty, initial_tr_radius,
#     555         factorization_method, finite_diff_bounds)
#     557 # Status 4 occurs when minimize is successful but constraints are not satisfied.
#     558 if result.status in (1, 2) and state.constr_violation > gtol:
#
# File ~/miniforge3/lib/python3.12/site-packages/scipy/optimize/_trustregion_constr/tr_interior_point.py:336, in tr_interior_point(fun, grad, lagr_hess, n_vars, n_ineq, n_eq, constr, jac, x0, fun0, grad0, constr_ineq0, jac_ineq0, constr_eq0, jac_eq0, stop_criteria, enforce_feasibility, xtol, state, initial_barrier_parameter, initial_tolerance, initial_penalty, initial_trust_radius, factorization_method, finite_diff_bounds)
#     333 # Solves a sequence of barrier problems
#     334 while True:
#     335     # Solve SQP subproblem
# --> 336     z, state = equality_constrained_sqp(
#     337         subprob.function_and_constraints,
#     338         subprob.gradient_and_jacobian,
#     339         subprob.lagrangian_hessian,
#     340         z, fun0_subprob, grad0_subprob,
#     341         constr0_subprob, jac0_subprob, subprob.stop_criteria,
#     342         state, initial_penalty, trust_radius,
#     343         factorization_method, trust_lb, trust_ub, subprob.scaling)
#     344     if subprob.terminate:
#     345         break
#
# File ~/miniforge3/lib/python3.12/site-packages/scipy/optimize/_trustregion_constr/equality_constrained_sqp.py:132, in equality_constrained_sqp(fun_and_constr, grad_and_jac, lagr_hess, x0, fun0, grad0, constr0, jac0, stop_criteria, state, initial_penalty, initial_trust_radius, factorization_method, trust_lb, trust_ub, scaling)
#     130 lb_t = trust_lb - dn
#     131 ub_t = trust_ub - dn
# --> 132 dt, cg_info = projected_cg(H, c_t, Z, Y, b_t,
#     133                            trust_radius_t,
#     134                            lb_t, ub_t)
#     136 # Compute update (normal + tangential steps).
#     137 d = dn + dt
#
# File ~/miniforge3/lib/python3.12/site-packages/scipy/optimize/_trustregion_constr/qp_subproblem.py:499, in projected_cg(H, c, Z, Y, b, trust_radius, lb, ub, tol, max_iter, max_infeasible_iter, return_all)
#     497 x = Y.dot(-b)
#     498 r = Z.dot(H.dot(x) + c)
# --> 499 g = Z.dot(r)
#     500 p = -g
#     502 # Store ``x`` value
#
# File ~/miniforge3/lib/python3.12/site-packages/scipy/sparse/linalg/_interface.py:469, in LinearOperator.dot(self, x)
#     466     x = np.asarray(x)
#     468 if x.ndim == 1 or x.ndim == 2 and x.shape[1] == 1:
# --> 469     return self.matvec(x)
#     470 elif x.ndim == 2:
#     471     return self.matmat(x)
#
# File ~/miniforge3/lib/python3.12/site-packages/scipy/sparse/linalg/_interface.py:258, in LinearOperator.matvec(self, x)
#     255 if x.shape != (N,) and x.shape != (N,1):
#     256     raise ValueError('dimension mismatch')
# --> 258 y = self._matvec(x)
#     260 if isinstance(x, np.matrix):
#     261     y = asmatrix(y)
#
# File ~/miniforge3/lib/python3.12/site-packages/scipy/sparse/linalg/_interface.py:616, in _CustomLinearOperator._matvec(self, x)
#     615 def _matvec(self, x):
# --> 616     return self.__matvec_impl(x)
#
# File ~/miniforge3/lib/python3.12/site-packages/scipy/optimize/_trustregion_constr/projections.py:124, in augmented_system_projections.<locals>.null_space(x)
#     121 v = np.hstack([x, np.zeros(m)])
#     122 # lu_sol = [ z ]
#     123 #          [aux]
# --> 124 lu_sol = solve(v)
#     125 z = lu_sol[:n]
#     127 # Iterative refinement to improve roundoff
#     128 # errors described in [2]_, algorithm 5.2.
#
# KeyboardInterrupt:
