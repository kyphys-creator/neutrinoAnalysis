# %% [markdown]
# # Confidence-band root finder (`find_confidence_band`)
#
# Example: instead of a uniform grid, locate the band edges directly by bracketing + geometric bisection.
# Bracket the outer reach with the widest level (2σ); the narrower 1σ / 90% / 2σ edges nest inside that interval.
#
# - `num_pseudo_data`: pseudo-data sample size during bracketing (can be coarse)
# - `n_pseudo_edge`: pseudo-data sample size for the edge bisection (larger suppresses cutoff noise)
# - `seed`: fixed value makes every evaluation reproducible and stops the bisection from jittering

# %%
from neutrino_analysis_band import NeutrinoAnalysis

a = NeutrinoAnalysis(background_scenario='b', intervals='180',
                     GeV=0.6e16, solver='osqp')
a.optimize(a.data_vector)   # Compute the best fit first (populates self.result)
result_b = a.optimize(a.data_vector)
print("\nOptimization Complete.")
print(f"Minimum chi-squared: {result_b.fun / a.c}")
# 3. Plot the primary result: the optimized flux vs. theory.
a.plot_flux_comparison(save = True)
# Out:
# Optimization Complete.
# Minimum chi-squared: 6.779129900985238e-05
# Plot saved as T3/scenario_bkg_b/flux_comparison_bkg_b.pdf

# %% [markdown]
# ## Save bands for several indices and overlay them
#
# 1. Run `find_and_save_band` per index and save one JSON file per index under `bands/`.
# 2. Load the saved files with `plot_flux_with_bands` and overlay each index's band as an error bar on top of the `optimize` flux scatter.
#
# `save_band` / `load_band` use a human-readable JSON format. The band centre is the saved `self.result.x[index]`, so it lines up exactly with the scatter from the same `optimize` result.

# %%
# Build bands for several indices and save one file per index
# Destination: ./bands/band_bkg<scenario>_idx<NNN>.json
indices = [0, 1, 2, 3, 4, 5, 8, 13, 16, 20, 25, 30, 40, 50, 60, 70, 80, 90, 100, 110, 120, 130, 140, 150, 160, 167]    # Indices to run

for idx in indices:
    print(f'=== index {idx} ===')
    a.find_and_save_band(
        idx,
        outdir='scenario_bkg_b/bands',
        levels=(0.678, 0.954),
        num_pseudo_data=50,
        n_pseudo_edge=500,
        step=1.5,
        rel_tol=0.03,
        seed=42,
        n_jobs=1,
        verbose=True,
        bkg_penalty=True,
    )
# Out:
# === index 0 ===
# [band idx=0] v0=1.0478e+12 (phys), bracketing with step=1.5
#   upper bracket: 2.6854e+13
#   lower bracket: 6.9855e+11
#   level 0.678: [8.4484e+11, 1.1786e+13] (phys)
#   level 0.954: [7.4429e+11, 2.6519e+13] (phys)
# Band saved as scenario_bkg_b/bands/band_bkgb_idx000_bkgpen.json
# === index 1 ===
# [band idx=1] v0=1.0478e+12 (phys), bracketing with step=1.5
#   upper bracket: 1.1935e+13
#   lower bracket: 6.9855e+11
#   level 0.678: [7.8299e+11, 7.6362e+12] (phys)
#   level 0.954: [7.0751e+11, 1.1823e+13] (phys)
# Band saved as scenario_bkg_b/bands/band_bkgb_idx001_bkgpen.json
# === index 2 ===
# [band idx=2] v0=1.0478e+12 (phys), bracketing with step=1.5
#   upper bracket: 7.9569e+12
#   lower bracket: 6.9855e+11
#   level 0.678: [7.8299e+11, 4.6809e+12] (phys)
#   level 0.954: [7.0751e+11, 7.8944e+12] (phys)
# Band saved as scenario_bkg_b/bands/band_bkgb_idx002_bkgpen.json
# === index 3 ===
# [band idx=3] v0=1.0478e+12 (phys), bracketing with step=1.5
#   upper bracket: 5.3046e+12
#   lower bracket: 6.9855e+11
#   level 0.678: [7.8299e+11, 3.3196e+12] (phys)
#   level 0.954: [7.0751e+11, 5.2382e+12] (phys)
# Band saved as scenario_bkg_b/bands/band_bkgb_idx003_bkgpen.json
# === index 4 ===
# [band idx=4] v0=1.0478e+12 (phys), bracketing with step=1.5
#   upper bracket: 5.3046e+12
#   lower bracket: 6.9855e+11
#   level 0.678: [7.8299e+11, 2.3281e+12] (phys)
#   level 0.954: [7.0751e+11, 4.3868e+12] (phys)
# Band saved as scenario_bkg_b/bands/band_bkgb_idx004_bkgpen.json
# === index 5 ===
# [band idx=5] v0=1.0478e+12 (phys), bracketing with step=1.5
#   upper bracket: 3.5364e+12
#   lower bracket: 6.9855e+11
#   level 0.678: [7.8299e+11, 2.1372e+12] (phys)
#   level 0.954: [7.0751e+11, 3.5031e+12] (phys)
# Band saved as scenario_bkg_b/bands/band_bkgb_idx005_bkgpen.json
# === index 8 ===
# [band idx=8] v0=1.0478e+12 (phys), bracketing with step=1.5
#   upper bracket: 2.3576e+12
#   lower bracket: 6.9855e+11
#   level 0.678: [7.6340e+11, 1.5521e+12] (phys)
#   level 0.954: [7.0751e+11, 2.2698e+12] (phys)
# Band saved as scenario_bkg_b/bands/band_bkgb_idx008_bkgpen.json
# === index 13 ===
# [band idx=13] v0=9.9736e+11 (phys), bracketing with step=1.5
#   upper bracket: 2.2441e+12
#   lower bracket: 6.6491e+11
#   level 0.678: [7.4528e+11, 1.4043e+12] (phys)
#   level 0.954: [6.7344e+11, 1.6769e+12] (phys)
# Band saved as scenario_bkg_b/bands/band_bkgb_idx013_bkgpen.json
# === index 16 ===
# [band idx=16] v0=9.1776e+11 (phys), bracketing with step=1.5
#   upper bracket: 2.0650e+12
#   lower bracket: 6.1184e+11
#   level 0.678: [7.2146e+11, 1.2922e+12] (phys)
#   level 0.954: [6.1969e+11, 1.5431e+12] (phys)
# Band saved as scenario_bkg_b/bands/band_bkgb_idx016_bkgpen.json
# === index 20 ===
# [band idx=20] v0=9.1776e+11 (phys), bracketing with step=1.5
#   upper bracket: 1.3766e+12
#   lower bracket: 4.0789e+11
#   level 0.678: [6.8580e+11, 1.1976e+12] (phys)
#   level 0.954: [6.0419e+11, 1.3594e+12] (phys)
# Band saved as scenario_bkg_b/bands/band_bkgb_idx020_bkgpen.json
# === index 25 ===
# [band idx=25] v0=9.1776e+11 (phys), bracketing with step=1.5
#   upper bracket: 1.3766e+12
#   lower bracket: 4.0789e+11
#   level 0.678: [6.5191e+11, 1.1384e+12] (phys)
#   level 0.954: [5.7433e+11, 1.2922e+12] (phys)
# Band saved as scenario_bkg_b/bands/band_bkgb_idx025_bkgpen.json
# === index 30 ===
# [band idx=30] v0=8.1574e+11 (phys), bracketing with step=1.5
#   upper bracket: 1.2236e+12
#   lower bracket: 3.6255e+11
#   level 0.678: [6.0956e+11, 1.0918e+12] (phys)
#   level 0.954: [5.2358e+11, 1.2083e+12] (phys)
# Band saved as scenario_bkg_b/bands/band_bkgb_idx030_bkgpen.json
# === index 40 ===
# [band idx=40] v0=7.3264e+11 (phys), bracketing with step=1.5
#   upper bracket: 1.0990e+12
#   lower bracket: 3.2562e+11
#   level 0.678: [5.3377e+11, 1.0058e+12] (phys)
#   level 0.954: [4.5848e+11, 1.0852e+12] (phys)
# Band saved as scenario_bkg_b/bands/band_bkgb_idx040_bkgpen.json
# === index 50 ===
# [band idx=50] v0=6.6021e+11 (phys), bracketing with step=1.5
#   upper bracket: 1.4855e+12
#   lower bracket: 2.9343e+11
#   level 0.678: [4.3463e+11, 9.0633e+11] (phys)
#   level 0.954: [3.9273e+11, 1.0030e+12] (phys)
# Band saved as scenario_bkg_b/bands/band_bkgb_idx050_bkgpen.json
# === index 60 ===
# [band idx=60] v0=5.9196e+11 (phys), bracketing with step=1.5
#   upper bracket: 1.3319e+12
#   lower bracket: 2.6309e+11
#   level 0.678: [3.7045e+11, 8.3350e+11] (phys)
#   level 0.954: [3.0247e+11, 9.2242e+11] (phys)
# Band saved as scenario_bkg_b/bands/band_bkgb_idx060_bkgpen.json
# === index 70 ===
# [band idx=70] v0=5.0707e+11 (phys), bracketing with step=1.5
#   upper bracket: 1.1409e+12
#   lower bracket: 2.2537e+11
#   level 0.678: [3.0164e+11, 7.5110e+11] (phys)
#   level 0.954: [2.4629e+11, 8.3122e+11] (phys)
# Band saved as scenario_bkg_b/bands/band_bkgb_idx070_bkgpen.json
# === index 80 ===
# [band idx=80] v0=4.4930e+11 (phys), bracketing with step=1.5
#   upper bracket: 1.0109e+12
#   lower bracket: 1.3313e+11
#   level 0.678: [2.4692e+11, 6.6552e+11] (phys)
#   level 0.954: [1.9286e+11, 7.3652e+11] (phys)
# Band saved as scenario_bkg_b/bands/band_bkgb_idx080_bkgpen.json
# === index 90 ===
# [band idx=90] v0=3.8353e+11 (phys), bracketing with step=1.5
#   upper bracket: 8.6293e+11
#   lower bracket: 1.1364e+11
#   level 0.678: [1.9534e+11, 5.6809e+11] (phys)
#   level 0.954: [1.3105e+11, 6.4483e+11] (phys)
# Band saved as scenario_bkg_b/bands/band_bkgb_idx090_bkgpen.json
# === index 100 ===
# [band idx=100] v0=3.1564e+11 (phys), bracketing with step=1.5
#   upper bracket: 7.1019e+11
#   lower bracket: 9.3523e+10
#   level 0.678: [1.5185e+11, 5.1742e+11] (phys)
#   level 0.954: [1.0993e+11, 5.7262e+11] (phys)
# Band saved as scenario_bkg_b/bands/band_bkgb_idx100_bkgpen.json
# === index 110 ===
# [band idx=110] v0=2.7582e+11 (phys), bracketing with step=1.5
#   upper bracket: 6.2060e+11
#   lower bracket: 5.4484e+10
#   level 0.678: [1.2416e+11, 4.5214e+11] (phys)
#   level 0.954: [6.7585e+10, 5.2639e+11] (phys)
# Band saved as scenario_bkg_b/bands/band_bkgb_idx110_bkgpen.json
# === index 120 ===
# [band idx=120] v0=2.1908e+11 (phys), bracketing with step=1.5
#   upper bracket: 4.9292e+11
#   lower bracket: 2.8850e+10
#   level 0.678: [6.6264e+10, 3.9743e+11] (phys)
#   level 0.954: [3.4071e+10, 4.6270e+11] (phys)
# Band saved as scenario_bkg_b/bands/band_bkgb_idx120_bkgpen.json
# === index 130 ===
# [band idx=130] v0=2.1714e+11 (phys), bracketing with step=1.5
#   upper bracket: 4.8856e+11
#   lower bracket: 1.6736e+09
#   level 0.678: [3.4038e+10, 3.5595e+11] (phys)
#   level 0.954: [1.6896e+09, 4.2504e+11] (phys)
# Band saved as scenario_bkg_b/bands/band_bkgb_idx130_bkgpen.json
# === index 140 ===
# [band idx=140] v0=1.2275e+11 (phys), bracketing with step=1.5
#   upper bracket: 4.1427e+11
#   lower edge reaches 0 / unbounded below
#   level 0.678: [0.0000e+00, 3.2053e+11] (phys)
#   level 0.954: [0.0000e+00, 3.6615e+11] (phys)
# Band saved as scenario_bkg_b/bands/band_bkgb_idx140_bkgpen.json
# === index 150 ===
# [band idx=150] v0=1.2275e+11 (phys), bracketing with step=1.5
#   upper bracket: 4.1427e+11
#   lower edge reaches 0 / unbounded below
#   level 0.678: [0.0000e+00, 2.6505e+11] (phys)
#   level 0.954: [0.0000e+00, 2.9707e+11] (phys)
# Band saved as scenario_bkg_b/bands/band_bkgb_idx150_bkgpen.json
# === index 160 ===
# [band idx=160] v0=1.2275e+11 (phys), bracketing with step=1.5
#   upper bracket: 2.7618e+11
#   lower edge reaches 0 / unbounded below
#   level 0.678: [0.0000e+00, 2.0638e+11] (phys)
#   level 0.954: [0.0000e+00, 2.4027e+11] (phys)
# Band saved as scenario_bkg_b/bands/band_bkgb_idx160_bkgpen.json
# === index 167 ===
# [band idx=167] v0=0.0000e+00 (phys), bracketing with step=1.5
#   upper edge unbounded (still inside at max_bracket)
#   lower edge reaches 0 / unbounded below
#   level 0.678: [0.0000e+00, inf] (phys)
#   level 0.954: [0.0000e+00, inf] (phys)
# Band saved as scenario_bkg_b/bands/band_bkgb_idx167_bkgpen.json

# %%
# Load the saved bands and overlay them on the optimize result
# band_files can be a glob pattern or an explicit list
a.plot_flux_with_bands(
    f'scenario_bkg_b/bands/band_bkg{a.background_scenario}_idx*.json',
    levels=(0.678, 0.954),   # Levels to plot (omit to show all saved levels)
    save=True,
    ylim=(0, 3e13),                # So the high-flux tail is visible
)
import matplotlib.pyplot as plt
#plt.yscale('log')
plt.ylim(0, 2e12)
plt.show()
# Out:
# Plot saved as scenario_bkg_b/flux_with_bands_bkg_b.pdf

# %%
# Load the saved bands and overlay them on the optimize result
# band_files can be a glob pattern or an explicit list
a.plot_flux_with_bands(
    f'scenario_bkg_b/bands/band_bkg{a.background_scenario}_idx*.json',
    levels=(0.678, 0.954),   # Levels to plot (omit to show all saved levels)
    save=True,
    ylim=(0, 3e13),                # So the high-flux tail is visible
)
import matplotlib.pyplot as plt
plt.yscale('log')
plt.ylim(1e11, 1e14)
plt.show()
# Out:
# Plot saved as scenario_bkg_b/flux_with_bands_bkg_b.pdf
