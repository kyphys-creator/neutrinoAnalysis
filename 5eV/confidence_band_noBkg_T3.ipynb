# %% [markdown]
# # Confidence-band root finder (`find_confidence_band`)
#
# Example: instead of a uniform grid, locate the band edges directly by bracketing + geometric bisection.
# Bracket the outer reach with the widest level (2σ); the narrower 1σ / 90% / 2σ edges nest inside that interval.
#
# - `num_pseudo_data`: pseudo-data sample size during bracketing (can be coarse)
# - `n_pseudo_edge`: pseudo-data sample size for the edge bisection (larger suppresses cutoff noise)
# - `seed`: fixed value makes every evaluation reproducible and stops the bisection from jittering

# %%
from neutrino_analysis_band import NeutrinoAnalysis

a = NeutrinoAnalysis(background_scenario='a', intervals='180',
                     GeV=0.36e16, solver='osqp')
a.optimize(a.data_vector)   # Compute the best fit first (populates self.result)
result_a = a.optimize(a.data_vector)
print("\nOptimization Complete.")
print(f"Minimum chi-squared: {result_a.fun / a.c}")
# 3. Plot the primary result: the optimized flux vs. theory.
a.plot_flux_comparison(save = True)
# Out:
# Optimization Complete.
# Minimum chi-squared: 1.4643028784668667e-08
# Plot saved as T3/scenario_bkg_a/flux_comparison_bkg_a.pdf

# %% [markdown]
# ## Save bands for several indices and overlay them
#
# 1. Run `find_and_save_band` per index and save one JSON file per index under `bands/`.
# 2. Load the saved files with `plot_flux_with_bands` and overlay each index's band as an error bar on top of the `optimize` flux scatter.
#
# `save_band` / `load_band` use a human-readable JSON format. The band centre is the saved `self.result.x[index]`, so it lines up exactly with the scatter from the same `optimize` result.

# %%
# Build bands for several indices and save one file per index
# Destination: ./bands/band_bkg<scenario>_idx<NNN>.json
indices = [0, 1, 2, 3, 4, 5, 8, 13, 16, 20, 25, 30, 40, 50, 60, 70, 80, 90, 100, 110, 120, 130, 140, 150, 160, 167]     # Indices to run

for idx in indices:
    print(f'=== index {idx} ===')
    a.find_and_save_band(
        idx,
        outdir='scenario_bkg_a/bands',
        levels=(0.678, 0.954),
        num_pseudo_data=50,
        n_pseudo_edge=500,
        step=1.5,
        rel_tol=0.03,
        seed=42,
        n_jobs=1,
        verbose=True,
        bkg_penalty=True,
    )
# Out:
# === index 0 ===
# [band idx=0] v0=1.0448e+12 (phys), bracketing with step=1.5
#   upper bracket: 2.6776e+13
#   lower bracket: 6.9650e+11
#   level 0.678: [8.8616e+11, 1.1752e+13] (phys)
#   level 0.954: [8.0074e+11, 2.4505e+13] (phys)
# Band saved as scenario_bkg_a/bands/band_bkga_idx000_bkgpen.json
# === index 1 ===
# [band idx=1] v0=1.0448e+12 (phys), bracketing with step=1.5
#   upper bracket: 1.1900e+13
#   lower bracket: 6.9650e+11
#   level 0.678: [8.2129e+11, 5.9470e+12] (phys)
#   level 0.954: [7.4212e+11, 1.0925e+13] (phys)
# Band saved as scenario_bkg_a/bands/band_bkga_idx001_bkgpen.json
# === index 2 ===
# [band idx=2] v0=1.0448e+12 (phys), bracketing with step=1.5
#   upper bracket: 7.9336e+12
#   lower bracket: 6.9650e+11
#   level 0.678: [8.2129e+11, 3.7390e+12] (phys)
#   level 0.954: [7.4212e+11, 6.6127e+12] (phys)
# Band saved as scenario_bkg_a/bands/band_bkga_idx002_bkgpen.json
# === index 3 ===
# [band idx=3] v0=1.0448e+12 (phys), bracketing with step=1.5
#   upper bracket: 5.2891e+12
#   lower bracket: 6.9650e+11
#   level 0.678: [8.2129e+11, 2.3213e+12] (phys)
#   level 0.954: [7.4212e+11, 4.6013e+12] (phys)
# Band saved as scenario_bkg_a/bands/band_bkga_idx003_bkgpen.json
# === index 4 ===
# [band idx=4] v0=1.0448e+12 (phys), bracketing with step=1.5
#   upper bracket: 3.5261e+12
#   lower bracket: 6.9650e+11
#   level 0.678: [8.2129e+11, 2.1718e+12] (phys)
#   level 0.954: [7.4212e+11, 3.4271e+12] (phys)
# Band saved as scenario_bkg_a/bands/band_bkga_idx004_bkgpen.json
# === index 5 ===
# [band idx=5] v0=1.0448e+12 (phys), bracketing with step=1.5
#   upper bracket: 3.5261e+12
#   lower bracket: 6.9650e+11
#   level 0.678: [8.2129e+11, 1.8304e+12] (phys)
#   level 0.954: [7.4212e+11, 2.7805e+12] (phys)
# Band saved as scenario_bkg_a/bands/band_bkga_idx005_bkgpen.json
# === index 8 ===
# [band idx=8] v0=1.0448e+12 (phys), bracketing with step=1.5
#   upper bracket: 2.3507e+12
#   lower bracket: 6.9650e+11
#   level 0.678: [8.0074e+11, 1.4342e+12] (phys)
#   level 0.954: [7.2355e+11, 1.8953e+12] (phys)
# Band saved as scenario_bkg_a/bands/band_bkga_idx008_bkgpen.json
# === index 13 ===
# [band idx=13] v0=1.0448e+12 (phys), bracketing with step=1.5
#   upper bracket: 1.5671e+12
#   lower bracket: 6.9650e+11
#   level 0.678: [7.8070e+11, 1.2960e+12] (phys)
#   level 0.954: [7.0544e+11, 1.4710e+12] (phys)
# Band saved as scenario_bkg_a/bands/band_bkga_idx013_bkgpen.json
# === index 16 ===
# [band idx=16] v0=9.1382e+11 (phys), bracketing with step=1.5
#   upper bracket: 1.3707e+12
#   lower bracket: 6.0921e+11
#   level 0.678: [7.5570e+11, 1.1925e+12] (phys)
#   level 0.954: [6.8285e+11, 1.3536e+12] (phys)
# Band saved as scenario_bkg_a/bands/band_bkga_idx016_bkgpen.json
# === index 20 ===
# [band idx=20] v0=9.1382e+11 (phys), bracketing with step=1.5
#   upper bracket: 1.3707e+12
#   lower bracket: 6.0921e+11
#   level 0.678: [7.1836e+11, 1.1336e+12] (phys)
#   level 0.954: [6.4911e+11, 1.2867e+12] (phys)
# Band saved as scenario_bkg_a/bands/band_bkga_idx020_bkgpen.json
# === index 25 ===
# [band idx=25] v0=9.1382e+11 (phys), bracketing with step=1.5
#   upper bracket: 1.3707e+12
#   lower bracket: 6.0921e+11
#   level 0.678: [6.6577e+11, 1.1052e+12] (phys)
#   level 0.954: [6.1703e+11, 1.1925e+12] (phys)
# Band saved as scenario_bkg_a/bands/band_bkga_idx025_bkgpen.json
# === index 30 ===
# [band idx=30] v0=8.1510e+11 (phys), bracketing with step=1.5
#   upper bracket: 1.2227e+12
#   lower bracket: 5.4340e+11
#   level 0.678: [6.4075e+11, 1.0371e+12] (phys)
#   level 0.954: [5.7899e+11, 1.1190e+12] (phys)
# Band saved as scenario_bkg_a/bands/band_bkga_idx030_bkgpen.json
# === index 40 ===
# [band idx=40] v0=7.3633e+11 (phys), bracketing with step=1.5
#   upper bracket: 1.1045e+12
#   lower bracket: 3.2726e+11
#   level 0.678: [5.6435e+11, 9.6088e+11] (phys)
#   level 0.954: [4.8475e+11, 1.0368e+12] (phys)
# Band saved as scenario_bkg_a/bands/band_bkga_idx040_bkgpen.json
# === index 50 ===
# [band idx=50] v0=6.8545e+11 (phys), bracketing with step=1.5
#   upper bracket: 1.0282e+12
#   lower bracket: 3.0464e+11
#   level 0.678: [4.7471e+11, 8.7209e+11] (phys)
#   level 0.954: [4.1821e+11, 9.4098e+11] (phys)
# Band saved as scenario_bkg_a/bands/band_bkga_idx050_bkgpen.json
# === index 60 ===
# [band idx=60] v0=5.9103e+11 (phys), bracketing with step=1.5
#   upper bracket: 8.8654e+11
#   lower bracket: 2.6268e+11
#   level 0.678: [3.8909e+11, 8.1136e+11] (phys)
#   level 0.954: [3.3421e+11, 8.7545e+11] (phys)
# Band saved as scenario_bkg_a/bands/band_bkga_idx060_bkgpen.json
# === index 70 ===
# [band idx=70] v0=5.0709e+11 (phys), bracketing with step=1.5
#   upper bracket: 1.1410e+12
#   lower bracket: 2.2537e+11
#   level 0.678: [3.2548e+11, 7.1400e+11] (phys)
#   level 0.954: [2.7257e+11, 7.9017e+11] (phys)
# Band saved as scenario_bkg_a/bands/band_bkga_idx070_bkgpen.json
# === index 80 ===
# [band idx=80] v0=4.4929e+11 (phys), bracketing with step=1.5
#   upper bracket: 1.0109e+12
#   lower bracket: 1.9968e+11
#   level 0.678: [2.6726e+11, 6.4885e+11] (phys)
#   level 0.954: [2.2382e+11, 7.0010e+11] (phys)
# Band saved as scenario_bkg_a/bands/band_bkga_idx080_bkgpen.json
# === index 90 ===
# [band idx=90] v0=3.8352e+11 (phys), bracketing with step=1.5
#   upper bracket: 8.6292e+11
#   lower bracket: 1.1364e+11
#   level 0.678: [2.1481e+11, 5.6808e+11] (phys)
#   level 0.954: [1.7100e+11, 6.1295e+11] (phys)
# Band saved as scenario_bkg_a/bands/band_bkga_idx090_bkgpen.json
# === index 100 ===
# [band idx=100] v0=3.1567e+11 (phys), bracketing with step=1.5
#   upper bracket: 7.1025e+11
#   lower bracket: 9.3531e+10
#   level 0.678: [1.7348e+11, 4.9188e+11] (phys)
#   level 0.954: [1.3550e+11, 5.4436e+11] (phys)
# Band saved as scenario_bkg_a/bands/band_bkga_idx100_bkgpen.json
# === index 110 ===
# [band idx=110] v0=2.7584e+11 (phys), bracketing with step=1.5
#   upper bracket: 6.2064e+11
#   lower bracket: 8.1731e+10
#   level 0.678: [1.3021e+11, 4.2983e+11] (phys)
#   level 0.954: [9.2482e+10, 4.7568e+11] (phys)
# Band saved as scenario_bkg_a/bands/band_bkga_idx110_bkgpen.json
# === index 120 ===
# [band idx=120] v0=2.1915e+11 (phys), bracketing with step=1.5
#   upper bracket: 4.9308e+11
#   lower bracket: 4.3288e+10
#   level 0.678: [9.1427e+10, 3.7792e+11] (phys)
#   level 0.954: [5.2354e+10, 4.2897e+11] (phys)
# Band saved as scenario_bkg_a/bands/band_bkga_idx120_bkgpen.json
# === index 130 ===
# [band idx=130] v0=2.1629e+11 (phys), bracketing with step=1.5
#   upper bracket: 4.8666e+11
#   lower bracket: 1.8989e+10
#   level 0.678: [4.8652e+10, 3.2038e+11] (phys)
#   level 0.954: [1.9914e+10, 3.8257e+11] (phys)
# Band saved as scenario_bkg_a/bands/band_bkga_idx130_bkgpen.json
# === index 140 ===
# [band idx=140] v0=1.2276e+11 (phys), bracketing with step=1.5
#   upper bracket: 4.1432e+11
#   lower edge reaches 0 / unbounded below
#   level 0.678: [0.0000e+00, 2.9151e+11] (phys)
#   level 0.954: [0.0000e+00, 3.3938e+11] (phys)
# Band saved as scenario_bkg_a/bands/band_bkga_idx140_bkgpen.json
# === index 150 ===
# [band idx=150] v0=1.2276e+11 (phys), bracketing with step=1.5
#   upper bracket: 2.7621e+11
#   lower edge reaches 0 / unbounded below
#   level 0.678: [0.0000e+00, 2.4647e+11] (phys)
#   level 0.954: [0.0000e+00, 2.7276e+11] (phys)
# Band saved as scenario_bkg_a/bands/band_bkga_idx150_bkgpen.json
# === index 160 ===
# [band idx=160] v0=1.2276e+11 (phys), bracketing with step=1.5
#   upper bracket: 2.7621e+11
#   lower edge reaches 0 / unbounded below
#   level 0.678: [0.0000e+00, 1.9129e+11] (phys)
#   level 0.954: [0.0000e+00, 2.2271e+11] (phys)
# Band saved as scenario_bkg_a/bands/band_bkga_idx160_bkgpen.json
# === index 167 ===
# [band idx=167] v0=0.0000e+00 (phys), bracketing with step=1.5
#   upper edge unbounded (still inside at max_bracket)
#   lower edge reaches 0 / unbounded below
#   level 0.678: [0.0000e+00, inf] (phys)
#   level 0.954: [0.0000e+00, inf] (phys)
# Band saved as scenario_bkg_a/bands/band_bkga_idx167_bkgpen.json

# %%
# Load the saved bands and overlay them on the optimize result
# band_files can be a glob pattern or an explicit list
a.plot_flux_with_bands(
    f'scenario_bkg_a/bands/band_bkg{a.background_scenario}_idx*.json',
    levels=(0.678, 0.954),   # Levels to plot (omit to show all saved levels)
    save=True,
    ylim=(0, 3e13),                # So the high-flux tail is visible
)
import matplotlib.pyplot as plt
#plt.yscale('log')
plt.ylim(0, 2e12)
plt.show()
# Out:
# Plot saved as scenario_bkg_a/flux_with_bands_bkg_a.pdf

# %%
# Load the saved bands and overlay them on the optimize result
# band_files can be a glob pattern or an explicit list
a.plot_flux_with_bands(
    f'scenario_bkg_a/bands/band_bkg{a.background_scenario}_idx*.json',
    levels=(0.678, 0.954),   # Levels to plot (omit to show all saved levels)
    save=True,
    ylim=(0, 3e13),                # So the high-flux tail is visible
)
import matplotlib.pyplot as plt
plt.yscale('log')
plt.ylim(1e11, 1e14)
plt.show()
# Out:
# Plot saved as scenario_bkg_a/flux_with_bands_bkg_a.pdf
