# %% [markdown]
# # Confidence-band root finder (`find_confidence_band`)
#
# Example: instead of a uniform grid, locate the band edges directly by bracketing + geometric bisection.
# Bracket the outer reach with the widest level (2σ); the narrower 1σ / 90% / 2σ edges nest inside that interval.
#
# - `num_pseudo_data`: pseudo-data sample size during bracketing (can be coarse)
# - `n_pseudo_edge`: pseudo-data sample size for the edge bisection (larger suppresses cutoff noise)
# - `seed`: fixed value makes every evaluation reproducible and stops the bisection from jittering

# %%
from neutrino_analysis_band import NeutrinoAnalysis

# %%
a = NeutrinoAnalysis(background_scenario='a', intervals='180',
                     GeV=0.36e16, solver='osqp', T=300)
a.optimize(a.data_vector)   # Compute the best fit first (populates self.result)
result_a = a.optimize(a.data_vector)
print("\nOptimization Complete.")
print(f"Minimum chi-squared: {result_a.fun / a.c}")
# 3. Plot the primary result: the optimized flux vs. theory.
a.plot_flux_comparison(save = True)
# Out:
# Optimization Complete.
# Minimum chi-squared: 2.888357586943653e-13
# Plot saved as T300/scenario_bkg_a/flux_comparison_bkg_a.pdf

# %% [markdown]
# ## Save bands for several indices and overlay them
#
# 1. Run `find_and_save_band` per index and save one JSON file per index under `bands/`.
# 2. Load the saved files with `plot_flux_with_bands` and overlay each index's band as an error bar on top of the `optimize` flux scatter.
#
# `save_band` / `load_band` use a human-readable JSON format. The band centre is the saved `self.result.x[index]`, so it lines up exactly with the scatter from the same `optimize` result.

# %%
# Saved automatically under the T-prefixed folder (outdir can be omitted)
# → T3/scenario_bkg_flat/bands/band_bkgflat_idx000.json

# Build bands for several indices and save one file per index
# Destination: ./bands/band_bkg<scenario>_idx<NNN>.json
indices = [0, 1, 2, 3, 4, 5, 8, 13, 16, 20, 25, 30, 40, 50, 60, 70, 80, 90, 100, 110, 120, 130, 140, 150, 160, 167]      # Indices to run

for idx in indices:
    print(f'=== index {idx} ===')
    a.find_and_save_band(
        idx,
        outdir='T300/scenario_bkg_a/bands',
        levels=(0.678, 0.954),
        num_pseudo_data=50,
        n_pseudo_edge=500,
        step=1.5,
        rel_tol=0.03,
        seed=42,
        n_jobs=1,
        verbose=True,
        bkg_penalty=True,
    )
# Out:
# === index 0 ===
# [band idx=0] v0=1.0448e+12 (phys), bracketing with step=1.5
#   upper bracket: 7.9336e+12
#   lower bracket: 6.9650e+11
#   level 0.678: [1.0317e+12, 4.1773e+12] (phys)
#   level 0.954: [9.8069e+11, 6.0132e+12] (phys)
# Band saved as T300/scenario_bkg_a/bands/band_bkga_idx000_bkgpen.json
# === index 1 ===
# [band idx=1] v0=1.0448e+12 (phys), bracketing with step=1.5
#   upper bracket: 3.5260e+12
#   lower bracket: 6.9650e+11
#   level 0.678: [9.5615e+11, 2.3434e+12] (phys)
#   level 0.954: [9.0890e+11, 3.1164e+12] (phys)
# Band saved as T300/scenario_bkg_a/bands/band_bkga_idx001_bkgpen.json
# === index 2 ===
# [band idx=2] v0=1.0448e+12 (phys), bracketing with step=1.5
#   upper bracket: 2.3507e+12
#   lower bracket: 6.9650e+11
#   level 0.678: [9.5615e+11, 1.7566e+12] (phys)
#   level 0.954: [9.0890e+11, 2.1513e+12] (phys)
# Band saved as T300/scenario_bkg_a/bands/band_bkga_idx002_bkgpen.json
# === index 3 ===
# [band idx=3] v0=1.0448e+12 (phys), bracketing with step=1.5
#   upper bracket: 2.3507e+12
#   lower bracket: 6.9650e+11
#   level 0.678: [9.5615e+11, 1.4710e+12] (phys)
#   level 0.954: [9.0890e+11, 1.7126e+12] (phys)
# Band saved as T300/scenario_bkg_a/bands/band_bkga_idx003_bkgpen.json
# === index 4 ===
# [band idx=4] v0=1.0448e+12 (phys), bracketing with step=1.5
#   upper bracket: 1.5671e+12
#   lower bracket: 6.9650e+11
#   level 0.678: [9.5615e+11, 1.3292e+12] (phys)
#   level 0.954: [9.0890e+11, 1.5088e+12] (phys)
# Band saved as T300/scenario_bkg_a/bands/band_bkga_idx004_bkgpen.json
# === index 5 ===
# [band idx=5] v0=1.0448e+12 (phys), bracketing with step=1.5
#   upper bracket: 1.5671e+12
#   lower bracket: 6.9650e+11
#   level 0.678: [9.5615e+11, 1.2319e+12] (phys)
#   level 0.954: [9.0890e+11, 1.3633e+12] (phys)
# Band saved as T300/scenario_bkg_a/bands/band_bkga_idx005_bkgpen.json
# === index 8 ===
# [band idx=8] v0=1.0448e+12 (phys), bracketing with step=1.5
#   upper bracket: 1.5671e+12
#   lower bracket: 6.9650e+11
#   level 0.678: [9.3223e+11, 1.1132e+12] (phys)
#   level 0.954: [9.0890e+11, 1.1710e+12] (phys)
# Band saved as T300/scenario_bkg_a/bands/band_bkga_idx008_bkgpen.json
# === index 13 ===
# [band idx=13] v0=1.0448e+12 (phys), bracketing with step=1.5
#   upper bracket: 1.5671e+12
#   lower bracket: 6.9650e+11
#   level 0.678: [8.8616e+11, 1.0853e+12] (phys)
#   level 0.954: [8.6398e+11, 1.1132e+12] (phys)
# Band saved as T300/scenario_bkg_a/bands/band_bkga_idx013_bkgpen.json
# === index 16 ===
# [band idx=16] v0=9.1378e+11 (phys), bracketing with step=1.5
#   upper bracket: 1.3707e+12
#   lower bracket: 6.0919e+11
#   level 0.678: [8.5775e+11, 1.0505e+12] (phys)
#   level 0.954: [8.3629e+11, 1.0775e+12] (phys)
# Band saved as T300/scenario_bkg_a/bands/band_bkga_idx016_bkgpen.json
# === index 20 ===
# [band idx=20] v0=9.1378e+11 (phys), bracketing with step=1.5
#   upper bracket: 1.3707e+12
#   lower bracket: 6.0919e+11
#   level 0.678: [8.3629e+11, 9.9861e+11] (phys)
#   level 0.954: [8.1536e+11, 1.0242e+12] (phys)
# Band saved as T300/scenario_bkg_a/bands/band_bkga_idx020_bkgpen.json
# === index 25 ===
# [band idx=25] v0=9.1378e+11 (phys), bracketing with step=1.5
#   upper bracket: 1.3707e+12
#   lower bracket: 6.0919e+11
#   level 0.678: [7.9496e+11, 9.7362e+11] (phys)
#   level 0.954: [7.7507e+11, 9.7362e+11] (phys)
# Band saved as T300/scenario_bkg_a/bands/band_bkga_idx025_bkgpen.json
# === index 30 ===
# [band idx=30] v0=8.1503e+11 (phys), bracketing with step=1.5
#   upper bracket: 1.2225e+12
#   lower bracket: 5.4335e+11
#   level 0.678: [7.4592e+11, 9.1356e+11] (phys)
#   level 0.954: [7.2725e+11, 9.3700e+11] (phys)
# Band saved as T300/scenario_bkg_a/bands/band_bkga_idx030_bkgpen.json
# === index 40 ===
# [band idx=40] v0=7.3632e+11 (phys), bracketing with step=1.5
#   upper bracket: 1.1045e+12
#   lower bracket: 4.9088e+11
#   level 0.678: [6.7387e+11, 8.2532e+11] (phys)
#   level 0.954: [6.5701e+11, 8.4651e+11] (phys)
# Band saved as T300/scenario_bkg_a/bands/band_bkga_idx040_bkgpen.json
# === index 50 ===
# [band idx=50] v0=6.8545e+11 (phys), bracketing with step=1.5
#   upper bracket: 1.0282e+12
#   lower bracket: 4.5697e+11
#   level 0.678: [5.9632e+11, 7.4909e+11] (phys)
#   level 0.954: [5.6685e+11, 7.6831e+11] (phys)
# Band saved as T300/scenario_bkg_a/bands/band_bkga_idx050_bkgpen.json
# === index 60 ===
# [band idx=60] v0=5.9104e+11 (phys), bracketing with step=1.5
#   upper bracket: 8.8656e+11
#   lower bracket: 3.9403e+11
#   level 0.678: [5.1418e+11, 6.7949e+11] (phys)
#   level 0.954: [4.8877e+11, 6.9693e+11] (phys)
# Band saved as T300/scenario_bkg_a/bands/band_bkga_idx060_bkgpen.json
# === index 70 ===
# [band idx=70] v0=5.0708e+11 (phys), bracketing with step=1.5
#   upper bracket: 7.6062e+11
#   lower bracket: 3.3805e+11
#   level 0.678: [4.4114e+11, 5.9793e+11] (phys)
#   level 0.954: [4.1934e+11, 6.1327e+11] (phys)
# Band saved as T300/scenario_bkg_a/bands/band_bkga_idx070_bkgpen.json
# === index 80 ===
# [band idx=80] v0=4.4928e+11 (phys), bracketing with step=1.5
#   upper bracket: 6.7392e+11
#   lower bracket: 2.9952e+11
#   level 0.678: [3.7154e+11, 5.1651e+11] (phys)
#   level 0.954: [3.5318e+11, 5.4337e+11] (phys)
# Band saved as T300/scenario_bkg_a/bands/band_bkga_idx080_bkgpen.json
# === index 90 ===
# [band idx=90] v0=3.8351e+11 (phys), bracketing with step=1.5
#   upper bracket: 5.7527e+11
#   lower bracket: 2.5567e+11
#   level 0.678: [3.0922e+11, 4.4090e+11] (phys)
#   level 0.954: [2.9394e+11, 4.6383e+11] (phys)
# Band saved as T300/scenario_bkg_a/bands/band_bkga_idx090_bkgpen.json
# === index 100 ===
# [band idx=100] v0=3.1563e+11 (phys), bracketing with step=1.5
#   upper bracket: 4.7345e+11
#   lower bracket: 2.1042e+11
#   level 0.678: [2.6102e+11, 3.8173e+11] (phys)
#   level 0.954: [2.4191e+11, 4.0158e+11] (phys)
# Band saved as T300/scenario_bkg_a/bands/band_bkga_idx100_bkgpen.json
# === index 110 ===
# [band idx=110] v0=2.7585e+11 (phys), bracketing with step=1.5
#   upper bracket: 4.1378e+11
#   lower bracket: 1.8390e+11
#   level 0.678: [2.1142e+11, 3.2527e+11] (phys)
#   level 0.954: [1.9595e+11, 3.5097e+11] (phys)
# Band saved as T300/scenario_bkg_a/bands/band_bkga_idx110_bkgpen.json
# === index 120 ===
# [band idx=120] v0=2.1915e+11 (phys), bracketing with step=1.5
#   upper bracket: 3.2873e+11
#   lower bracket: 1.4610e+11
#   level 0.678: [1.7228e+11, 2.7883e+11] (phys)
#   level 0.954: [1.5567e+11, 3.0085e+11] (phys)
# Band saved as T300/scenario_bkg_a/bands/band_bkga_idx120_bkgpen.json
# === index 130 ===
# [band idx=130] v0=2.1625e+11 (phys), bracketing with step=1.5
#   upper bracket: 3.2437e+11
#   lower bracket: 9.6110e+10
#   level 0.678: [1.1333e+11, 2.4239e+11] (phys)
#   level 0.954: [1.0503e+11, 2.5499e+11] (phys)
# Band saved as T300/scenario_bkg_a/bands/band_bkga_idx130_bkgpen.json
# === index 140 ===
# [band idx=140] v0=1.2276e+11 (phys), bracketing with step=1.5
#   upper bracket: 2.7622e+11
#   lower bracket: 5.4561e+10
#   level 0.678: [8.0818e+10, 2.0124e+11] (phys)
#   level 0.954: [6.1157e+10, 2.2842e+11] (phys)
# Band saved as T300/scenario_bkg_a/bands/band_bkga_idx140_bkgpen.json
# === index 150 ===
# [band idx=150] v0=1.2276e+11 (phys), bracketing with step=1.5
#   upper bracket: 1.8414e+11
#   lower bracket: 2.4249e+10
#   level 0.678: [3.3290e+10, 1.6431e+11] (phys)
#   level 0.954: [2.7181e+10, 1.7729e+11] (phys)
# Band saved as T300/scenario_bkg_a/bands/band_bkga_idx150_bkgpen.json
# === index 160 ===
# [band idx=160] v0=1.2276e+11 (phys), bracketing with step=1.5
#   upper bracket: 1.8414e+11
#   lower bracket: 3.1933e+09
#   level 0.678: [9.0409e+09, 1.3416e+11] (phys)
#   level 0.954: [3.2395e+09, 1.4476e+11] (phys)
# Band saved as T300/scenario_bkg_a/bands/band_bkga_idx160_bkgpen.json
# === index 167 ===
# [band idx=167] v0=0.0000e+00 (phys), bracketing with step=1.5
#   upper edge unbounded (still inside at max_bracket)
#   lower edge reaches 0 / unbounded below
#   level 0.678: [0.0000e+00, inf] (phys)
#   level 0.954: [0.0000e+00, inf] (phys)
# Band saved as T300/scenario_bkg_a/bands/band_bkga_idx167_bkgpen.json

# %%
# Load the saved bands and overlay them on the optimize result
# band_files can be a glob pattern or an explicit list
a.plot_flux_with_bands(
    f'scenario_bkg_b/bands/band_bkg{a.background_scenario}_idx*.json',
    levels=(0.678, 0.954),   # Levels to plot (omit to show all saved levels)
    save=True,
    ylim=(0, 3e13),                # So the high-flux tail is visible
)
import matplotlib.pyplot as plt
#plt.yscale('log')
plt.ylim(0, 2e12)
plt.show()

# %%
# Load the saved bands and overlay them on the optimize result
# band_files can be a glob pattern or an explicit list
a.plot_flux_with_bands(
    f'scenario_bkg_b/bands/band_bkg{a.background_scenario}_idx*.json',
    levels=(0.678, 0.954),   # Levels to plot (omit to show all saved levels)
    save=True,
    ylim=(0, 3e13),                # So the high-flux tail is visible
)
import matplotlib.pyplot as plt
plt.yscale('log')
plt.ylim(1e11, 1e14)
plt.show()
