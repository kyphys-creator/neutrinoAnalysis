# %% [markdown]
# # 信頼バンドの根探索 (`find_confidence_band`)
#
# 等間隔グリッドの代わりに、ブラケット＋幾何二分法でバンドの上下端を直接探す例。
# 最も広い 2σ で外側をブラケットし、各レベル (1σ/90%/2σ) の端を入れ子で詰める。
#
# - `num_pseudo_data`: ブラケット段階の擬似データ数（粗くてよい）
# - `n_pseudo_edge`: 端の二分法で使う擬似データ数（cutoff のノイズを抑えるため大きめ）
# - `seed`: 固定すると各点が再現可能になり、二分法のジッターが減る

# %%
from neutrino_analysis_band import NeutrinoAnalysis

# %%
a = NeutrinoAnalysis(background_scenario='a', intervals='180',
                     GeV=0.36e16, solver='osqp', T=300)
a.optimize(a.data_vector)   # ベストフィットを先に求める (self.result を埋める)
result_a = a.optimize(a.data_vector)
print("\nOptimization Complete.")
print(f"Minimum chi-squared: {result_a.fun / a.c}")
# 3. Plot the primary result: the optimized flux vs. theory.
a.plot_flux_comparison(save = True)
# Out:
# Optimization Complete.
# Minimum chi-squared: 2.888357586943653e-13
# Plot saved as T300/scenario_bkg_a/flux_comparison_bkg_a.pdf

# %% [markdown]
# ## 複数インデックスのバンドを保存して重ねる
#
# 1. インデックスごとに `find_and_save_band` を実行し、`bands/` 配下に 1 ファイルずつ JSON で保存する。
# 2. `plot_flux_with_bands` で保存済みファイルを読み込み、`optimize` の最適フラックス（散布図）の上に各インデックスのバンドを誤差棒として重ねる。
#
# `save_band` / `load_band` は JSON 形式（人が読める）。バンドの中心は保存時の `self.result.x[index]` なので、同じ `optimize` 結果の散布図とちょうど重なる。

# %%
# 自動で T 別フォルダに保存（outdir 省略可）
# → T3/scenario_bkg_flat/bands/band_bkgflat_idx000.json

# 複数インデックスでバンドを作り、インデックスごとに 1 ファイルへ保存
# 保存先は ./bands/band_bkg<scenario>_idx<NNN>.json
indices = [1, 2, 3, 4, 5, 8, 13, 16, 20, 25, 30, 40, 50, 60, 70, 80, 90, 100, 110, 120, 130, 140, 150, 160, 167]     # 走らせたいインデックス

for idx in indices:
    print(f'=== index {idx} ===')
    a.find_and_save_band(
        idx,
        outdir='T300/scenario_bkg_a/bands',
        levels=(0.678, 0.954),
        num_pseudo_data=50,
        n_pseudo_edge=500,
        step=1.5,
        rel_tol=0.03,
        seed=42,
        n_jobs=1,
        verbose=True,
    )
# Out:
# === index 1 ===
# [band idx=1] v0=1.0447e+12 (phys), bracketing with step=1.5
#   upper bracket: 3.5258e+12
#   lower bracket: 6.9645e+11
#   level 0.678: [9.5608e+11, 2.2133e+12] (phys)
#   level 0.954: [9.3215e+11, 2.9434e+12] (phys)
# Band saved as T300/scenario_bkg_a/bands/band_bkga_idx001.json
# === index 2 ===
# [band idx=2] v0=1.0644e+12 (phys), bracketing with step=1.5
#   upper bracket: 2.3950e+12
#   lower bracket: 7.0962e+11
#   level 0.678: [9.4978e+11, 1.7012e+12] (phys)
#   level 0.954: [9.2602e+11, 2.0835e+12] (phys)
# Band saved as T300/scenario_bkg_a/bands/band_bkga_idx002.json
# === index 3 ===
# [band idx=3] v0=1.0638e+12 (phys), bracketing with step=1.5
#   upper bracket: 2.3935e+12
#   lower bracket: 7.0918e+11
#   level 0.678: [9.4920e+11, 1.4238e+12] (phys)
#   level 0.954: [9.2544e+11, 1.7001e+12] (phys)
# Band saved as T300/scenario_bkg_a/bands/band_bkga_idx003.json
# === index 4 ===
# [band idx=4] v0=1.0624e+12 (phys), bracketing with step=1.5
#   upper bracket: 1.5936e+12
#   lower bracket: 7.0825e+11
#   level 0.678: [9.4795e+11, 1.2849e+12] (phys)
#   level 0.954: [9.2423e+11, 1.4584e+12] (phys)
# Band saved as T300/scenario_bkg_a/bands/band_bkga_idx004.json
# === index 5 ===
# [band idx=5] v0=1.0598e+12 (phys), bracketing with step=1.5
#   upper bracket: 1.5897e+12
#   lower bracket: 7.0652e+11
#   level 0.678: [9.4563e+11, 1.2184e+12] (phys)
#   level 0.954: [9.2197e+11, 1.3483e+12] (phys)
# Band saved as T300/scenario_bkg_a/bands/band_bkga_idx005.json
# === index 8 ===
# [band idx=8] v0=1.0425e+12 (phys), bracketing with step=1.5
#   upper bracket: 1.5638e+12
#   lower bracket: 6.9502e+11
#   level 0.678: [9.5411e+11, 1.1108e+12] (phys)
#   level 0.954: [9.0696e+11, 1.1685e+12] (phys)
# Band saved as T300/scenario_bkg_a/bands/band_bkga_idx008.json
# === index 13 ===
# [band idx=13] v0=9.7756e+11 (phys), bracketing with step=1.5
#   upper bracket: 1.4663e+12
#   lower bracket: 6.5171e+11
#   level 0.678: [8.9466e+11, 1.0683e+12] (phys)
#   level 0.954: [8.7228e+11, 1.0957e+12] (phys)
# Band saved as T300/scenario_bkg_a/bands/band_bkga_idx013.json
# === index 16 ===
# [band idx=16] v0=9.4697e+11 (phys), bracketing with step=1.5
#   upper bracket: 1.4205e+12
#   lower bracket: 6.3131e+11
#   level 0.678: [8.6667e+11, 1.0349e+12] (phys)
#   level 0.954: [8.4498e+11, 1.0614e+12] (phys)
# Band saved as T300/scenario_bkg_a/bands/band_bkga_idx016.json
# === index 20 ===
# [band idx=20] v0=9.1967e+11 (phys), bracketing with step=1.5
#   upper bracket: 1.3795e+12
#   lower bracket: 6.1311e+11
#   level 0.678: [8.4168e+11, 1.0050e+12] (phys)
#   level 0.954: [8.2062e+11, 1.0308e+12] (phys)
# Band saved as T300/scenario_bkg_a/bands/band_bkga_idx020.json
# === index 25 ===
# [band idx=25] v0=8.7747e+11 (phys), bracketing with step=1.5
#   upper bracket: 1.3162e+12
#   lower bracket: 5.8498e+11
#   level 0.678: [8.0305e+11, 9.5893e+11] (phys)
#   level 0.954: [7.8296e+11, 9.8354e+11] (phys)
# Band saved as T300/scenario_bkg_a/bands/band_bkga_idx025.json
# === index 30 ===
# [band idx=30] v0=8.3391e+11 (phys), bracketing with step=1.5
#   upper bracket: 1.2509e+12
#   lower bracket: 5.5594e+11
#   level 0.678: [7.6319e+11, 9.1132e+11] (phys)
#   level 0.954: [7.4409e+11, 9.3471e+11] (phys)
# Band saved as T300/scenario_bkg_a/bands/band_bkga_idx030.json
# === index 40 ===
# [band idx=40] v0=7.5281e+11 (phys), bracketing with step=1.5
#   upper bracket: 1.1292e+12
#   lower bracket: 5.0187e+11
#   level 0.678: [6.7173e+11, 8.2270e+11] (phys)
#   level 0.954: [6.5492e+11, 8.4381e+11] (phys)
# Band saved as T300/scenario_bkg_a/bands/band_bkga_idx040.json
# === index 50 ===
# [band idx=50] v0=6.7268e+11 (phys), bracketing with step=1.5
#   upper bracket: 1.0090e+12
#   lower bracket: 4.4845e+11
#   level 0.678: [6.0023e+11, 7.5399e+11] (phys)
#   level 0.954: [5.8521e+11, 7.7334e+11] (phys)
# Band saved as T300/scenario_bkg_a/bands/band_bkga_idx050.json
# === index 60 ===
# [band idx=60] v0=5.9472e+11 (phys), bracketing with step=1.5
#   upper bracket: 8.9208e+11
#   lower bracket: 3.9648e+11
#   level 0.678: [5.1739e+11, 6.6661e+11] (phys)
#   level 0.954: [5.0444e+11, 6.8372e+11] (phys)
# Band saved as T300/scenario_bkg_a/bands/band_bkga_idx060.json
# === index 70 ===
# [band idx=70] v0=5.1784e+11 (phys), bracketing with step=1.5
#   upper bracket: 7.7676e+11
#   lower bracket: 3.4523e+11
#   level 0.678: [4.5051e+11, 5.8044e+11] (phys)
#   level 0.954: [4.2824e+11, 6.1062e+11] (phys)
# Band saved as T300/scenario_bkg_a/bands/band_bkga_idx070.json
# === index 80 ===
# [band idx=80] v0=4.4216e+11 (phys), bracketing with step=1.5
#   upper bracket: 6.6324e+11
#   lower bracket: 2.9477e+11
#   level 0.678: [3.7504e+11, 5.0833e+11] (phys)
#   level 0.954: [3.5651e+11, 5.3476e+11] (phys)
# Band saved as T300/scenario_bkg_a/bands/band_bkga_idx080.json
# === index 90 ===
# [band idx=90] v0=3.7629e+11 (phys), bracketing with step=1.5
#   upper bracket: 5.6443e+11
#   lower bracket: 2.5086e+11
#   level 0.678: [3.1917e+11, 4.3260e+11] (phys)
#   level 0.954: [3.0339e+11, 4.5509e+11] (phys)
# Band saved as T300/scenario_bkg_a/bands/band_bkga_idx090.json
# === index 100 ===
# [band idx=100] v0=3.1842e+11 (phys), bracketing with step=1.5
#   upper bracket: 4.7763e+11
#   lower bracket: 2.1228e+11
#   level 0.678: [2.7008e+11, 3.7547e+11] (phys)
#   level 0.954: [2.5031e+11, 3.9499e+11] (phys)
# Band saved as T300/scenario_bkg_a/bands/band_bkga_idx100.json
# === index 110 ===
# [band idx=110] v0=2.7092e+11 (phys), bracketing with step=1.5
#   upper bracket: 4.0638e+11
#   lower bracket: 1.8061e+11
#   level 0.678: [2.1844e+11, 3.1946e+11] (phys)
#   level 0.954: [2.0245e+11, 3.3606e+11] (phys)
# Band saved as T300/scenario_bkg_a/bands/band_bkga_idx110.json
# === index 120 ===
# [band idx=120] v0=2.2531e+11 (phys), bracketing with step=1.5
#   upper bracket: 3.3796e+11
#   lower bracket: 1.5020e+11
#   level 0.678: [1.7712e+11, 2.7249e+11] (phys)
#   level 0.954: [1.6415e+11, 2.9402e+11] (phys)
# Band saved as T300/scenario_bkg_a/bands/band_bkga_idx120.json
# === index 130 ===
# [band idx=130] v0=1.8187e+11 (phys), bracketing with step=1.5
#   upper bracket: 2.7281e+11
#   lower bracket: 8.0833e+10
#   level 0.678: [1.1674e+11, 2.3734e+11] (phys)
#   level 0.954: [1.1097e+11, 2.4968e+11] (phys)
# Band saved as T300/scenario_bkg_a/bands/band_bkga_idx130.json
# === index 140 ===
# [band idx=140] v0=1.4397e+11 (phys), bracketing with step=1.5
#   upper bracket: 2.1596e+11
#   lower bracket: 6.3988e+10
#   level 0.678: [8.5644e+10, 1.9764e+11] (phys)
#   level 0.954: [6.6472e+10, 2.1326e+11] (phys)
# Band saved as T300/scenario_bkg_a/bands/band_bkga_idx140.json
# === index 150 ===
# [band idx=150] v0=9.8822e+10 (phys), bracketing with step=1.5
#   upper bracket: 2.2235e+11
#   lower bracket: 2.9281e+10
#   level 0.678: [3.4416e+10, 1.6199e+11] (phys)
#   level 0.954: [3.0129e+10, 1.7479e+11] (phys)
# Band saved as T300/scenario_bkg_a/bands/band_bkga_idx150.json
# === index 160 ===
# [band idx=160] v0=5.4824e+10 (phys), bracketing with step=1.5
#   upper bracket: 1.8503e+11
#   lower bracket: 4.8130e+09
#   level 0.678: [1.0796e+10, 1.3268e+11] (phys)
#   level 0.954: [5.0475e+09, 1.4047e+11] (phys)
# Band saved as T300/scenario_bkg_a/bands/band_bkga_idx160.json
# === index 167 ===
# [band idx=167] v0=3.5470e+10 (phys), bracketing with step=1.5
#   upper bracket: 1.1971e+11
#   lower edge reaches 0 / unbounded below
#   level 0.678: [0.0000e+00, 9.0880e+10] (phys)
#   level 0.954: [0.0000e+00, 9.6212e+10] (phys)
# Band saved as T300/scenario_bkg_a/bands/band_bkga_idx167.json

# %%
# 保存したバンドを読み込んで optimize 結果の上に重ねる
# band_files はグロブパターンでも、明示的なリストでもよい
a.plot_flux_with_bands(
    f'scenario_bkg_b/bands/band_bkg{a.background_scenario}_idx*.json',
    levels=(0.678, 0.954),   # 表示するレベル (省略すると保存済み全レベル)
    save=True,
    ylim=(0, 3e13),                # 高フラックス側の裾まで見えるように
)
import matplotlib.pyplot as plt
#plt.yscale('log')
plt.ylim(0, 2e12)
plt.show()

# %%
# 保存したバンドを読み込んで optimize 結果の上に重ねる
# band_files はグロブパターンでも、明示的なリストでもよい
a.plot_flux_with_bands(
    f'scenario_bkg_b/bands/band_bkg{a.background_scenario}_idx*.json',
    levels=(0.678, 0.954),   # 表示するレベル (省略すると保存済み全レベル)
    save=True,
    ylim=(0, 3e13),                # 高フラックス側の裾まで見えるように
)
import matplotlib.pyplot as plt
plt.yscale('log')
plt.ylim(1e11, 1e14)
plt.show()
