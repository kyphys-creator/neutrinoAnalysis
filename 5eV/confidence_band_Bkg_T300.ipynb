# %% [markdown]
# # 信頼バンドの根探索 (`find_confidence_band`)
#
# 等間隔グリッドの代わりに、ブラケット＋幾何二分法でバンドの上下端を直接探す例。
# 最も広い 2σ で外側をブラケットし、各レベル (1σ/90%/2σ) の端を入れ子で詰める。
#
# - `num_pseudo_data`: ブラケット段階の擬似データ数（粗くてよい）
# - `n_pseudo_edge`: 端の二分法で使う擬似データ数（cutoff のノイズを抑えるため大きめ）
# - `seed`: 固定すると各点が再現可能になり、二分法のジッターが減る

# %%
from neutrino_analysis_band import NeutrinoAnalysis

# %%
a = NeutrinoAnalysis(background_scenario='b', intervals='180',
                     GeV=0.36e16, solver='osqp', T=300)
a.optimize(a.data_vector)   # ベストフィットを先に求める (self.result を埋める)
result_b = a.optimize(a.data_vector)
print("\nOptimization Complete.")
print(f"Minimum chi-squared: {result_b.fun / a.c}")
# 3. Plot the primary result: the optimized flux vs. theory.
a.plot_flux_comparison(save = True)
# Out:
# Optimization Complete.
# Minimum chi-squared: 1.8137155906451046e-13
# Plot saved as T300/scenario_bkg_b/flux_comparison_bkg_b.pdf

# %% [markdown]
# ## 複数インデックスのバンドを保存して重ねる
#
# 1. インデックスごとに `find_and_save_band` を実行し、`bands/` 配下に 1 ファイルずつ JSON で保存する。
# 2. `plot_flux_with_bands` で保存済みファイルを読み込み、`optimize` の最適フラックス（散布図）の上に各インデックスのバンドを誤差棒として重ねる。
#
# `save_band` / `load_band` は JSON 形式（人が読める）。バンドの中心は保存時の `self.result.x[index]` なので、同じ `optimize` 結果の散布図とちょうど重なる。

# %%
# 自動で T 別フォルダに保存（outdir 省略可）
# → T3/scenario_bkg_flat/bands/band_bkgflat_idx000.json

# 複数インデックスでバンドを作り、インデックスごとに 1 ファイルへ保存
# 保存先は ./bands/band_bkg<scenario>_idx<NNN>.json
indices = [4, 5, 8, 13, 16, 20, 25, 30, 40, 50, 60, 70, 80, 90, 100, 110, 120, 130, 140, 150, 160, 167]     # 走らせたいインデックス

for idx in indices:
    print(f'=== index {idx} ===')
    a.find_and_save_band(
        idx,
        outdir='T300/scenario_bkg_b/bands',
        levels=(0.678, 0.954),
        num_pseudo_data=50,
        n_pseudo_edge=500,
        step=1.5,
        rel_tol=0.03,
        seed=42,
        n_jobs=1,
        verbose=True,
    )
# Out:
# === index 4 ===
# [band idx=4] v0=1.0447e+12 (phys), bracketing with step=1.5
#   upper bracket: 1.5670e+12
#   lower bracket: 6.9645e+11
#   level 0.678: [9.5608e+11, 1.3291e+12] (phys)
#   level 0.954: [9.0883e+11, 1.5474e+12] (phys)
# Band saved as T300/scenario_bkg_b/bands/band_bkgb_idx004.json
# === index 5 ===
# [band idx=5] v0=1.0447e+12 (phys), bracketing with step=1.5
#   upper bracket: 1.5670e+12
#   lower bracket: 6.9645e+11
#   level 0.678: [9.5608e+11, 1.2318e+12] (phys)
#   level 0.954: [9.0883e+11, 1.3982e+12] (phys)
# Band saved as T300/scenario_bkg_b/bands/band_bkgb_idx005.json
# === index 8 ===
# [band idx=8] v0=1.0447e+12 (phys), bracketing with step=1.5
#   upper bracket: 1.5670e+12
#   lower bracket: 6.9645e+11
#   level 0.678: [9.3215e+11, 1.1131e+12] (phys)
#   level 0.954: [9.0883e+11, 1.2010e+12] (phys)
# Band saved as T300/scenario_bkg_b/bands/band_bkgb_idx008.json
# === index 13 ===
# [band idx=13] v0=1.0447e+12 (phys), bracketing with step=1.5
#   upper bracket: 1.5670e+12
#   lower bracket: 6.9645e+11
#   level 0.678: [8.8609e+11, 1.0852e+12] (phys)
#   level 0.954: [8.6391e+11, 1.1131e+12] (phys)
# Band saved as T300/scenario_bkg_b/bands/band_bkgb_idx013.json
# === index 16 ===
# [band idx=16] v0=9.1379e+11 (phys), bracketing with step=1.5
#   upper bracket: 1.3707e+12
#   lower bracket: 6.0919e+11
#   level 0.678: [8.5776e+11, 1.0505e+12] (phys)
#   level 0.954: [8.3630e+11, 1.0775e+12] (phys)
# Band saved as T300/scenario_bkg_b/bands/band_bkgb_idx016.json
# === index 20 ===
# [band idx=20] v0=9.1379e+11 (phys), bracketing with step=1.5
#   upper bracket: 1.3707e+12
#   lower bracket: 6.0919e+11
#   level 0.678: [8.3630e+11, 9.9862e+11] (phys)
#   level 0.954: [7.9497e+11, 1.0505e+12] (phys)
# Band saved as T300/scenario_bkg_b/bands/band_bkgb_idx020.json
# === index 25 ===
# [band idx=25] v0=9.1379e+11 (phys), bracketing with step=1.5
#   upper bracket: 1.3707e+12
#   lower bracket: 6.0919e+11
#   level 0.678: [7.9497e+11, 9.7363e+11] (phys)
#   level 0.954: [7.7507e+11, 9.9862e+11] (phys)
# Band saved as T300/scenario_bkg_b/bands/band_bkgb_idx025.json
# === index 30 ===
# [band idx=30] v0=8.1596e+11 (phys), bracketing with step=1.5
#   upper bracket: 1.2239e+12
#   lower bracket: 5.4397e+11
#   level 0.678: [7.4676e+11, 9.1459e+11] (phys)
#   level 0.954: [7.2808e+11, 9.3807e+11] (phys)
# Band saved as T300/scenario_bkg_b/bands/band_bkgb_idx030.json
# === index 40 ===
# [band idx=40] v0=7.4288e+11 (phys), bracketing with step=1.5
#   upper bracket: 1.1143e+12
#   lower bracket: 4.9525e+11
#   level 0.678: [6.7988e+11, 8.3268e+11] (phys)
#   level 0.954: [6.4628e+11, 8.5405e+11] (phys)
# Band saved as T300/scenario_bkg_b/bands/band_bkgb_idx040.json
# === index 50 ===
# [band idx=50] v0=6.9049e+11 (phys), bracketing with step=1.5
#   upper bracket: 1.0357e+12
#   lower bracket: 4.6032e+11
#   level 0.678: [6.0070e+11, 7.5459e+11] (phys)
#   level 0.954: [5.7101e+11, 7.7395e+11] (phys)
# Band saved as T300/scenario_bkg_b/bands/band_bkgb_idx050.json
# === index 60 ===
# [band idx=60] v0=5.9849e+11 (phys), bracketing with step=1.5
#   upper bracket: 8.9773e+11
#   lower bracket: 3.9899e+11
#   level 0.678: [5.2066e+11, 6.7083e+11] (phys)
#   level 0.954: [4.9493e+11, 7.0571e+11] (phys)
# Band saved as T300/scenario_bkg_b/bands/band_bkgb_idx060.json
# === index 70 ===
# [band idx=70] v0=5.3174e+11 (phys), bracketing with step=1.5
#   upper bracket: 7.9761e+11
#   lower bracket: 3.5449e+11
#   level 0.678: [4.3974e+11, 5.9602e+11] (phys)
#   level 0.954: [4.1800e+11, 6.1132e+11] (phys)
# Band saved as T300/scenario_bkg_b/bands/band_bkgb_idx070.json
# === index 80 ===
# [band idx=80] v0=4.2693e+11 (phys), bracketing with step=1.5
#   upper bracket: 6.4039e+11
#   lower bracket: 2.8462e+11
#   level 0.678: [3.7141e+11, 5.1633e+11] (phys)
#   level 0.954: [3.5306e+11, 5.4318e+11] (phys)
# Band saved as T300/scenario_bkg_b/bands/band_bkgb_idx080.json
# === index 90 ===
# [band idx=90] v0=3.7288e+11 (phys), bracketing with step=1.5
#   upper bracket: 5.5931e+11
#   lower bracket: 2.4858e+11
#   level 0.678: [3.1627e+11, 4.3968e+11] (phys)
#   level 0.954: [2.9312e+11, 4.6254e+11] (phys)
# Band saved as T300/scenario_bkg_b/bands/band_bkgb_idx090.json
# === index 100 ===
# [band idx=100] v0=3.1588e+11 (phys), bracketing with step=1.5
#   upper bracket: 4.7382e+11
#   lower bracket: 2.1059e+11
#   level 0.678: [2.6123e+11, 3.8203e+11] (phys)
#   level 0.954: [2.4210e+11, 4.0190e+11] (phys)
# Band saved as T300/scenario_bkg_b/bands/band_bkgb_idx100.json
# === index 110 ===
# [band idx=110] v0=2.7580e+11 (phys), bracketing with step=1.5
#   upper bracket: 4.1370e+11
#   lower bracket: 1.8386e+11
#   level 0.678: [2.1138e+11, 3.2521e+11] (phys)
#   level 0.954: [1.9591e+11, 3.5090e+11] (phys)
# Band saved as T300/scenario_bkg_b/bands/band_bkgb_idx110.json
# === index 120 ===
# [band idx=120] v0=2.1923e+11 (phys), bracketing with step=1.5
#   upper bracket: 3.2885e+11
#   lower bracket: 1.4615e+11
#   level 0.678: [1.7234e+11, 2.7893e+11] (phys)
#   level 0.954: [1.5573e+11, 3.0096e+11] (phys)
# Band saved as T300/scenario_bkg_b/bands/band_bkgb_idx120.json
# === index 130 ===
# [band idx=130] v0=2.1571e+11 (phys), bracketing with step=1.5
#   upper bracket: 3.2356e+11
#   lower bracket: 9.5871e+10
#   level 0.678: [1.1305e+11, 2.4178e+11] (phys)
#   level 0.954: [1.0477e+11, 2.5436e+11] (phys)
# Band saved as T300/scenario_bkg_b/bands/band_bkgb_idx130.json
# === index 140 ===
# [band idx=140] v0=1.2277e+11 (phys), bracketing with step=1.5
#   upper bracket: 2.7623e+11
#   lower bracket: 5.4564e+10
#   level 0.678: [8.2896e+10, 2.0125e+11] (phys)
#   level 0.954: [5.8137e+10, 2.2844e+11] (phys)
# Band saved as T300/scenario_bkg_b/bands/band_bkgb_idx140.json
# === index 150 ===
# [band idx=150] v0=1.2277e+11 (phys), bracketing with step=1.5
#   upper bracket: 1.8415e+11
#   lower bracket: 2.4251e+10
#   level 0.678: [3.2458e+10, 1.6432e+11] (phys)
#   level 0.954: [2.5839e+10, 1.7730e+11] (phys)
# Band saved as T300/scenario_bkg_b/bands/band_bkgb_idx150.json
# === index 160 ===
# [band idx=160] v0=1.2277e+11 (phys), bracketing with step=1.5
#   upper bracket: 1.8415e+11
#   lower bracket: 1.4193e+09
#   level 0.678: [9.2362e+09, 1.3417e+11] (phys)
#   level 0.954: [1.4318e+09, 1.4848e+11] (phys)
# Band saved as T300/scenario_bkg_b/bands/band_bkgb_idx160.json
# === index 167 ===
# [band idx=167] v0=0.0000e+00 (phys), bracketing with step=1.5
#   upper edge unbounded (still inside at max_bracket)
#   lower edge reaches 0 / unbounded below
#   level 0.678: [0.0000e+00, inf] (phys)
#   level 0.954: [0.0000e+00, inf] (phys)
# Band saved as T300/scenario_bkg_b/bands/band_bkgb_idx167.json

# %%
# 保存したバンドを読み込んで optimize 結果の上に重ねる
# band_files はグロブパターンでも、明示的なリストでもよい
a.plot_flux_with_bands(
    f'scenario_bkg_b/bands/band_bkg{a.background_scenario}_idx*.json',
    levels=(0.678, 0.954),   # 表示するレベル (省略すると保存済み全レベル)
    save=True,
    ylim=(0, 3e13),                # 高フラックス側の裾まで見えるように
)
import matplotlib.pyplot as plt
#plt.yscale('log')
plt.ylim(0, 2e12)
plt.show()

# %%
# 保存したバンドを読み込んで optimize 結果の上に重ねる
# band_files はグロブパターンでも、明示的なリストでもよい
a.plot_flux_with_bands(
    f'scenario_bkg_b/bands/band_bkg{a.background_scenario}_idx*.json',
    levels=(0.678, 0.954),   # 表示するレベル (省略すると保存済み全レベル)
    save=True,
    ylim=(0, 3e13),                # 高フラックス側の裾まで見えるように
)
import matplotlib.pyplot as plt
plt.yscale('log')
plt.ylim(1e11, 1e14)
plt.show()
