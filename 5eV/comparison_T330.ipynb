# %%
from neutrino_analysis_band import NeutrinoAnalysis

# %%
# Run optimize() on each scenario first
a_flat = NeutrinoAnalysis(background_scenario='flat', intervals='180', GeV=0.32e16, solver='osqp', T=330)
a_flat.optimize(a_flat.data_vector)
a_a = NeutrinoAnalysis(background_scenario='a', intervals='180', GeV=0.36e16, solver='osqp', T=330)
a_a.optimize(a_a.data_vector)
a_b = NeutrinoAnalysis(background_scenario='b', intervals='180', GeV=0.6e16, solver='osqp', T=330)
a_b.optimize(a_b.data_vector)

# %%
a_b.plot_band_comparison(
    {r'1$\sigma$ CL: Exp Bkg':    'T330/scenario_bkg_b/bands/band_*_bkgpen.json',
     r'1$\sigma$ CL: No Bkg': 'T330/scenario_bkg_a/bands/band_*_bkgpen.json',},
    level=0.678,
    optimized={'Exp Bkg': a_b},   # Overlay each scenario's optimize result
    ylim=(0, 2e12), save=True,
    fname='5eVband_comparison_T330_1sigma_bkgpen.pdf',
    logy = False,
    style = 'both',
    degeneracy_files='T330/scenario_bkg_b/degeneracy/degeneracy_bkgb_idx*.json',
    show_errorbars=False,
    bestfit_marker= '.'
)
# Out:
# [warn] degeneracy requested but no data to draw
# Plot saved as 5eVband_comparison_T330_1sigma_bkgpen.pdf

# %%
a_b.plot_band_comparison(
    {r'1$\sigma$ CL: Exp Bkg':    'T330/scenario_bkg_b/bands/band_*_bkgpen.json',
     r'1$\sigma$ CL: No Bkg': 'T330/scenario_bkg_a/bands/band_*_bkgpen.json',},
    level=0.678,
    optimized={'Exp Bkg': a_b},   # Overlay each scenario's optimize result
    ylim=(1e11, 5e12), save=True,
    fname='5eVband_comparison_T330_1sigma_edge_bkgpen.pdf',
    logy = True,
    style = 'both',
    degeneracy_files='T330/scenario_bkg_b/degeneracy/degeneracy_bkgb_idx*.json',
    show_errorbars=False,
    bestfit_marker= '.'
)
# Out:
# [warn] degeneracy requested but no data to draw
# Plot saved as 5eVband_comparison_T330_1sigma_edge_bkgpen.pdf

# %%
a_b.plot_band_comparison(
    {r'2$\sigma$ CL: Exp Bkg':    'T330/scenario_bkg_b/bands/band_*_bkgpen.json',
     r'2$\sigma$ CL: No Bkg': 'T330/scenario_bkg_a/bands/band_*_bkgpen.json',},
    level=0.954,
    optimized={'Exp Bkg': a_b},   # Overlay each scenario's optimize result
    ylim=(0, 2e12), save=True,
    fname='5eVband_comparison_T330_2sigma_bkgpen.pdf',
    logy = False,
    style = 'both',
    degeneracy_files='T330/scenario_bkg_b/degeneracy/degeneracy_bkgb_idx*.json',
    show_errorbars=False,
    bestfit_marker= '.'
)
import matplotlib.pyplot as plt
plt.xlim(0.35, 3)
plt.ylim(1e-3, 2.5)
plt.savefig('5eVband_comparison_T330_2sigma_bkgpen.pdf')
# Out:
# [warn] degeneracy requested but no data to draw
# Plot saved as 5eVband_comparison_T330_2sigma_bkgpen.pdf

# %%
a_b.plot_band_comparison(
    {r'2$\sigma$ CL: Exp Bkg':    'T330/scenario_bkg_b/bands/band_*_bkgpen.json',
     r'2$\sigma$ CL: No Bkg': 'T330/scenario_bkg_a/bands/band_*_bkgpen.json',},
    level=0.954,
    optimized={'Exp Bkg': a_b},   # Overlay each scenario's optimize result
    ylim=(1e11, 8e12), save=True,
    fname='5eVband_comparison_T330_2sigma_edge_bkgpen.pdf',
    logy = True,
    style = 'both',
    degeneracy_files='T330/scenario_bkg_b/degeneracy/degeneracy_bkgb_idx*.json',
    show_errorbars=False,
    bestfit_marker= '.'
)
# Out:
# [warn] degeneracy requested but no data to draw
# Plot saved as 5eVband_comparison_T330_2sigma_edge_bkgpen.pdf

# %% [markdown]
# ### Comparison

# %%
a_b.plot_band_comparison(
    {r'1$\sigma$ CL: Exp Bkg 3 kg year':    'T3/scenario_bkg_b/bands/band_*.json',
     r'1$\sigma$ CL: Exp Bkg 300 kg year': 'T300/scenario_bkg_a/bands/band_*.json',},
    level=0.678,
    optimized={'Exp Bkg': a_b},   # Overlay each scenario's optimize result
    ylim=(0, 2e12), save=True,
    fname='band_comparison_Tvaried_1sigma.pdf',
    logy = False
)
# Out:
# Plot saved as band_comparison_Tvaried_1sigma.pdf

# %%
a_b.plot_band_comparison(
    {r'1$\sigma$ CL: Exp Bkg 3 kg year':    'T3/scenario_bkg_b/bands/band_*.json',
     r'1$\sigma$ CL: Exp Bkg 300 kg year': 'T300/scenario_bkg_a/bands/band_*.json',},
    level=0.678,
    optimized={'Exp Bkg': a_b},   # Overlay each scenario's optimize result
    ylim=(1e11, 1e14), save=True,
    fname='band_comparison_Tvaried_1sigma_edge.pdf',
    logy = True
)
# Out:
# Plot saved as band_comparison_Tvaried_1sigma_edge.pdf

# %%
a_b.plot_band_comparison(
    {r'2$\sigma$ CL: Exp Bkg 3 kg year':    'T3/scenario_bkg_b/bands/band_*_bkgpen.json',
     r'2$\sigma$ CL: Exp Bkg 300 kg year': 'T300/scenario_bkg_a/bands/band_*_bkgpen.json',},
    level=0.954,
    optimized={'Exp Bkg': a_b},   # Overlay each scenario's optimize result
    ylim=(0, 2e12), save=True,
    fname='band_comparison_Tvaried_2sigma.pdf',
    logy = False,
    show_errorbars=False,
    bestfit_marker= '.'
)
import matplotlib.pyplot as plt
plt.xlim(0.35, 3)
plt.ylim(1e-3, 2.5)
plt.savefig('5eVband_comparison_Tvaried_2sigma_bkgpen.pdf')
# Out:
# Plot saved as band_comparison_Tvaried_2sigma.pdf

# %%
a_b.plot_band_comparison(
    {r'2$\sigma$ CL: Exp Bkg 3 kg year':    'T3/scenario_bkg_b/bands/band_*.json',
     r'2$\sigma$ CL: Exp Bkg 300 kg year': 'T300/scenario_bkg_a/bands/band_*.json',},
    level=0.954,
    optimized={'Exp Bkg': a_b},   # Overlay each scenario's optimize result
    ylim=(1e11, 1e14), save=True,
    fname='band_comparison_Tvaried_2sigma_edge.pdf',
    logy = True
)
# Out:
# Plot saved as band_comparison_Tvaried_2sigma_edge.pdf

# %% [markdown]
# ### Individual bands

# %%
# Load the saved bands and overlay them on the optimize result
# band_files can be a glob pattern or an explicit list
a_a.plot_flux_with_bands(
    f'T300/scenario_bkg_a/bands/band_bkg{a_a.background_scenario}_idx*.json',
    levels=(0.678, 0.954),   # Levels to plot (omit to show all saved levels)
    save=True,
    ylim=(0, 3e13),                # So the high-flux tail is visible
)
import matplotlib.pyplot as plt
plt.yscale('log')
plt.ylim(1e-1, 7)
plt.show()
# Out:
# Plot saved as T3/scenario_bkg_a/flux_with_bands_bkg_a.pdf

# %%
# Load the saved bands and overlay them on the optimize result
# band_files can be a glob pattern or an explicit list
a_b.plot_flux_with_bands(
    f'T300/scenario_bkg_b/bands/band_bkg{a_b.background_scenario}_idx*.json',
    levels=(0.678, 0.954),   # Levels to plot (omit to show all saved levels)
    save=True,
    ylim=(0, 3e13),                # So the high-flux tail is visible
)
import matplotlib.pyplot as plt
plt.yscale('log')
plt.ylim(1e-1, 7)
plt.show()
# Out:
# Plot saved as T3/scenario_bkg_b/flux_with_bands_bkg_b.pdf
