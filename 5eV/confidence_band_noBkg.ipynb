# %% [markdown]
# # Confidence-band root finder (`find_confidence_band`)
#
# Example: instead of a uniform grid, locate the band edges directly by bracketing + geometric bisection.
# Bracket the outer reach with the widest level (2σ); the narrower 1σ / 90% / 2σ edges nest inside that interval.
#
# - `num_pseudo_data`: pseudo-data sample size during bracketing (can be coarse)
# - `n_pseudo_edge`: pseudo-data sample size for the edge bisection (larger suppresses cutoff noise)
# - `seed`: fixed value makes every evaluation reproducible and stops the bisection from jittering

# %%
from neutrino_analysis_band import NeutrinoAnalysis

a = NeutrinoAnalysis(background_scenario='a', intervals='180',
                     GeV=0.36e16, solver='osqp')
a.optimize(a.data_vector)   # Compute the best fit first (populates self.result)
result_a = a.optimize(a.data_vector)
print("\nOptimization Complete.")
print(f"Minimum chi-squared: {result_a.fun / a.c}")
# 3. Plot the primary result: the optimized flux vs. theory.
a.plot_flux_comparison(save = True)
# Out:
# Optimization Complete.
# Minimum chi-squared: 1.4643028784668667e-08
# Plot saved as scenario_bkg_a/flux_comparison_bkg_a.pdf

# %% [markdown]
# ## Save bands for several indices and overlay them
#
# 1. Run `find_and_save_band` per index and save one JSON file per index under `bands/`.
# 2. Load the saved files with `plot_flux_with_bands` and overlay each index's band as an error bar on top of the `optimize` flux scatter.
#
# `save_band` / `load_band` use a human-readable JSON format. The band centre is the saved `self.result.x[index]`, so it lines up exactly with the scatter from the same `optimize` result.

# %%
# Build bands for several indices and save one file per index
# Destination: ./bands/band_bkg<scenario>_idx<NNN>.json
indices = [0, 1, 2, 3, 4, 5, 8, 13, 16, 20, 25, 30, 40, 50, 60, 70, 80, 90, 100, 110, 120, 130, 140, 150, 160, 167]     # Indices to run

for idx in indices:
    print(f'=== index {idx} ===')
    a.find_and_save_band(
        idx,
        outdir='scenario_bkg_a/bands',
        levels=(0.678, 0.954),
        num_pseudo_data=50,
        n_pseudo_edge=500,
        step=1.5,
        rel_tol=0.03,
        seed=42,
        n_jobs=1,
        verbose=True,
    )
# Out:
# === index 0 ===
# [band idx=0] v0=1.0447e+12 (phys), bracketing with step=1.5
#   upper bracket: 2.6774e+13
#   lower bracket: 6.9645e+11
#   level 0.678: [9.0883e+11, 1.1170e+13] (phys)
#   level 0.954: [8.4230e+11, 2.2710e+13] (phys)
# Band saved as scenario_bkg_a/bands/band_bkga_idx000.json
# === index 1 ===
# [band idx=1] v0=1.0447e+12 (phys), bracketing with step=1.5
#   upper bracket: 1.1900e+13
#   lower bracket: 6.9645e+11
#   level 0.678: [8.4230e+11, 5.2058e+12] (phys)
#   level 0.954: [7.6111e+11, 1.0125e+13] (phys)
# Band saved as scenario_bkg_a/bands/band_bkga_idx001.json
# === index 2 ===
# [band idx=2] v0=1.0447e+12 (phys), bracketing with step=1.5
#   upper bracket: 7.9330e+12
#   lower bracket: 6.9645e+11
#   level 0.678: [8.4230e+11, 3.3463e+12] (phys)
#   level 0.954: [7.6111e+11, 6.1088e+12] (phys)
# Band saved as scenario_bkg_a/bands/band_bkga_idx002.json
# === index 3 ===
# [band idx=3] v0=1.0447e+12 (phys), bracketing with step=1.5
#   upper bracket: 5.2887e+12
#   lower bracket: 6.9645e+11
#   level 0.678: [8.4230e+11, 2.5045e+12] (phys)
#   level 0.954: [7.6111e+11, 4.2642e+12] (phys)
# Band saved as scenario_bkg_a/bands/band_bkga_idx003.json
# === index 4 ===
# [band idx=4] v0=1.0447e+12 (phys), bracketing with step=1.5
#   upper bracket: 3.5258e+12
#   lower bracket: 6.9645e+11
#   level 0.678: [8.4230e+11, 2.0127e+12] (phys)
#   level 0.954: [7.6111e+11, 3.2369e+12] (phys)
# Band saved as scenario_bkg_a/bands/band_bkga_idx004.json
# === index 5 ===
# [band idx=5] v0=1.0447e+12 (phys), bracketing with step=1.5
#   upper bracket: 3.5258e+12
#   lower bracket: 6.9645e+11
#   level 0.678: [8.4230e+11, 1.7288e+12] (phys)
#   level 0.954: [7.6111e+11, 2.6262e+12] (phys)
# Band saved as scenario_bkg_a/bands/band_bkga_idx005.json
# === index 8 ===
# [band idx=8] v0=1.0447e+12 (phys), bracketing with step=1.5
#   upper bracket: 2.3505e+12
#   lower bracket: 6.9645e+11
#   level 0.678: [8.2122e+11, 1.3633e+12] (phys)
#   level 0.954: [7.6111e+11, 1.8015e+12] (phys)
# Band saved as scenario_bkg_a/bands/band_bkga_idx008.json
# === index 13 ===
# [band idx=13] v0=1.0447e+12 (phys), bracketing with step=1.5
#   upper bracket: 1.5670e+12
#   lower bracket: 6.9645e+11
#   level 0.678: [7.8064e+11, 1.2635e+12] (phys)
#   level 0.954: [7.2349e+11, 1.4341e+12] (phys)
# Band saved as scenario_bkg_a/bands/band_bkga_idx013.json
# === index 16 ===
# [band idx=16] v0=9.1382e+11 (phys), bracketing with step=1.5
#   upper bracket: 1.3707e+12
#   lower bracket: 6.0922e+11
#   level 0.678: [7.5571e+11, 1.1925e+12] (phys)
#   level 0.954: [7.0039e+11, 1.3536e+12] (phys)
# Band saved as scenario_bkg_a/bands/band_bkga_idx016.json
# === index 20 ===
# [band idx=20] v0=9.1382e+11 (phys), bracketing with step=1.5
#   upper bracket: 1.3707e+12
#   lower bracket: 6.0922e+11
#   level 0.678: [7.1836e+11, 1.1336e+12] (phys)
#   level 0.954: [6.6577e+11, 1.2545e+12] (phys)
# Band saved as scenario_bkg_a/bands/band_bkga_idx020.json
# === index 25 ===
# [band idx=25] v0=9.1382e+11 (phys), bracketing with step=1.5
#   upper bracket: 1.3707e+12
#   lower bracket: 6.0922e+11
#   level 0.678: [6.8286e+11, 1.0775e+12] (phys)
#   level 0.954: [6.3287e+11, 1.1627e+12] (phys)
# Band saved as scenario_bkg_a/bands/band_bkga_idx025.json
# === index 30 ===
# [band idx=30] v0=8.1603e+11 (phys), bracketing with step=1.5
#   upper bracket: 1.2240e+12
#   lower bracket: 5.4402e+11
#   level 0.678: [6.4148e+11, 1.0382e+12] (phys)
#   level 0.954: [5.9452e+11, 1.1202e+12] (phys)
# Band saved as scenario_bkg_a/bands/band_bkga_idx030.json
# === index 40 ===
# [band idx=40] v0=7.4290e+11 (phys), bracketing with step=1.5
#   upper bracket: 1.1144e+12
#   lower bracket: 4.9527e+11
#   level 0.678: [5.6938e+11, 9.4519e+11] (phys)
#   level 0.954: [5.1450e+11, 9.9433e+11] (phys)
# Band saved as scenario_bkg_a/bands/band_bkga_idx040.json
# === index 50 ===
# [band idx=50] v0=6.9048e+11 (phys), bracketing with step=1.5
#   upper bracket: 1.0357e+12
#   lower bracket: 3.0688e+11
#   level 0.678: [5.0306e+11, 8.5652e+11] (phys)
#   level 0.954: [4.3210e+11, 9.2417e+11] (phys)
# Band saved as scenario_bkg_a/bands/band_bkga_idx050.json
# === index 60 ===
# [band idx=60] v0=5.9848e+11 (phys), bracketing with step=1.5
#   upper bracket: 8.9771e+11
#   lower bracket: 2.6599e+11
#   level 0.678: [3.9399e+11, 7.8098e+11] (phys)
#   level 0.954: [3.6515e+11, 8.4267e+11] (phys)
# Band saved as scenario_bkg_a/bands/band_bkga_idx060.json
# === index 70 ===
# [band idx=70] v0=5.3173e+11 (phys), bracketing with step=1.5
#   upper bracket: 7.9759e+11
#   lower bracket: 2.3632e+11
#   level 0.678: [3.5005e+11, 6.9388e+11] (phys)
#   level 0.954: [3.0068e+11, 7.4869e+11] (phys)
# Band saved as scenario_bkg_a/bands/band_bkga_idx070.json
# === index 80 ===
# [band idx=80] v0=4.2693e+11 (phys), bracketing with step=1.5
#   upper bracket: 9.6060e+11
#   lower bracket: 1.8975e+11
#   level 0.678: [2.8827e+11, 6.1656e+11] (phys)
#   level 0.954: [2.4142e+11, 6.6526e+11] (phys)
# Band saved as scenario_bkg_a/bands/band_bkga_idx080.json
# === index 90 ===
# [band idx=90] v0=3.7284e+11 (phys), bracketing with step=1.5
#   upper bracket: 8.3890e+11
#   lower bracket: 1.6571e+11
#   level 0.678: [2.3332e+11, 5.3845e+11] (phys)
#   level 0.954: [1.9540e+11, 5.9589e+11] (phys)
# Band saved as scenario_bkg_a/bands/band_bkga_idx090.json
# === index 100 ===
# [band idx=100] v0=3.1592e+11 (phys), bracketing with step=1.5
#   upper bracket: 7.1081e+11
#   lower bracket: 1.4041e+11
#   level 0.678: [1.9275e+11, 4.6795e+11] (phys)
#   level 0.954: [1.4960e+11, 5.1787e+11] (phys)
# Band saved as scenario_bkg_a/bands/band_bkga_idx100.json
# === index 110 ===
# [band idx=110] v0=2.7578e+11 (phys), bracketing with step=1.5
#   upper bracket: 6.2052e+11
#   lower bracket: 8.1714e+10
#   level 0.678: [1.4046e+11, 4.0850e+11] (phys)
#   level 0.954: [1.0971e+11, 4.6368e+11] (phys)
# Band saved as scenario_bkg_a/bands/band_bkga_idx110.json
# === index 120 ===
# [band idx=120] v0=2.1923e+11 (phys), bracketing with step=1.5
#   upper bracket: 4.9326e+11
#   lower bracket: 6.4956e+10
#   level 0.678: [1.0749e+11, 3.5937e+11] (phys)
#   level 0.954: [6.9427e+10, 3.9771e+11] (phys)
# Band saved as scenario_bkg_a/bands/band_bkga_idx120.json
# === index 130 ===
# [band idx=130] v0=2.1575e+11 (phys), bracketing with step=1.5
#   upper bracket: 4.8545e+11
#   lower bracket: 2.8412e+10
#   level 0.678: [6.7360e+10, 3.0379e+11] (phys)
#   level 0.954: [3.8086e+10, 3.5368e+11] (phys)
# Band saved as scenario_bkg_a/bands/band_bkga_idx130.json
# === index 140 ===
# [band idx=140] v0=1.2277e+11 (phys), bracketing with step=1.5
#   upper bracket: 4.1434e+11
#   lower bracket: 4.7902e+09
#   level 0.678: [2.5839e+10, 2.7537e+11] (phys)
#   level 0.954: [4.8517e+09, 3.1455e+11] (phys)
# Band saved as scenario_bkg_a/bands/band_bkga_idx140.json
# === index 150 ===
# [band idx=150] v0=1.2277e+11 (phys), bracketing with step=1.5
#   upper bracket: 2.7623e+11
#   lower edge reaches 0 / unbounded below
#   level 0.678: [0.0000e+00, 2.2843e+11] (phys)
#   level 0.954: [0.0000e+00, 2.6595e+11] (phys)
# Band saved as scenario_bkg_a/bands/band_bkga_idx150.json
# === index 160 ===
# [band idx=160] v0=1.2277e+11 (phys), bracketing with step=1.5
#   upper bracket: 2.7623e+11
#   lower edge reaches 0 / unbounded below
#   level 0.678: [0.0000e+00, 1.7730e+11] (phys)
#   level 0.954: [0.0000e+00, 2.0641e+11] (phys)
# Band saved as scenario_bkg_a/bands/band_bkga_idx160.json
# === index 167 ===
# [band idx=167] v0=0.0000e+00 (phys), bracketing with step=1.5
#   upper edge unbounded (still inside at max_bracket)
#   lower edge reaches 0 / unbounded below
#   level 0.678: [0.0000e+00, inf] (phys)
#   level 0.954: [0.0000e+00, inf] (phys)
# Band saved as scenario_bkg_a/bands/band_bkga_idx167.json

# %%
# Load the saved bands and overlay them on the optimize result
# band_files can be a glob pattern or an explicit list
a.plot_flux_with_bands(
    f'scenario_bkg_a/bands/band_bkg{a.background_scenario}_idx*.json',
    levels=(0.678, 0.954),   # Levels to plot (omit to show all saved levels)
    save=True,
    ylim=(0, 3e13),                # So the high-flux tail is visible
)
import matplotlib.pyplot as plt
#plt.yscale('log')
plt.ylim(0, 2e12)
plt.show()
# Out:
# Plot saved as scenario_bkg_a/flux_with_bands_bkg_a.pdf

# %%
# Load the saved bands and overlay them on the optimize result
# band_files can be a glob pattern or an explicit list
a.plot_flux_with_bands(
    f'scenario_bkg_a/bands/band_bkg{a.background_scenario}_idx*.json',
    levels=(0.678, 0.954),   # Levels to plot (omit to show all saved levels)
    save=True,
    ylim=(0, 3e13),                # So the high-flux tail is visible
)
import matplotlib.pyplot as plt
plt.yscale('log')
plt.ylim(1e11, 1e14)
plt.show()
# Out:
# Plot saved as scenario_bkg_a/flux_with_bands_bkg_a.pdf
